# %%
input_dir = "[1] Peakfinder Results" 

output_dir = "[2] Analyzer Results"

# %%
import os
import pandas as pd
import numpy as np
import ast

dfs = {}


files = [file for file in os.listdir(input_dir) if file.endswith(('.xlsx', '.xls')) and not file.startswith('OVERVIEW')]

for file in files:
    file_path = os.path.join(input_dir, file)
    dfs[file.split('.')[0]] = pd.read_excel(file_path)

framenames = list(dfs.keys())
results = framenames[0]
results_mtt = framenames[1]
results_tt = framenames[2]

print(f"Found {framenames} in {input_dir}.")

framenames.append('RESULTS_MERGED')
framenames.append('RESULTS_MERGED_MTT')
framenames.append('RESULTS_MERGED_TT')

experiments = dfs[results]['experiment'].unique().tolist()
variables = dfs[results].columns[4:].tolist()
parameters = dfs[results].columns[:4].tolist()
print(f"\nFound {len(experiments)} experiments, {len(variables)} variables and {len(parameters)} parameters:")
print(" "+', '.join(experiments))
print(" "+', '.join(variables))
print(" "+', '.join(parameters))



def average_list_columns(df):
    import numpy as np
    import ast

    def safe_mean(x):
        # If x is a string representing a list, convert to list
        if isinstance(x, str) and x.startswith('['):
            try:
                x = ast.literal_eval(x)
            except Exception:
                return np.nan
        # If x is a list, filter out None and np.nan
        if isinstance(x, list):
            x = [v for v in x if v is not None and not (isinstance(v, float) and np.isnan(v))]
            return np.mean(x) if len(x) > 0 else np.nan
        # If x is None or nan, return nan
        if x is None or (isinstance(x, float) and np.isnan(x)):
            return np.nan
        # Otherwise, return x
        return x

    df_copy = df.copy()
    for col in df_copy.columns:
        if df_copy[col].apply(lambda x: isinstance(x, list) or (isinstance(x, str) and x.startswith('['))).any():
            df_copy[col] = df_copy[col].apply(safe_mean)
    return df_copy

def average_across_dates(df):
    # Group by all columns except 'date' and the variables, then average variables across dates
    group_cols = [col for col in df.columns if col not in variables and col != 'date']
    averaged = df.groupby(group_cols, as_index=False)[variables].mean()
    return averaged

def average_across_experiment(df):
    # Group by all columns except 'experiment' and the variables, then average variables across experiment
    group_cols = [col for col in df.columns if col not in variables and col != 'experiment']
    averaged = df.groupby(group_cols, as_index=False)[variables].mean()
    return averaged



# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])


# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])

# Create date-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_TT_MERGED'])


# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])

# Create date-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_TT_MERGED'])

# Create experiment-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_TT_MERGED'])

print(f"\nFound {len(dfs)} dataframes:")
print(list(dfs.keys()))
# Out:
# Found ['RESULTS', 'RESULTS_MT10', 'RESULTS_T10', 'SegmentOrder'] in [1] Peakfinder Results.
#
# Found 18 experiments, 9 variables and 4 parameters:
#  ASR_control, gap_depth, tone_in_noise, gap_duration_4, gap_duration_8, gap_duration_10, gap_duration_20, gap_duration_50, offset_PPI_4, offset_PPI_6, offset_PPI_8, offset_PPI_10, offset_PPI_12, offset_PPI_14, offset_PPI_16, offset_PPI_18, offset_PPI_20, offset_PPI_50
#  reactionTime, peakTime, difference, peakValue, PTPA, PTTA, RMS, tau, AUC
#  animal, sex, date, experiment
#
# Found 13 dataframes:
# ['RESULTS', 'RESULTS_MT10', 'RESULTS_T10', 'SegmentOrder', 'RESULTS_MERGED', 'RESULTS_MTT_MERGED', 'RESULTS_TT_MERGED', 'RESULTS_MERGED_DATE', 'RESULTS_MTT_MERGED_DATE', 'RESULTS_TT_MERGED_DATE', 'RESULTS_MERGED_EXP', 'RESULTS_MTT_MERGED_EXP', 'RESULTS_TT_MERGED_EXP']

# %% [markdown]
# ---

# %% [markdown]
# # Normality

# %%
# Test normality (Shapiro-Wilk) for each variable, averaged across dates, split by experiment and sex

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED_DATE']  # This DataFrame is already averaged across dates
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex']]  # 'date' is averaged out

for experiment in df['experiment'].unique():
    for sex in df['sex'].unique():
        print(f"\nExperiment: {experiment}, Sex: {sex} (date-averaged)")
        for var in variables:
            vals = pd.to_numeric(df[(df['experiment'] == experiment) & (df['sex'] == sex)][var], errors='coerce').dropna()
            if len(vals) > 2:
                stat, p = shapiro(vals)
                print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
            else:
                print(f"{var}: Not enough data")
# Out:
# Experiment: ASR_control, Sex: female (date-averaged)
# reactionTime: stat=0.964, p=6.369e-01 normal
# peakTime: stat=0.986, p=7.745e-01 normal
# difference: stat=0.979, p=7.222e-01 normal
# peakValue: stat=0.993, p=8.435e-01 normal
# PTPA: stat=0.990, p=8.071e-01 normal
# PTTA: stat=1.000, p=9.932e-01 normal
# RMS: stat=0.994, p=8.492e-01 normal
# tau: stat=1.000, p=9.866e-01 normal
# AUC: stat=0.996, p=8.845e-01 normal
#
# Experiment: ASR_control, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.895, p=3.712e-01 normal
# difference: stat=0.902, p=3.906e-01 normal
# peakValue: stat=0.824, p=1.744e-01 normal
# PTPA: stat=0.854, p=2.500e-01 normal
# PTTA: stat=0.776, p=5.757e-02 normal
# RMS: stat=0.961, p=6.212e-01 normal
# tau: stat=0.993, p=8.437e-01 normal
# AUC: stat=0.992, p=8.252e-01 normal
#
# Experiment: gap_depth, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.923, p=4.633e-01 normal
# difference: stat=0.923, p=4.633e-01 normal
# peakValue: stat=0.989, p=8.032e-01 normal
# PTPA: stat=0.987, p=7.846e-01 normal
# PTTA: stat=0.983, p=7.480e-01 normal
# RMS: stat=0.988, p=7.902e-01 normal
# tau: stat=0.859, p=2.660e-01 normal
# AUC: stat=0.989, p=8.029e-01 normal
#
# Experiment: gap_depth, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.765, p=3.410e-02 NOT normal
# difference: stat=0.767, p=3.716e-02 NOT normal
# peakValue: stat=0.987, p=7.826e-01 normal
# PTPA: stat=0.998, p=9.192e-01 normal
# PTTA: stat=0.988, p=7.898e-01 normal
# RMS: stat=0.946, p=5.513e-01 normal
# tau: stat=0.946, p=5.521e-01 normal
# AUC: stat=0.950, p=5.697e-01 normal
#
# Experiment: gap_duration_10, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.798, p=1.101e-01 normal
# difference: stat=0.798, p=1.101e-01 normal
# peakValue: stat=0.891, p=3.588e-01 normal
# PTPA: stat=0.888, p=3.480e-01 normal
# PTTA: stat=0.927, p=4.762e-01 normal
# RMS: stat=0.869, p=2.923e-01 normal
# tau: stat=0.945, p=5.491e-01 normal
# AUC: stat=0.828, p=1.821e-01 normal
#
# Experiment: gap_duration_10, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.783, p=7.480e-02 normal
# difference: stat=0.783, p=7.480e-02 normal
# peakValue: stat=0.790, p=8.998e-02 normal
# PTPA: stat=0.754, p=8.409e-03 NOT normal
# PTTA: stat=0.778, p=6.259e-02 normal
# RMS: stat=0.781, p=6.948e-02 normal
# tau: stat=0.854, p=2.512e-01 normal
# AUC: stat=0.953, p=5.823e-01 normal
#
# Experiment: gap_duration_20, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.936, p=5.098e-01 normal
# difference: stat=0.936, p=5.098e-01 normal
# peakValue: stat=0.997, p=8.879e-01 normal
# PTPA: stat=0.998, p=9.054e-01 normal
# PTTA: stat=1.000, p=9.953e-01 normal
# RMS: stat=0.993, p=8.361e-01 normal
# tau: stat=0.978, p=7.176e-01 normal
# AUC: stat=1.000, p=9.876e-01 normal
#
# Experiment: gap_duration_20, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.950, p=5.691e-01 normal
# difference: stat=0.950, p=5.691e-01 normal
# peakValue: stat=0.834, p=1.980e-01 normal
# PTPA: stat=0.838, p=2.083e-01 normal
# PTTA: stat=0.772, p=4.875e-02 NOT normal
# RMS: stat=0.889, p=3.502e-01 normal
# tau: stat=0.982, p=7.428e-01 normal
# AUC: stat=0.774, p=5.329e-02 normal
#
# Experiment: gap_duration_4, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.873, p=3.028e-01 normal
# difference: stat=0.873, p=3.028e-01 normal
# peakValue: stat=0.818, p=1.577e-01 normal
# PTPA: stat=0.819, p=1.614e-01 normal
# PTTA: stat=0.874, p=3.059e-01 normal
# RMS: stat=0.782, p=7.332e-02 normal
# tau: stat=0.986, p=7.696e-01 normal
# AUC: stat=0.809, p=1.352e-01 normal
#
# Experiment: gap_duration_4, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.999, p=9.460e-01 normal
# difference: stat=0.993, p=8.428e-01 normal
# peakValue: stat=0.945, p=5.474e-01 normal
# PTPA: stat=0.967, p=6.514e-01 normal
# PTTA: stat=0.816, p=1.525e-01 normal
# RMS: stat=0.969, p=6.598e-01 normal
# tau: stat=0.946, p=5.505e-01 normal
# AUC: stat=0.868, p=2.907e-01 normal
#
# Experiment: gap_duration_50, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.994, p=8.533e-01 normal
# difference: stat=0.994, p=8.533e-01 normal
# peakValue: stat=0.938, p=5.197e-01 normal
# PTPA: stat=0.936, p=5.112e-01 normal
# PTTA: stat=0.946, p=5.510e-01 normal
# RMS: stat=0.834, p=1.993e-01 normal
# tau: stat=0.992, p=8.285e-01 normal
# AUC: stat=0.918, p=4.463e-01 normal
#
# Experiment: gap_duration_50, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.994, p=8.482e-01 normal
# difference: stat=0.994, p=8.482e-01 normal
# peakValue: stat=0.959, p=6.105e-01 normal
# PTPA: stat=0.964, p=6.376e-01 normal
# PTTA: stat=0.988, p=7.929e-01 normal
# RMS: stat=0.887, p=3.443e-01 normal
# tau: stat=0.999, p=9.486e-01 normal
# AUC: stat=0.751, p=1.519e-03 NOT normal
#
# Experiment: gap_duration_8, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.937, p=5.173e-01 normal
# difference: stat=0.937, p=5.173e-01 normal
# peakValue: stat=0.889, p=3.514e-01 normal
# PTPA: stat=0.901, p=3.879e-01 normal
# PTTA: stat=0.914, p=4.320e-01 normal
# RMS: stat=0.868, p=2.913e-01 normal
# tau: stat=0.866, p=2.829e-01 normal
# AUC: stat=0.797, p=1.071e-01 normal
#
# Experiment: gap_duration_8, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.899, p=3.829e-01 normal
# difference: stat=0.923, p=4.633e-01 normal
# peakValue: stat=0.836, p=2.039e-01 normal
# PTPA: stat=0.887, p=3.453e-01 normal
# PTTA: stat=0.878, p=3.200e-01 normal
# RMS: stat=0.801, p=1.163e-01 normal
# tau: stat=0.793, p=9.872e-02 normal
# AUC: stat=0.996, p=8.804e-01 normal
#
# Experiment: offset_PPI_10, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.881, p=3.275e-01 normal
# difference: stat=0.881, p=3.275e-01 normal
# peakValue: stat=0.960, p=6.135e-01 normal
# PTPA: stat=0.954, p=5.851e-01 normal
# PTTA: stat=0.909, p=4.145e-01 normal
# RMS: stat=0.958, p=6.043e-01 normal
# tau: stat=0.824, p=1.728e-01 normal
# AUC: stat=0.946, p=5.511e-01 normal
#
# Experiment: offset_PPI_10, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.940, p=5.280e-01 normal
# difference: stat=0.932, p=4.974e-01 normal
# peakValue: stat=0.841, p=2.164e-01 normal
# PTPA: stat=0.869, p=2.917e-01 normal
# PTTA: stat=0.768, p=3.991e-02 NOT normal
# RMS: stat=0.911, p=4.219e-01 normal
# tau: stat=1.000, p=9.859e-01 normal
# AUC: stat=0.984, p=7.574e-01 normal
#
# Experiment: offset_PPI_12, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.949, p=5.644e-01 normal
# difference: stat=0.949, p=5.644e-01 normal
# peakValue: stat=0.856, p=2.561e-01 normal
# PTPA: stat=0.848, p=2.355e-01 normal
# PTTA: stat=0.890, p=3.547e-01 normal
# RMS: stat=0.858, p=2.631e-01 normal
# tau: stat=0.888, p=3.486e-01 normal
# AUC: stat=0.922, p=4.602e-01 normal
#
# Experiment: offset_PPI_12, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.994, p=8.491e-01 normal
# difference: stat=0.994, p=8.491e-01 normal
# peakValue: stat=0.997, p=9.029e-01 normal
# PTPA: stat=0.999, p=9.262e-01 normal
# PTTA: stat=0.982, p=7.417e-01 normal
# RMS: stat=0.999, p=9.417e-01 normal
# tau: stat=0.879, p=3.213e-01 normal
# AUC: stat=0.994, p=8.554e-01 normal
#
# Experiment: offset_PPI_14, Sex: female (date-averaged)
# reactionTime: stat=0.750, p=0.000e+00 NOT normal
# peakTime: stat=1.000, p=1.000e+00 normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=0.833, p=1.961e-01 normal
# PTPA: stat=0.842, p=2.206e-01 normal
# PTTA: stat=0.890, p=3.547e-01 normal
# RMS: stat=0.820, p=1.640e-01 normal
# tau: stat=0.907, p=4.075e-01 normal
# AUC: stat=0.862, p=2.738e-01 normal
#
# Experiment: offset_PPI_14, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.755, p=1.153e-02 NOT normal
# difference: stat=0.755, p=1.153e-02 NOT normal
# peakValue: stat=1.000, p=9.778e-01 normal
# PTPA: stat=1.000, p=9.733e-01 normal
# PTTA: stat=0.998, p=9.046e-01 normal
# RMS: stat=0.998, p=9.171e-01 normal
# tau: stat=1.000, p=9.895e-01 normal
# AUC: stat=0.996, p=8.765e-01 normal
#
# Experiment: offset_PPI_16, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.763, p=2.998e-02 NOT normal
# difference: stat=0.763, p=2.998e-02 NOT normal
# peakValue: stat=0.975, p=6.965e-01 normal
# PTPA: stat=0.965, p=6.402e-01 normal
# PTTA: stat=0.949, p=5.650e-01 normal
# RMS: stat=0.998, p=9.153e-01 normal
# tau: stat=0.903, p=3.944e-01 normal
# AUC: stat=0.964, p=6.367e-01 normal
#
# Experiment: offset_PPI_16, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.971, p=6.712e-01 normal
# difference: stat=0.983, p=7.515e-01 normal
# peakValue: stat=0.941, p=5.316e-01 normal
# PTPA: stat=0.943, p=5.382e-01 normal
# PTTA: stat=0.898, p=3.777e-01 normal
# RMS: stat=0.963, p=6.302e-01 normal
# tau: stat=0.750, p=7.639e-06 NOT normal
# AUC: stat=0.811, p=1.405e-01 normal
#
# Experiment: offset_PPI_18, Sex: female (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.985, p=7.673e-01 normal
# difference: stat=0.991, p=8.227e-01 normal
# peakValue: stat=0.755, p=1.001e-02 NOT normal
# PTPA: stat=0.752, p=5.224e-03 NOT normal
# PTTA: stat=0.823, p=1.712e-01 normal
# RMS: stat=0.771, p=4.776e-02 NOT normal
# tau: stat=0.935, p=5.058e-01 normal
# AUC: stat=0.821, p=1.662e-01 normal
#
# Experiment: offset_PPI_18, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.994, p=8.464e-01 normal
# difference: stat=0.990, p=8.046e-01 normal
# peakValue: stat=0.894, p=3.670e-01 normal
# PTPA: stat=0.907, p=4.093e-01 normal
# PTTA: stat=0.800, p=1.153e-01 normal
# RMS: stat=0.923, p=4.641e-01 normal
# tau: stat=0.914, p=4.306e-01 normal
# AUC: stat=0.989, p=7.989e-01 normal
#
# Experiment: offset_PPI_20, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.839, p=2.121e-01 normal
# difference: stat=0.839, p=2.121e-01 normal
# peakValue: stat=0.999, p=9.533e-01 normal
# PTPA: stat=0.999, p=9.567e-01 normal
# PTTA: stat=0.999, p=9.518e-01 normal
# RMS: stat=0.999, p=9.456e-01 normal
# tau: stat=0.900, p=3.865e-01 normal
# AUC: stat=0.961, p=6.215e-01 normal
#
# Experiment: offset_PPI_20, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.845, p=2.278e-01 normal
# difference: stat=0.855, p=2.530e-01 normal
# peakValue: stat=0.892, p=3.615e-01 normal
# PTPA: stat=0.901, p=3.887e-01 normal
# PTTA: stat=0.914, p=4.301e-01 normal
# RMS: stat=0.917, p=4.415e-01 normal
# tau: stat=0.999, p=9.404e-01 normal
# AUC: stat=1.000, p=9.946e-01 normal
#
# Experiment: offset_PPI_4, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.925, p=4.701e-01 normal
# difference: stat=0.925, p=4.701e-01 normal
# peakValue: stat=0.904, p=4.000e-01 normal
# PTPA: stat=0.896, p=3.718e-01 normal
# PTTA: stat=0.893, p=3.644e-01 normal
# RMS: stat=0.890, p=3.549e-01 normal
# tau: stat=0.831, p=1.914e-01 normal
# AUC: stat=0.832, p=1.942e-01 normal
#
# Experiment: offset_PPI_4, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.992, p=8.334e-01 normal
# difference: stat=0.997, p=8.934e-01 normal
# peakValue: stat=0.813, p=1.448e-01 normal
# PTPA: stat=0.774, p=5.454e-02 normal
# PTTA: stat=0.770, p=4.539e-02 NOT normal
# RMS: stat=0.935, p=5.082e-01 normal
# tau: stat=0.989, p=7.993e-01 normal
# AUC: stat=0.904, p=3.971e-01 normal
#
# Experiment: offset_PPI_50, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.968, p=6.591e-01 normal
# difference: stat=0.968, p=6.591e-01 normal
# peakValue: stat=0.896, p=3.730e-01 normal
# PTPA: stat=0.887, p=3.460e-01 normal
# PTTA: stat=0.927, p=4.768e-01 normal
# RMS: stat=0.850, p=2.392e-01 normal
# tau: stat=0.999, p=9.447e-01 normal
# AUC: stat=0.850, p=2.401e-01 normal
#
# Experiment: offset_PPI_50, Sex: male (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.763, p=2.945e-02 NOT normal
# difference: stat=0.763, p=2.945e-02 NOT normal
# peakValue: stat=0.933, p=4.984e-01 normal
# PTPA: stat=0.918, p=4.462e-01 normal
# PTTA: stat=0.847, p=2.316e-01 normal
# RMS: stat=0.945, p=5.473e-01 normal
# tau: stat=0.750, p=1.328e-04 NOT normal
# AUC: stat=0.966, p=6.465e-01 normal
#
# Experiment: offset_PPI_6, Sex: female (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.878, p=3.196e-01 normal
# difference: stat=0.826, p=1.785e-01 normal
# peakValue: stat=0.837, p=2.061e-01 normal
# PTPA: stat=0.849, p=2.387e-01 normal
# PTTA: stat=0.899, p=3.813e-01 normal
# RMS: stat=0.822, p=1.684e-01 normal
# tau: stat=0.882, p=3.302e-01 normal
# AUC: stat=0.826, p=1.782e-01 normal
#
# Experiment: offset_PPI_6, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.984, p=7.555e-01 normal
# difference: stat=0.973, p=6.847e-01 normal
# peakValue: stat=0.815, p=1.508e-01 normal
# PTPA: stat=0.824, p=1.730e-01 normal
# PTTA: stat=0.763, p=2.848e-02 NOT normal
# RMS: stat=0.889, p=3.502e-01 normal
# tau: stat=0.845, p=2.265e-01 normal
# AUC: stat=0.769, p=4.157e-02 NOT normal
#
# Experiment: offset_PPI_8, Sex: female (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.997, p=9.028e-01 normal
# difference: stat=1.000, p=9.694e-01 normal
# peakValue: stat=0.950, p=5.674e-01 normal
# PTPA: stat=0.955, p=5.922e-01 normal
# PTTA: stat=0.930, p=4.902e-01 normal
# RMS: stat=0.946, p=5.502e-01 normal
# tau: stat=0.891, p=3.562e-01 normal
# AUC: stat=0.963, p=6.317e-01 normal
#
# Experiment: offset_PPI_8, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.980, p=7.322e-01 normal
# difference: stat=0.976, p=7.031e-01 normal
# peakValue: stat=0.863, p=2.763e-01 normal
# PTPA: stat=0.888, p=3.493e-01 normal
# PTTA: stat=0.839, p=2.127e-01 normal
# RMS: stat=0.873, p=3.033e-01 normal
# tau: stat=0.939, p=5.246e-01 normal
# AUC: stat=0.885, p=3.403e-01 normal
#
# Experiment: tone_in_noise, Sex: female (date-averaged)
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.893, p=3.631e-01 normal
# difference: stat=0.893, p=3.631e-01 normal
# peakValue: stat=0.984, p=7.544e-01 normal
# PTPA: stat=0.982, p=7.433e-01 normal
# PTTA: stat=0.982, p=7.435e-01 normal
# RMS: stat=0.923, p=4.629e-01 normal
# tau: stat=0.781, p=7.075e-02 normal
# AUC: stat=0.820, p=1.623e-01 normal
#
# Experiment: tone_in_noise, Sex: male (date-averaged)
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.979, p=7.251e-01 normal
# difference: stat=0.985, p=7.688e-01 normal
# peakValue: stat=0.999, p=9.562e-01 normal
# PTPA: stat=0.999, p=9.570e-01 normal
# PTTA: stat=0.980, p=7.295e-01 normal
# RMS: stat=1.000, p=9.886e-01 normal
# tau: stat=0.785, p=8.011e-02 normal
# AUC: stat=0.923, p=4.619e-01 normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Test normality (Shapiro-Wilk) for each variable, averaged across dates, split by experiment, sex, and date

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']  # Use merged, not date-averaged, to allow splitting by date
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for experiment in df['experiment'].unique():
    for sex in df['sex'].unique():
        for date in df['date'].unique():
            print(f"\nExperiment: {experiment}, Sex: {sex}, Date: {date}")
            subset = df[(df['experiment'] == experiment) & (df['sex'] == sex) & (df['date'] == date)]
            for var in variables:
                vals = pd.to_numeric(subset[var], errors='coerce').dropna()
                if len(vals) > 2:
                    stat, p = shapiro(vals)
                    print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
                else:
                    print(f"{var}: Not enough data")
# Out:
# Experiment: ASR_control, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.923, p=4.633e-01 normal
# difference: stat=0.923, p=4.633e-01 normal
# peakValue: stat=0.995, p=8.648e-01 normal
# PTPA: stat=0.999, p=9.365e-01 normal
# PTTA: stat=0.984, p=7.586e-01 normal
# RMS: stat=0.969, p=6.632e-01 normal
# tau: stat=0.836, p=2.033e-01 normal
# AUC: stat=0.976, p=7.013e-01 normal
#
# Experiment: ASR_control, Sex: female, Date: June26
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.815, p=1.514e-01 normal
# difference: stat=0.841, p=2.155e-01 normal
# peakValue: stat=0.780, p=6.694e-02 normal
# PTPA: stat=0.819, p=1.600e-01 normal
# PTTA: stat=0.771, p=4.699e-02 NOT normal
# RMS: stat=0.790, p=9.199e-02 normal
# tau: stat=0.992, p=8.252e-01 normal
# AUC: stat=0.801, p=1.162e-01 normal
#
# Experiment: ASR_control, Sex: female, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.949, p=5.665e-01 normal
# difference: stat=0.972, p=6.788e-01 normal
# peakValue: stat=0.770, p=4.531e-02 NOT normal
# PTPA: stat=0.802, p=1.197e-01 normal
# PTTA: stat=0.888, p=3.491e-01 normal
# RMS: stat=0.832, p=1.944e-01 normal
# tau: stat=0.999, p=9.361e-01 normal
# AUC: stat=0.788, p=8.539e-02 normal
#
# Experiment: ASR_control, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.999, p=9.559e-01 normal
# difference: stat=0.997, p=8.956e-01 normal
# peakValue: stat=0.803, p=1.221e-01 normal
# PTPA: stat=0.816, p=1.524e-01 normal
# PTTA: stat=0.795, p=1.032e-01 normal
# RMS: stat=0.880, p=3.242e-01 normal
# tau: stat=0.969, p=6.621e-01 normal
# AUC: stat=0.785, p=7.902e-02 normal
#
# Experiment: ASR_control, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.998, p=9.152e-01 normal
# difference: stat=0.998, p=9.152e-01 normal
# peakValue: stat=0.982, p=7.404e-01 normal
# PTPA: stat=0.966, p=6.437e-01 normal
# PTTA: stat=0.989, p=8.009e-01 normal
# RMS: stat=0.905, p=4.025e-01 normal
# tau: stat=0.871, p=2.992e-01 normal
# AUC: stat=0.838, p=2.094e-01 normal
#
# Experiment: ASR_control, Sex: male, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.907, p=4.072e-01 normal
# difference: stat=0.915, p=4.335e-01 normal
# peakValue: stat=0.944, p=5.433e-01 normal
# PTPA: stat=0.995, p=8.602e-01 normal
# PTTA: stat=0.968, p=6.582e-01 normal
# RMS: stat=0.844, p=2.257e-01 normal
# tau: stat=0.769, p=4.320e-02 NOT normal
# AUC: stat=0.903, p=3.952e-01 normal
#
# Experiment: gap_depth, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.964, p=6.369e-01 normal
# peakValue: stat=0.995, p=8.606e-01 normal
# PTPA: stat=0.999, p=9.349e-01 normal
# PTTA: stat=0.999, p=9.504e-01 normal
# RMS: stat=0.954, p=5.893e-01 normal
# tau: stat=0.859, p=2.636e-01 normal
# AUC: stat=0.999, p=9.261e-01 normal
#
# Experiment: gap_depth, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.932, p=4.974e-01 normal
# difference: stat=0.932, p=4.974e-01 normal
# peakValue: stat=1.000, p=9.731e-01 normal
# PTPA: stat=1.000, p=9.604e-01 normal
# PTTA: stat=0.989, p=7.968e-01 normal
# RMS: stat=0.967, p=6.511e-01 normal
# tau: stat=0.820, p=1.625e-01 normal
# AUC: stat=0.765, p=3.414e-02 NOT normal
#
# Experiment: gap_depth, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.991, p=8.168e-01 normal
# difference: stat=0.991, p=8.168e-01 normal
# peakValue: stat=0.912, p=4.244e-01 normal
# PTPA: stat=0.910, p=4.170e-01 normal
# PTTA: stat=0.934, p=5.048e-01 normal
# RMS: stat=0.755, p=1.039e-02 NOT normal
# tau: stat=0.958, p=6.049e-01 normal
# AUC: stat=0.995, p=8.680e-01 normal
#
# Experiment: gap_depth, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.992, p=8.326e-01 normal
# PTPA: stat=1.000, p=9.621e-01 normal
# PTTA: stat=0.954, p=5.866e-01 normal
# RMS: stat=0.988, p=7.874e-01 normal
# tau: stat=0.766, p=3.522e-02 NOT normal
# AUC: stat=0.922, p=4.601e-01 normal
#
# Experiment: gap_depth, Sex: male, Date: June26
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.893, p=3.631e-01 normal
# difference: stat=0.860, p=2.665e-01 normal
# peakValue: stat=0.993, p=8.390e-01 normal
# PTPA: stat=0.989, p=7.983e-01 normal
# PTTA: stat=0.974, p=6.889e-01 normal
# RMS: stat=1.000, p=9.969e-01 normal
# tau: stat=0.997, p=8.888e-01 normal
# AUC: stat=0.985, p=7.622e-01 normal
#
# Experiment: gap_depth, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.785, p=7.966e-02 normal
# difference: stat=0.785, p=7.966e-02 normal
# peakValue: stat=0.822, p=1.673e-01 normal
# PTPA: stat=0.771, p=4.782e-02 NOT normal
# PTTA: stat=0.847, p=2.333e-01 normal
# RMS: stat=0.947, p=5.553e-01 normal
# tau: stat=0.912, p=4.258e-01 normal
# AUC: stat=0.987, p=7.784e-01 normal
#
# Experiment: tone_in_noise, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.866, p=2.855e-01 normal
# difference: stat=0.866, p=2.855e-01 normal
# peakValue: stat=0.966, p=6.437e-01 normal
# PTPA: stat=0.920, p=4.529e-01 normal
# PTTA: stat=0.873, p=3.040e-01 normal
# RMS: stat=1.000, p=9.702e-01 normal
# tau: stat=0.958, p=6.045e-01 normal
# AUC: stat=0.829, p=1.849e-01 normal
#
# Experiment: tone_in_noise, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.923, p=4.633e-01 normal
# PTPA: stat=0.923, p=4.648e-01 normal
# PTTA: stat=0.955, p=5.932e-01 normal
# RMS: stat=0.947, p=5.550e-01 normal
# tau: stat=0.942, p=5.338e-01 normal
# AUC: stat=0.827, p=1.808e-01 normal
#
# Experiment: tone_in_noise, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.885, p=3.404e-01 normal
# PTPA: stat=0.886, p=3.417e-01 normal
# PTTA: stat=0.896, p=3.725e-01 normal
# RMS: stat=0.911, p=4.209e-01 normal
# tau: stat=0.999, p=9.451e-01 normal
# AUC: stat=0.965, p=6.391e-01 normal
#
# Experiment: tone_in_noise, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.998, p=9.088e-01 normal
# PTPA: stat=0.995, p=8.593e-01 normal
# PTTA: stat=0.998, p=9.155e-01 normal
# RMS: stat=1.000, p=9.719e-01 normal
# tau: stat=0.981, p=7.341e-01 normal
# AUC: stat=0.981, p=7.363e-01 normal
#
# Experiment: tone_in_noise, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.984, p=7.563e-01 normal
# difference: stat=0.984, p=7.563e-01 normal
# peakValue: stat=0.989, p=8.027e-01 normal
# PTPA: stat=0.986, p=7.744e-01 normal
# PTTA: stat=0.947, p=5.573e-01 normal
# RMS: stat=1.000, p=9.846e-01 normal
# tau: stat=0.987, p=7.823e-01 normal
# AUC: stat=0.979, p=7.244e-01 normal
#
# Experiment: tone_in_noise, Sex: male, Date: May20
# reactionTime: stat=0.750, p=0.000e+00 NOT normal
# peakTime: stat=0.772, p=5.036e-02 normal
# difference: stat=0.810, p=1.376e-01 normal
# peakValue: stat=0.992, p=8.271e-01 normal
# PTPA: stat=0.996, p=8.854e-01 normal
# PTTA: stat=0.774, p=5.367e-02 normal
# RMS: stat=0.995, p=8.589e-01 normal
# tau: stat=0.948, p=5.586e-01 normal
# AUC: stat=0.872, p=3.000e-01 normal
#
# Experiment: gap_duration_4, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.828, p=1.832e-01 normal
# difference: stat=0.828, p=1.832e-01 normal
# peakValue: stat=0.787, p=8.476e-02 normal
# PTPA: stat=0.751, p=2.525e-03 NOT normal
# PTTA: stat=0.988, p=7.881e-01 normal
# RMS: stat=0.917, p=4.418e-01 normal
# tau: stat=0.924, p=4.651e-01 normal
# AUC: stat=0.963, p=6.287e-01 normal
#
# Experiment: gap_duration_4, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.992, p=8.264e-01 normal
# difference: stat=0.992, p=8.264e-01 normal
# peakValue: stat=0.795, p=1.033e-01 normal
# PTPA: stat=0.883, p=3.346e-01 normal
# PTTA: stat=0.906, p=4.033e-01 normal
# RMS: stat=0.907, p=4.073e-01 normal
# tau: stat=0.784, p=7.800e-02 normal
# AUC: stat=0.988, p=7.893e-01 normal
#
# Experiment: gap_duration_4, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.832, p=1.939e-01 normal
# difference: stat=0.832, p=1.939e-01 normal
# peakValue: stat=0.836, p=2.041e-01 normal
# PTPA: stat=0.786, p=8.252e-02 normal
# PTTA: stat=0.806, p=1.289e-01 normal
# RMS: stat=0.843, p=2.224e-01 normal
# tau: stat=0.982, p=7.465e-01 normal
# AUC: stat=0.890, p=3.550e-01 normal
#
# Experiment: gap_duration_4, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.991, p=8.168e-01 normal
# difference: stat=0.840, p=2.139e-01 normal
# peakValue: stat=0.900, p=3.851e-01 normal
# PTPA: stat=0.919, p=4.478e-01 normal
# PTTA: stat=0.995, p=8.640e-01 normal
# RMS: stat=0.802, p=1.185e-01 normal
# tau: stat=0.916, p=4.384e-01 normal
# AUC: stat=1.000, p=9.968e-01 normal
#
# Experiment: gap_duration_4, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.855, p=2.530e-01 normal
# difference: stat=0.855, p=2.530e-01 normal
# peakValue: stat=0.891, p=3.578e-01 normal
# PTPA: stat=0.846, p=2.306e-01 normal
# PTTA: stat=0.968, p=6.553e-01 normal
# RMS: stat=0.861, p=2.715e-01 normal
# tau: stat=1.000, p=9.775e-01 normal
# AUC: stat=0.772, p=4.945e-02 NOT normal
#
# Experiment: gap_duration_4, Sex: male, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.779, p=6.484e-02 normal
# difference: stat=0.780, p=6.748e-02 normal
# peakValue: stat=0.754, p=9.934e-03 NOT normal
# PTPA: stat=0.794, p=9.919e-02 normal
# PTTA: stat=0.867, p=2.876e-01 normal
# RMS: stat=0.862, p=2.720e-01 normal
# tau: stat=0.857, p=2.596e-01 normal
# AUC: stat=0.807, p=1.321e-01 normal
#
# Experiment: gap_duration_8, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.842, p=2.196e-01 normal
# difference: stat=0.842, p=2.196e-01 normal
# peakValue: stat=0.874, p=3.061e-01 normal
# PTPA: stat=0.948, p=5.606e-01 normal
# PTTA: stat=0.982, p=7.408e-01 normal
# RMS: stat=0.782, p=7.316e-02 normal
# tau: stat=0.999, p=9.291e-01 normal
# AUC: stat=0.871, p=2.978e-01 normal
#
# Experiment: gap_duration_8, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.996, p=8.777e-01 normal
# difference: stat=0.996, p=8.777e-01 normal
# peakValue: stat=0.945, p=5.475e-01 normal
# PTPA: stat=0.966, p=6.450e-01 normal
# PTTA: stat=0.980, p=7.282e-01 normal
# RMS: stat=0.843, p=2.210e-01 normal
# tau: stat=0.988, p=7.931e-01 normal
# AUC: stat=0.789, p=8.834e-02 normal
#
# Experiment: gap_duration_8, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.923, p=4.633e-01 normal
# difference: stat=0.923, p=4.633e-01 normal
# peakValue: stat=0.999, p=9.303e-01 normal
# PTPA: stat=0.990, p=8.085e-01 normal
# PTTA: stat=0.963, p=6.322e-01 normal
# RMS: stat=0.989, p=7.999e-01 normal
# tau: stat=0.884, p=3.356e-01 normal
# AUC: stat=0.961, p=6.179e-01 normal
#
# Experiment: gap_duration_8, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.814, p=1.478e-01 normal
# difference: stat=0.814, p=1.478e-01 normal
# peakValue: stat=0.969, p=6.621e-01 normal
# PTPA: stat=0.999, p=9.409e-01 normal
# PTTA: stat=0.997, p=8.900e-01 normal
# RMS: stat=0.861, p=2.709e-01 normal
# tau: stat=0.855, p=2.548e-01 normal
# AUC: stat=0.939, p=5.245e-01 normal
#
# Experiment: gap_duration_8, Sex: male, Date: June26
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.923, p=4.633e-01 normal
# difference: stat=0.947, p=5.542e-01 normal
# peakValue: stat=0.807, p=1.316e-01 normal
# PTPA: stat=0.780, p=6.828e-02 normal
# PTTA: stat=0.752, p=4.579e-03 NOT normal
# RMS: stat=0.861, p=2.713e-01 normal
# tau: stat=0.787, p=8.432e-02 normal
# AUC: stat=0.994, p=8.514e-01 normal
#
# Experiment: gap_duration_8, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.964, p=6.369e-01 normal
# peakValue: stat=0.940, p=5.257e-01 normal
# PTPA: stat=0.849, p=2.383e-01 normal
# PTTA: stat=0.757, p=1.572e-02 NOT normal
# RMS: stat=0.998, p=9.160e-01 normal
# tau: stat=0.784, p=7.738e-02 normal
# AUC: stat=0.996, p=8.838e-01 normal
#
# Experiment: gap_duration_10, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.964, p=6.369e-01 normal
# peakValue: stat=1.000, p=9.792e-01 normal
# PTPA: stat=0.990, p=8.097e-01 normal
# PTTA: stat=0.919, p=4.484e-01 normal
# RMS: stat=0.884, p=3.354e-01 normal
# tau: stat=0.946, p=5.511e-01 normal
# AUC: stat=0.996, p=8.772e-01 normal
#
# Experiment: gap_duration_10, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.837, p=2.059e-01 normal
# difference: stat=0.837, p=2.059e-01 normal
# peakValue: stat=0.774, p=5.334e-02 normal
# PTPA: stat=0.834, p=1.998e-01 normal
# PTTA: stat=0.907, p=4.084e-01 normal
# RMS: stat=0.811, p=1.421e-01 normal
# tau: stat=0.978, p=7.135e-01 normal
# AUC: stat=0.893, p=3.646e-01 normal
#
# Experiment: gap_duration_10, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.958, p=6.048e-01 normal
# difference: stat=0.958, p=6.048e-01 normal
# peakValue: stat=0.855, p=2.545e-01 normal
# PTPA: stat=0.850, p=2.405e-01 normal
# PTTA: stat=0.950, p=5.672e-01 normal
# RMS: stat=0.931, p=4.941e-01 normal
# tau: stat=0.937, p=5.158e-01 normal
# AUC: stat=0.886, p=3.431e-01 normal
#
# Experiment: gap_duration_10, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.940, p=5.286e-01 normal
# PTPA: stat=0.924, p=4.675e-01 normal
# PTTA: stat=0.903, p=3.947e-01 normal
# RMS: stat=0.839, p=2.127e-01 normal
# tau: stat=0.896, p=3.723e-01 normal
# AUC: stat=0.913, p=4.293e-01 normal
#
# Experiment: gap_duration_10, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.821, p=1.666e-01 normal
# difference: stat=0.821, p=1.666e-01 normal
# peakValue: stat=0.964, p=6.359e-01 normal
# PTPA: stat=0.932, p=4.953e-01 normal
# PTTA: stat=0.945, p=5.481e-01 normal
# RMS: stat=0.934, p=5.029e-01 normal
# tau: stat=0.778, p=6.362e-02 normal
# AUC: stat=0.849, p=2.378e-01 normal
#
# Experiment: gap_duration_10, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=0.000e+00 NOT normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=0.792, p=9.444e-02 normal
# PTPA: stat=0.992, p=8.339e-01 normal
# PTTA: stat=0.914, p=4.330e-01 normal
# RMS: stat=0.994, p=8.563e-01 normal
# tau: stat=0.801, p=1.177e-01 normal
# AUC: stat=0.764, p=3.205e-02 NOT normal
#
# Experiment: gap_duration_20, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.898, p=3.796e-01 normal
# difference: stat=0.898, p=3.796e-01 normal
# peakValue: stat=0.905, p=4.003e-01 normal
# PTPA: stat=0.891, p=3.587e-01 normal
# PTTA: stat=0.922, p=4.601e-01 normal
# RMS: stat=0.756, p=1.344e-02 NOT normal
# tau: stat=0.998, p=9.121e-01 normal
# AUC: stat=0.933, p=5.011e-01 normal
#
# Experiment: gap_duration_20, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.932, p=4.952e-01 normal
# difference: stat=0.932, p=4.952e-01 normal
# peakValue: stat=0.976, p=7.055e-01 normal
# PTPA: stat=0.983, p=7.499e-01 normal
# PTTA: stat=0.962, p=6.241e-01 normal
# RMS: stat=0.998, p=9.166e-01 normal
# tau: stat=0.908, p=4.102e-01 normal
# AUC: stat=0.984, p=7.606e-01 normal
#
# Experiment: gap_duration_20, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=0.000e+00 NOT normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=0.994, p=8.482e-01 normal
# PTPA: stat=0.992, p=8.276e-01 normal
# PTTA: stat=0.944, p=5.422e-01 normal
# RMS: stat=1.000, p=9.965e-01 normal
# tau: stat=0.982, p=7.421e-01 normal
# AUC: stat=1.000, p=9.856e-01 normal
#
# Experiment: gap_duration_20, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.916, p=4.391e-01 normal
# difference: stat=0.916, p=4.391e-01 normal
# peakValue: stat=0.882, p=3.289e-01 normal
# PTPA: stat=0.783, p=7.481e-02 normal
# PTTA: stat=0.958, p=6.047e-01 normal
# RMS: stat=0.980, p=7.293e-01 normal
# tau: stat=0.955, p=5.899e-01 normal
# AUC: stat=0.997, p=8.929e-01 normal
#
# Experiment: gap_duration_20, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.888, p=3.480e-01 normal
# difference: stat=0.888, p=3.480e-01 normal
# peakValue: stat=0.968, p=6.582e-01 normal
# PTPA: stat=0.952, p=5.791e-01 normal
# PTTA: stat=0.946, p=5.504e-01 normal
# RMS: stat=0.960, p=6.149e-01 normal
# tau: stat=0.959, p=6.106e-01 normal
# AUC: stat=0.768, p=3.957e-02 NOT normal
#
# Experiment: gap_duration_20, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.862, p=2.738e-01 normal
# difference: stat=0.862, p=2.738e-01 normal
# peakValue: stat=0.832, p=1.939e-01 normal
# PTPA: stat=0.905, p=4.007e-01 normal
# PTTA: stat=0.829, p=1.865e-01 normal
# RMS: stat=0.826, p=1.780e-01 normal
# tau: stat=0.860, p=2.675e-01 normal
# AUC: stat=0.982, p=7.457e-01 normal
#
# Experiment: gap_duration_50, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.855, p=2.530e-01 normal
# difference: stat=0.855, p=2.530e-01 normal
# peakValue: stat=0.923, p=4.633e-01 normal
# PTPA: stat=0.951, p=5.730e-01 normal
# PTTA: stat=0.903, p=3.953e-01 normal
# RMS: stat=0.799, p=1.118e-01 normal
# tau: stat=0.998, p=9.134e-01 normal
# AUC: stat=0.961, p=6.228e-01 normal
#
# Experiment: gap_duration_50, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.887, p=3.444e-01 normal
# difference: stat=0.887, p=3.444e-01 normal
# peakValue: stat=0.833, p=1.962e-01 normal
# PTPA: stat=0.857, p=2.590e-01 normal
# PTTA: stat=0.811, p=1.416e-01 normal
# RMS: stat=0.826, p=1.770e-01 normal
# tau: stat=0.972, p=6.817e-01 normal
# AUC: stat=0.753, p=7.647e-03 NOT normal
#
# Experiment: gap_duration_50, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.902, p=3.914e-01 normal
# difference: stat=0.902, p=3.914e-01 normal
# peakValue: stat=0.972, p=6.773e-01 normal
# PTPA: stat=0.961, p=6.188e-01 normal
# PTTA: stat=0.935, p=5.090e-01 normal
# RMS: stat=0.984, p=7.548e-01 normal
# tau: stat=0.998, p=9.087e-01 normal
# AUC: stat=0.989, p=7.959e-01 normal
#
# Experiment: gap_duration_50, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.987, p=7.804e-01 normal
# difference: stat=0.987, p=7.804e-01 normal
# peakValue: stat=0.793, p=9.817e-02 normal
# PTPA: stat=0.823, p=1.709e-01 normal
# PTTA: stat=0.984, p=7.543e-01 normal
# RMS: stat=0.880, p=3.258e-01 normal
# tau: stat=0.996, p=8.755e-01 normal
# AUC: stat=0.803, p=1.220e-01 normal
#
# Experiment: gap_duration_50, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.932, p=4.974e-01 normal
# difference: stat=0.932, p=4.974e-01 normal
# peakValue: stat=0.966, p=6.448e-01 normal
# PTPA: stat=0.949, p=5.635e-01 normal
# PTTA: stat=0.948, p=5.590e-01 normal
# RMS: stat=0.933, p=5.013e-01 normal
# tau: stat=0.868, p=2.906e-01 normal
# AUC: stat=0.822, p=1.686e-01 normal
#
# Experiment: gap_duration_50, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.907, p=4.072e-01 normal
# difference: stat=0.907, p=4.072e-01 normal
# peakValue: stat=0.901, p=3.888e-01 normal
# PTPA: stat=0.999, p=9.439e-01 normal
# PTTA: stat=0.957, p=6.007e-01 normal
# RMS: stat=0.754, p=7.947e-03 NOT normal
# tau: stat=0.890, p=3.549e-01 normal
# AUC: stat=0.912, p=4.265e-01 normal
#
# Experiment: offset_PPI_4, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.993, p=8.428e-01 normal
# difference: stat=0.993, p=8.428e-01 normal
# peakValue: stat=0.928, p=4.809e-01 normal
# PTPA: stat=0.950, p=5.696e-01 normal
# PTTA: stat=0.965, p=6.389e-01 normal
# RMS: stat=0.816, p=1.536e-01 normal
# tau: stat=0.774, p=5.364e-02 normal
# AUC: stat=0.783, p=7.533e-02 normal
#
# Experiment: offset_PPI_4, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.842, p=2.196e-01 normal
# difference: stat=0.842, p=2.196e-01 normal
# peakValue: stat=0.829, p=1.861e-01 normal
# PTPA: stat=0.858, p=2.623e-01 normal
# PTTA: stat=0.826, p=1.776e-01 normal
# RMS: stat=0.774, p=5.334e-02 normal
# tau: stat=0.838, p=2.077e-01 normal
# AUC: stat=0.872, p=3.025e-01 normal
#
# Experiment: offset_PPI_4, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.964, p=6.369e-01 normal
# peakValue: stat=0.989, p=7.993e-01 normal
# PTPA: stat=0.977, p=7.098e-01 normal
# PTTA: stat=0.976, p=7.032e-01 normal
# RMS: stat=0.986, p=7.720e-01 normal
# tau: stat=0.900, p=3.840e-01 normal
# AUC: stat=0.869, p=2.925e-01 normal
#
# Experiment: offset_PPI_4, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.987, p=7.804e-01 normal
# difference: stat=0.987, p=7.804e-01 normal
# peakValue: stat=0.941, p=5.315e-01 normal
# PTPA: stat=0.957, p=5.990e-01 normal
# PTTA: stat=0.912, p=4.248e-01 normal
# RMS: stat=0.969, p=6.641e-01 normal
# tau: stat=0.982, p=7.440e-01 normal
# AUC: stat=0.786, p=8.101e-02 normal
#
# Experiment: offset_PPI_4, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=0.000e+00 NOT normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=1.000, p=9.685e-01 normal
# PTPA: stat=1.000, p=9.981e-01 normal
# PTTA: stat=1.000, p=9.742e-01 normal
# RMS: stat=0.997, p=8.875e-01 normal
# tau: stat=0.914, p=4.311e-01 normal
# AUC: stat=0.976, p=7.042e-01 normal
#
# Experiment: offset_PPI_4, Sex: male, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.938, p=5.203e-01 normal
# difference: stat=0.885, p=3.386e-01 normal
# peakValue: stat=0.989, p=8.019e-01 normal
# PTPA: stat=0.995, p=8.699e-01 normal
# PTTA: stat=0.998, p=9.129e-01 normal
# RMS: stat=0.996, p=8.869e-01 normal
# tau: stat=0.908, p=4.113e-01 normal
# AUC: stat=0.839, p=2.112e-01 normal
#
# Experiment: offset_PPI_6, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.768, p=3.922e-02 NOT normal
# difference: stat=0.768, p=3.922e-02 NOT normal
# peakValue: stat=0.996, p=8.777e-01 normal
# PTPA: stat=0.999, p=9.370e-01 normal
# PTTA: stat=0.974, p=6.904e-01 normal
# RMS: stat=0.944, p=5.424e-01 normal
# tau: stat=0.976, p=7.014e-01 normal
# AUC: stat=0.807, p=1.320e-01 normal
#
# Experiment: offset_PPI_6, Sex: female, Date: June26
# reactionTime: stat=0.750, p=0.000e+00 NOT normal
# peakTime: stat=0.993, p=8.428e-01 normal
# difference: stat=0.987, p=7.804e-01 normal
# peakValue: stat=1.000, p=9.602e-01 normal
# PTPA: stat=0.996, p=8.809e-01 normal
# PTTA: stat=0.954, p=5.877e-01 normal
# RMS: stat=0.998, p=9.194e-01 normal
# tau: stat=0.794, p=9.935e-02 normal
# AUC: stat=0.959, p=6.113e-01 normal
#
# Experiment: offset_PPI_6, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.976, p=7.036e-01 normal
# PTPA: stat=0.979, p=7.214e-01 normal
# PTTA: stat=0.979, p=7.253e-01 normal
# RMS: stat=0.948, p=5.604e-01 normal
# tau: stat=0.962, p=6.250e-01 normal
# AUC: stat=0.841, p=2.170e-01 normal
#
# Experiment: offset_PPI_6, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.917, p=4.430e-01 normal
# difference: stat=0.929, p=4.855e-01 normal
# peakValue: stat=0.921, p=4.570e-01 normal
# PTPA: stat=0.857, p=2.584e-01 normal
# PTTA: stat=0.908, p=4.103e-01 normal
# RMS: stat=0.896, p=3.719e-01 normal
# tau: stat=0.887, p=3.462e-01 normal
# AUC: stat=0.996, p=8.768e-01 normal
#
# Experiment: offset_PPI_6, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.908, p=4.128e-01 normal
# difference: stat=0.908, p=4.128e-01 normal
# peakValue: stat=0.999, p=9.560e-01 normal
# PTPA: stat=0.999, p=9.361e-01 normal
# PTTA: stat=1.000, p=9.917e-01 normal
# RMS: stat=0.991, p=8.190e-01 normal
# tau: stat=0.936, p=5.096e-01 normal
# AUC: stat=0.988, p=7.945e-01 normal
#
# Experiment: offset_PPI_6, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.902, p=3.914e-01 normal
# difference: stat=0.902, p=3.914e-01 normal
# peakValue: stat=0.763, p=2.927e-02 NOT normal
# PTPA: stat=0.808, p=1.343e-01 normal
# PTTA: stat=0.907, p=4.085e-01 normal
# RMS: stat=0.884, p=3.364e-01 normal
# tau: stat=0.859, p=2.652e-01 normal
# AUC: stat=0.802, p=1.191e-01 normal
#
# Experiment: offset_PPI_8, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=0.000e+00 NOT normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=0.893, p=3.631e-01 normal
# PTPA: stat=0.908, p=4.114e-01 normal
# PTTA: stat=0.853, p=2.496e-01 normal
# RMS: stat=0.799, p=1.114e-01 normal
# tau: stat=0.994, p=8.501e-01 normal
# AUC: stat=0.852, p=2.453e-01 normal
#
# Experiment: offset_PPI_8, Sex: female, Date: June26
# reactionTime: stat=0.750, p=0.000e+00 NOT normal
# peakTime: stat=0.814, p=1.478e-01 normal
# difference: stat=0.771, p=4.658e-02 NOT normal
# peakValue: stat=0.805, p=1.276e-01 normal
# PTPA: stat=0.762, p=2.584e-02 NOT normal
# PTTA: stat=0.803, p=1.214e-01 normal
# RMS: stat=0.839, p=2.115e-01 normal
# tau: stat=0.944, p=5.418e-01 normal
# AUC: stat=0.767, p=3.699e-02 NOT normal
#
# Experiment: offset_PPI_8, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.968, p=6.591e-01 normal
# PTPA: stat=0.978, p=7.133e-01 normal
# PTTA: stat=0.988, p=7.879e-01 normal
# RMS: stat=0.958, p=6.053e-01 normal
# tau: stat=0.945, p=5.488e-01 normal
# AUC: stat=0.914, p=4.301e-01 normal
#
# Experiment: offset_PPI_8, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.996, p=8.861e-01 normal
# difference: stat=1.000, p=9.825e-01 normal
# peakValue: stat=0.996, p=8.777e-01 normal
# PTPA: stat=0.979, p=7.252e-01 normal
# PTTA: stat=0.865, p=2.804e-01 normal
# RMS: stat=0.984, p=7.549e-01 normal
# tau: stat=0.751, p=3.101e-03 NOT normal
# AUC: stat=0.971, p=6.710e-01 normal
#
# Experiment: offset_PPI_8, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.981, p=7.391e-01 normal
# difference: stat=0.981, p=7.391e-01 normal
# peakValue: stat=0.981, p=7.350e-01 normal
# PTPA: stat=0.961, p=6.214e-01 normal
# PTTA: stat=0.953, p=5.836e-01 normal
# RMS: stat=0.990, p=8.135e-01 normal
# tau: stat=0.832, p=1.938e-01 normal
# AUC: stat=0.973, p=6.875e-01 normal
#
# Experiment: offset_PPI_8, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.995, p=8.689e-01 normal
# difference: stat=0.995, p=8.689e-01 normal
# peakValue: stat=0.971, p=6.714e-01 normal
# PTPA: stat=0.970, p=6.659e-01 normal
# PTTA: stat=0.980, p=7.301e-01 normal
# RMS: stat=0.872, p=3.014e-01 normal
# tau: stat=0.899, p=3.831e-01 normal
# AUC: stat=0.970, p=6.690e-01 normal
#
# Experiment: offset_PPI_10, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.842, p=2.196e-01 normal
# difference: stat=0.842, p=2.196e-01 normal
# peakValue: stat=0.887, p=3.444e-01 normal
# PTPA: stat=0.920, p=4.527e-01 normal
# PTTA: stat=0.987, p=7.825e-01 normal
# RMS: stat=0.947, p=5.554e-01 normal
# tau: stat=0.947, p=5.554e-01 normal
# AUC: stat=0.994, p=8.481e-01 normal
#
# Experiment: offset_PPI_10, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.964, p=6.369e-01 normal
# peakValue: stat=1.000, p=9.613e-01 normal
# PTPA: stat=0.999, p=9.323e-01 normal
# PTTA: stat=0.954, p=5.852e-01 normal
# RMS: stat=1.000, p=9.962e-01 normal
# tau: stat=0.816, p=1.530e-01 normal
# AUC: stat=0.988, p=7.878e-01 normal
#
# Experiment: offset_PPI_10, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=1.000, p=1.000e+00 normal
# difference: stat=1.000, p=1.000e+00 normal
# peakValue: stat=0.834, p=1.981e-01 normal
# PTPA: stat=0.829, p=1.852e-01 normal
# PTTA: stat=0.771, p=4.729e-02 NOT normal
# RMS: stat=0.800, p=1.141e-01 normal
# tau: stat=0.828, p=1.833e-01 normal
# AUC: stat=0.784, p=7.602e-02 normal
#
# Experiment: offset_PPI_10, Sex: male, Date: April16
# reactionTime: stat=0.750, p=0.000e+00 NOT normal
# peakTime: stat=0.942, p=5.367e-01 normal
# difference: stat=0.927, p=4.778e-01 normal
# peakValue: stat=0.900, p=3.845e-01 normal
# PTPA: stat=0.900, p=3.861e-01 normal
# PTTA: stat=0.941, p=5.306e-01 normal
# RMS: stat=0.912, p=4.254e-01 normal
# tau: stat=0.999, p=9.457e-01 normal
# AUC: stat=0.834, p=1.978e-01 normal
#
# Experiment: offset_PPI_10, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.971, p=6.725e-01 normal
# difference: stat=0.971, p=6.725e-01 normal
# peakValue: stat=0.842, p=2.183e-01 normal
# PTPA: stat=0.887, p=3.452e-01 normal
# PTTA: stat=0.802, p=1.182e-01 normal
# RMS: stat=0.846, p=2.311e-01 normal
# tau: stat=1.000, p=9.907e-01 normal
# AUC: stat=0.908, p=4.131e-01 normal
#
# Experiment: offset_PPI_10, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.851, p=2.424e-01 normal
# difference: stat=0.851, p=2.424e-01 normal
# peakValue: stat=0.818, p=1.583e-01 normal
# PTPA: stat=0.865, p=2.821e-01 normal
# PTTA: stat=0.993, p=8.348e-01 normal
# RMS: stat=0.910, p=4.175e-01 normal
# tau: stat=0.984, p=7.583e-01 normal
# AUC: stat=0.957, p=6.009e-01 normal
#
# Experiment: offset_PPI_12, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.958, p=6.068e-01 normal
# PTPA: stat=0.939, p=5.238e-01 normal
# PTTA: stat=0.907, p=4.084e-01 normal
# RMS: stat=0.953, p=5.828e-01 normal
# tau: stat=0.964, p=6.356e-01 normal
# AUC: stat=0.920, p=4.535e-01 normal
#
# Experiment: offset_PPI_12, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.958, p=6.048e-01 normal
# difference: stat=0.958, p=6.048e-01 normal
# peakValue: stat=0.789, p=8.934e-02 normal
# PTPA: stat=0.791, p=9.208e-02 normal
# PTTA: stat=0.847, p=2.323e-01 normal
# RMS: stat=0.864, p=2.783e-01 normal
# tau: stat=0.887, p=3.467e-01 normal
# AUC: stat=0.942, p=5.338e-01 normal
#
# Experiment: offset_PPI_12, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=0.000e+00 NOT normal
# difference: stat=0.750, p=0.000e+00 NOT normal
# peakValue: stat=0.869, p=2.917e-01 normal
# PTPA: stat=0.864, p=2.797e-01 normal
# PTTA: stat=0.919, p=4.478e-01 normal
# RMS: stat=0.809, p=1.373e-01 normal
# tau: stat=0.761, p=2.502e-02 NOT normal
# AUC: stat=0.866, p=2.833e-01 normal
#
# Experiment: offset_PPI_12, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=1.000, p=9.676e-01 normal
# difference: stat=1.000, p=9.676e-01 normal
# peakValue: stat=0.982, p=7.421e-01 normal
# PTPA: stat=0.986, p=7.716e-01 normal
# PTTA: stat=0.999, p=9.570e-01 normal
# RMS: stat=0.998, p=9.085e-01 normal
# tau: stat=0.993, p=8.458e-01 normal
# AUC: stat=0.961, p=6.212e-01 normal
#
# Experiment: offset_PPI_12, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.862, p=2.738e-01 normal
# difference: stat=0.862, p=2.738e-01 normal
# peakValue: stat=0.777, p=6.086e-02 normal
# PTPA: stat=0.793, p=9.758e-02 normal
# PTTA: stat=0.820, p=1.641e-01 normal
# RMS: stat=0.767, p=3.783e-02 NOT normal
# tau: stat=0.801, p=1.166e-01 normal
# AUC: stat=0.900, p=3.868e-01 normal
#
# Experiment: offset_PPI_12, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.874, p=3.069e-01 normal
# difference: stat=0.874, p=3.069e-01 normal
# peakValue: stat=0.755, p=1.085e-02 NOT normal
# PTPA: stat=0.782, p=7.127e-02 normal
# PTTA: stat=0.841, p=2.157e-01 normal
# RMS: stat=0.831, p=1.905e-01 normal
# tau: stat=0.937, p=5.162e-01 normal
# AUC: stat=0.999, p=9.521e-01 normal
#
# Experiment: offset_PPI_14, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=1.000, p=1.000e+00 normal
# difference: stat=1.000, p=1.000e+00 normal
# peakValue: stat=0.819, p=1.602e-01 normal
# PTPA: stat=0.872, p=3.003e-01 normal
# PTTA: stat=0.934, p=5.031e-01 normal
# RMS: stat=0.831, p=1.921e-01 normal
# tau: stat=0.985, p=7.676e-01 normal
# AUC: stat=0.933, p=5.004e-01 normal
#
# Experiment: offset_PPI_14, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.966, p=6.447e-01 normal
# PTPA: stat=0.961, p=6.202e-01 normal
# PTTA: stat=0.922, p=4.609e-01 normal
# RMS: stat=0.908, p=4.104e-01 normal
# tau: stat=0.957, p=6.006e-01 normal
# AUC: stat=0.885, p=3.401e-01 normal
#
# Experiment: offset_PPI_14, Sex: female, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.858, p=2.609e-01 normal
# PTPA: stat=0.831, p=1.919e-01 normal
# PTTA: stat=0.877, p=3.158e-01 normal
# RMS: stat=0.928, p=4.814e-01 normal
# tau: stat=0.982, p=7.438e-01 normal
# AUC: stat=0.808, p=1.340e-01 normal
#
# Experiment: offset_PPI_14, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.958, p=6.048e-01 normal
# difference: stat=0.958, p=6.048e-01 normal
# peakValue: stat=0.868, p=2.908e-01 normal
# PTPA: stat=0.831, p=1.905e-01 normal
# PTTA: stat=0.863, p=2.761e-01 normal
# RMS: stat=0.997, p=9.013e-01 normal
# tau: stat=0.912, p=4.255e-01 normal
# AUC: stat=0.942, p=5.362e-01 normal
#
# Experiment: offset_PPI_14, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.984, p=7.563e-01 normal
# difference: stat=0.984, p=7.563e-01 normal
# peakValue: stat=0.776, p=5.905e-02 normal
# PTPA: stat=0.772, p=4.990e-02 NOT normal
# PTTA: stat=0.812, p=1.440e-01 normal
# RMS: stat=0.759, p=1.940e-02 NOT normal
# tau: stat=0.947, p=5.561e-01 normal
# AUC: stat=0.817, p=1.558e-01 normal
#
# Experiment: offset_PPI_14, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.998, p=9.213e-01 normal
# difference: stat=0.998, p=9.213e-01 normal
# peakValue: stat=0.768, p=4.131e-02 NOT normal
# PTPA: stat=0.788, p=8.730e-02 normal
# PTTA: stat=0.826, p=1.771e-01 normal
# RMS: stat=0.869, p=2.938e-01 normal
# tau: stat=0.770, p=4.505e-02 NOT normal
# AUC: stat=0.993, p=8.370e-01 normal
#
# Experiment: offset_PPI_16, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.764, p=3.211e-02 NOT normal
# difference: stat=0.764, p=3.211e-02 NOT normal
# peakValue: stat=0.877, p=3.143e-01 normal
# PTPA: stat=0.890, p=3.537e-01 normal
# PTTA: stat=0.911, p=4.216e-01 normal
# RMS: stat=0.881, p=3.287e-01 normal
# tau: stat=0.965, p=6.401e-01 normal
# AUC: stat=0.978, p=7.169e-01 normal
#
# Experiment: offset_PPI_16, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.928, p=4.822e-01 normal
# difference: stat=0.928, p=4.822e-01 normal
# peakValue: stat=0.811, p=1.408e-01 normal
# PTPA: stat=0.768, p=4.071e-02 NOT normal
# PTTA: stat=0.819, p=1.615e-01 normal
# RMS: stat=0.954, p=5.850e-01 normal
# tau: stat=0.750, p=5.109e-04 NOT normal
# AUC: stat=0.959, p=6.102e-01 normal
#
# Experiment: offset_PPI_16, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.832, p=1.939e-01 normal
# difference: stat=0.832, p=1.939e-01 normal
# peakValue: stat=0.950, p=5.684e-01 normal
# PTPA: stat=0.957, p=5.998e-01 normal
# PTTA: stat=0.951, p=5.726e-01 normal
# RMS: stat=0.943, p=5.399e-01 normal
# tau: stat=0.946, p=5.533e-01 normal
# AUC: stat=0.933, p=5.006e-01 normal
#
# Experiment: offset_PPI_16, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.807, p=1.321e-01 normal
# difference: stat=0.807, p=1.321e-01 normal
# peakValue: stat=0.996, p=8.777e-01 normal
# PTPA: stat=0.999, p=9.336e-01 normal
# PTTA: stat=0.999, p=9.470e-01 normal
# RMS: stat=0.999, p=9.334e-01 normal
# tau: stat=0.992, p=8.261e-01 normal
# AUC: stat=0.902, p=3.913e-01 normal
#
# Experiment: offset_PPI_16, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.832, p=1.939e-01 normal
# difference: stat=0.832, p=1.939e-01 normal
# peakValue: stat=0.931, p=4.927e-01 normal
# PTPA: stat=0.928, p=4.817e-01 normal
# PTTA: stat=0.981, p=7.361e-01 normal
# RMS: stat=0.892, p=3.613e-01 normal
# tau: stat=0.806, p=1.282e-01 normal
# AUC: stat=0.804, p=1.251e-01 normal
#
# Experiment: offset_PPI_16, Sex: male, Date: May20
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.800, p=1.139e-01 normal
# difference: stat=0.893, p=3.631e-01 normal
# peakValue: stat=0.975, p=6.955e-01 normal
# PTPA: stat=0.982, p=7.446e-01 normal
# PTTA: stat=0.988, p=7.865e-01 normal
# RMS: stat=0.952, p=5.783e-01 normal
# tau: stat=0.750, p=9.176e-06 NOT normal
# AUC: stat=0.945, p=5.465e-01 normal
#
# Experiment: offset_PPI_18, Sex: female, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.964, p=6.369e-01 normal
# difference: stat=0.993, p=8.428e-01 normal
# peakValue: stat=0.986, p=7.722e-01 normal
# PTPA: stat=0.994, p=8.532e-01 normal
# PTTA: stat=0.962, p=6.244e-01 normal
# RMS: stat=1.000, p=9.613e-01 normal
# tau: stat=0.909, p=4.141e-01 normal
# AUC: stat=0.992, p=8.340e-01 normal
#
# Experiment: offset_PPI_18, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.986, p=7.703e-01 normal
# difference: stat=0.986, p=7.703e-01 normal
# peakValue: stat=0.821, p=1.658e-01 normal
# PTPA: stat=0.806, p=1.286e-01 normal
# PTTA: stat=0.826, p=1.788e-01 normal
# RMS: stat=0.936, p=5.096e-01 normal
# tau: stat=0.924, p=4.656e-01 normal
# AUC: stat=0.964, p=6.329e-01 normal
#
# Experiment: offset_PPI_18, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.942, p=5.367e-01 normal
# difference: stat=0.942, p=5.367e-01 normal
# peakValue: stat=0.833, p=1.948e-01 normal
# PTPA: stat=0.848, p=2.360e-01 normal
# PTTA: stat=0.926, p=4.749e-01 normal
# RMS: stat=0.766, p=3.496e-02 NOT normal
# tau: stat=0.999, p=9.280e-01 normal
# AUC: stat=0.892, p=3.590e-01 normal
#
# Experiment: offset_PPI_18, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.784, p=7.689e-02 normal
# difference: stat=0.803, p=1.223e-01 normal
# peakValue: stat=1.000, p=9.825e-01 normal
# PTPA: stat=0.983, p=7.529e-01 normal
# PTTA: stat=0.783, p=7.381e-02 normal
# RMS: stat=0.997, p=8.939e-01 normal
# tau: stat=0.960, p=6.150e-01 normal
# AUC: stat=0.947, p=5.558e-01 normal
#
# Experiment: offset_PPI_18, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.992, p=8.299e-01 normal
# difference: stat=0.992, p=8.299e-01 normal
# peakValue: stat=0.961, p=6.224e-01 normal
# PTPA: stat=0.936, p=5.130e-01 normal
# PTTA: stat=0.957, p=6.016e-01 normal
# RMS: stat=0.941, p=5.312e-01 normal
# tau: stat=0.997, p=8.872e-01 normal
# AUC: stat=0.761, p=2.511e-02 NOT normal
#
# Experiment: offset_PPI_18, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.768, p=3.985e-02 NOT normal
# difference: stat=0.768, p=3.985e-02 NOT normal
# peakValue: stat=0.813, p=1.452e-01 normal
# PTPA: stat=0.778, p=6.328e-02 normal
# PTTA: stat=0.923, p=4.636e-01 normal
# RMS: stat=0.895, p=3.695e-01 normal
# tau: stat=0.756, p=1.390e-02 NOT normal
# AUC: stat=0.821, p=1.652e-01 normal
#
# Experiment: offset_PPI_20, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.750, p=7.772e-16 NOT normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.954, p=5.859e-01 normal
# PTPA: stat=0.998, p=9.124e-01 normal
# PTTA: stat=0.998, p=9.064e-01 normal
# RMS: stat=0.942, p=5.338e-01 normal
# tau: stat=0.790, p=9.178e-02 normal
# AUC: stat=0.949, p=5.652e-01 normal
#
# Experiment: offset_PPI_20, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.910, p=4.173e-01 normal
# difference: stat=0.910, p=4.173e-01 normal
# peakValue: stat=0.990, p=8.134e-01 normal
# PTPA: stat=0.990, p=8.129e-01 normal
# PTTA: stat=0.995, p=8.697e-01 normal
# RMS: stat=0.962, p=6.235e-01 normal
# tau: stat=1.000, p=9.629e-01 normal
# AUC: stat=0.996, p=8.799e-01 normal
#
# Experiment: offset_PPI_20, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.997, p=8.967e-01 normal
# difference: stat=0.997, p=8.967e-01 normal
# peakValue: stat=0.999, p=9.424e-01 normal
# PTPA: stat=1.000, p=9.884e-01 normal
# PTTA: stat=0.999, p=9.571e-01 normal
# RMS: stat=0.981, p=7.387e-01 normal
# tau: stat=0.953, p=5.811e-01 normal
# AUC: stat=0.859, p=2.643e-01 normal
#
# Experiment: offset_PPI_20, Sex: male, Date: April16
# reactionTime: stat=0.750, p=7.772e-16 NOT normal
# peakTime: stat=0.893, p=3.631e-01 normal
# difference: stat=0.750, p=7.772e-16 NOT normal
# peakValue: stat=0.810, p=1.380e-01 normal
# PTPA: stat=0.783, p=7.360e-02 normal
# PTTA: stat=0.779, p=6.445e-02 normal
# RMS: stat=0.841, p=2.168e-01 normal
# tau: stat=0.981, p=7.362e-01 normal
# AUC: stat=0.891, p=3.571e-01 normal
#
# Experiment: offset_PPI_20, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.999, p=9.265e-01 normal
# difference: stat=0.999, p=9.265e-01 normal
# peakValue: stat=0.974, p=6.903e-01 normal
# PTPA: stat=0.961, p=6.198e-01 normal
# PTTA: stat=0.966, p=6.468e-01 normal
# RMS: stat=0.969, p=6.630e-01 normal
# tau: stat=0.988, p=7.942e-01 normal
# AUC: stat=0.944, p=5.433e-01 normal
#
# Experiment: offset_PPI_20, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.827, p=1.799e-01 normal
# difference: stat=0.827, p=1.799e-01 normal
# peakValue: stat=0.981, p=7.346e-01 normal
# PTPA: stat=0.990, p=8.127e-01 normal
# PTTA: stat=0.953, p=5.839e-01 normal
# RMS: stat=0.998, p=9.251e-01 normal
# tau: stat=0.990, p=8.108e-01 normal
# AUC: stat=0.971, p=6.751e-01 normal
#
# Experiment: offset_PPI_50, Sex: female, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=1.000, p=1.000e+00 normal
# difference: stat=1.000, p=1.000e+00 normal
# peakValue: stat=0.973, p=6.837e-01 normal
# PTPA: stat=0.951, p=5.739e-01 normal
# PTTA: stat=0.882, p=3.295e-01 normal
# RMS: stat=1.000, p=9.865e-01 normal
# tau: stat=0.816, p=1.541e-01 normal
# AUC: stat=0.928, p=4.804e-01 normal
#
# Experiment: offset_PPI_50, Sex: female, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.909, p=4.144e-01 normal
# difference: stat=0.909, p=4.144e-01 normal
# peakValue: stat=0.918, p=4.437e-01 normal
# PTPA: stat=0.947, p=5.553e-01 normal
# PTTA: stat=0.903, p=3.964e-01 normal
# RMS: stat=0.835, p=2.002e-01 normal
# tau: stat=0.957, p=6.032e-01 normal
# AUC: stat=0.848, p=2.349e-01 normal
#
# Experiment: offset_PPI_50, Sex: female, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.893, p=3.631e-01 normal
# difference: stat=0.893, p=3.631e-01 normal
# peakValue: stat=0.795, p=1.022e-01 normal
# PTPA: stat=0.763, p=2.952e-02 NOT normal
# PTTA: stat=0.839, p=2.117e-01 normal
# RMS: stat=0.830, p=1.873e-01 normal
# tau: stat=0.991, p=8.146e-01 normal
# AUC: stat=1.000, p=9.690e-01 normal
#
# Experiment: offset_PPI_50, Sex: male, Date: April16
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.791, p=9.267e-02 normal
# difference: stat=0.791, p=9.267e-02 normal
# peakValue: stat=0.992, p=8.272e-01 normal
# PTPA: stat=0.998, p=9.144e-01 normal
# PTTA: stat=0.947, p=5.571e-01 normal
# RMS: stat=0.938, p=5.187e-01 normal
# tau: stat=0.842, p=2.198e-01 normal
# AUC: stat=0.942, p=5.370e-01 normal
#
# Experiment: offset_PPI_50, Sex: male, Date: June26
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.923, p=4.633e-01 normal
# difference: stat=0.923, p=4.633e-01 normal
# peakValue: stat=0.900, p=3.854e-01 normal
# PTPA: stat=0.900, p=3.861e-01 normal
# PTTA: stat=0.917, p=4.422e-01 normal
# RMS: stat=0.880, p=3.248e-01 normal
# tau: stat=0.793, p=9.799e-02 normal
# AUC: stat=0.859, p=2.655e-01 normal
#
# Experiment: offset_PPI_50, Sex: male, Date: May20
# reactionTime: stat=1.000, p=1.000e+00 normal
# peakTime: stat=0.952, p=5.782e-01 normal
# difference: stat=0.952, p=5.782e-01 normal
# peakValue: stat=0.900, p=3.860e-01 normal
# PTPA: stat=0.917, p=4.415e-01 normal
# PTTA: stat=0.930, p=4.868e-01 normal
# RMS: stat=0.813, p=1.463e-01 normal
# tau: stat=0.750, p=1.565e-05 NOT normal
# AUC: stat=0.934, p=5.035e-01 normal

# %%
from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for sex in df['sex'].unique():
    for date in df['date'].unique():
        found_normal = []
        for var in variables:
            vals = df[(df['sex'] == sex) & (df['date'] == date)][var].dropna()
            if len(vals) > 2:
                stat, p = shapiro(vals)
                if p > 0.05:
                    found_normal.append(f"{var}: stat={stat:.3f}, p={p:.3e} normal")
            # else: skip
        if found_normal:
            print(f"\nSex: {sex}, Date: {date}")
            for line in found_normal:
                print(line)
# Out:
# Sex: female, Date: April16
# peakValue: stat=0.959, p=6.010e-02 normal
# PTPA: stat=0.971, p=2.112e-01 normal
# PTTA: stat=0.973, p=2.667e-01 normal
# tau: stat=0.978, p=4.249e-01 normal
#
# Sex: female, Date: June26
# peakValue: stat=0.962, p=8.677e-02 normal
# PTPA: stat=0.960, p=7.249e-02 normal
# RMS: stat=0.962, p=8.113e-02 normal
# tau: stat=0.983, p=6.438e-01 normal
# AUC: stat=0.969, p=1.783e-01 normal
#
# Sex: female, Date: May20
# peakValue: stat=0.960, p=6.781e-02 normal
# PTTA: stat=0.957, p=5.266e-02 normal
# RMS: stat=0.965, p=1.205e-01 normal
# tau: stat=0.988, p=8.515e-01 normal
# AUC: stat=0.980, p=4.889e-01 normal
#
# Sex: male, Date: April16
# peakValue: stat=0.984, p=6.998e-01 normal
# PTPA: stat=0.988, p=8.788e-01 normal
# PTTA: stat=0.992, p=9.742e-01 normal
# RMS: stat=0.974, p=2.988e-01 normal
# AUC: stat=0.974, p=2.736e-01 normal
#
# Sex: male, Date: June26
# tau: stat=0.976, p=3.462e-01 normal
#
# Sex: male, Date: May20
# peakValue: stat=0.970, p=1.851e-01 normal
# PTPA: stat=0.973, p=2.516e-01 normal
# PTTA: stat=0.978, p=4.074e-01 normal
# AUC: stat=0.974, p=2.941e-01 normal

# %% [markdown]
# --> only rarely normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all dates, split by sex

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for sex in df['sex'].unique():
    print(f"\nSex: {sex} (all dates merged)")
    for var in variables:
        vals = df[df['sex'] == sex][var].dropna()
        if len(vals) > 2:
            stat, p = shapiro(vals)
            print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
        else:
            print(f"{var}: Not enough data")
# Out:
# Sex: female (all dates merged)
# reactionTime: stat=0.154, p=1.542e-26 NOT normal
# peakTime: stat=0.888, p=1.035e-09 NOT normal
# difference: stat=0.887, p=8.751e-10 NOT normal
# peakValue: stat=0.955, p=4.899e-05 NOT normal
# PTPA: stat=0.953, p=3.122e-05 NOT normal
# PTTA: stat=0.944, p=4.982e-06 NOT normal
# RMS: stat=0.956, p=6.093e-05 NOT normal
# tau: stat=0.976, p=5.884e-03 NOT normal
# AUC: stat=0.917, p=5.310e-08 NOT normal
#
# Sex: male (all dates merged)
# reactionTime: stat=0.284, p=8.274e-25 NOT normal
# peakTime: stat=0.944, p=4.933e-06 NOT normal
# difference: stat=0.947, p=8.215e-06 NOT normal
# peakValue: stat=0.956, p=4.947e-05 NOT normal
# PTPA: stat=0.955, p=4.428e-05 NOT normal
# PTTA: stat=0.956, p=5.855e-05 NOT normal
# RMS: stat=0.953, p=3.223e-05 NOT normal
# tau: stat=0.083, p=2.111e-27 NOT normal
# AUC: stat=0.954, p=3.971e-05 NOT normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all sexes, split by date

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for date in df['date'].unique():
    print(f"\nDate: {date} (all sexes merged)")
    for var in variables:
        vals = df[df['date'] == date][var].dropna()
        if len(vals) > 2:
            stat, p = shapiro(vals)
            print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
        else:
            print(f"{var}: Not enough data")
# Out:
# Date: April16 (all sexes merged)
# reactionTime: stat=0.251, p=5.209e-21 NOT normal
# peakTime: stat=0.910, p=2.025e-06 NOT normal
# difference: stat=0.912, p=2.695e-06 NOT normal
# peakValue: stat=0.913, p=2.900e-06 NOT normal
# PTPA: stat=0.918, p=5.488e-06 NOT normal
# PTTA: stat=0.924, p=1.105e-05 NOT normal
# RMS: stat=0.911, p=2.127e-06 NOT normal
# tau: stat=0.816, p=2.831e-10 NOT normal
# AUC: stat=0.889, p=1.850e-07 NOT normal
#
# Date: June26 (all sexes merged)
# reactionTime: stat=0.212, p=1.788e-21 NOT normal
# peakTime: stat=0.945, p=2.240e-04 NOT normal
# difference: stat=0.948, p=3.377e-04 NOT normal
# peakValue: stat=0.893, p=3.011e-07 NOT normal
# PTPA: stat=0.894, p=3.152e-07 NOT normal
# PTTA: stat=0.908, p=1.651e-06 NOT normal
# RMS: stat=0.885, p=1.254e-07 NOT normal
# tau: stat=0.978, p=7.287e-02 normal
# AUC: stat=0.911, p=2.365e-06 NOT normal
#
# Date: May20 (all sexes merged)
# reactionTime: stat=0.237, p=3.555e-21 NOT normal
# peakTime: stat=0.900, p=6.243e-07 NOT normal
# difference: stat=0.900, p=6.101e-07 NOT normal
# peakValue: stat=0.958, p=1.813e-03 NOT normal
# PTPA: stat=0.962, p=3.553e-03 NOT normal
# PTTA: stat=0.970, p=1.475e-02 NOT normal
# RMS: stat=0.954, p=8.788e-04 NOT normal
# tau: stat=0.113, p=1.371e-22 NOT normal
# AUC: stat=0.928, p=1.981e-05 NOT normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all sexes and all dates

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

print("\nAll data (sexes and dates merged):")
for var in variables:
    vals = df[var].dropna()
    if len(vals) > 2:
        stat, p = shapiro(vals)
        print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
    else:
        print(f"{var}: Not enough data")
# Out:
# All data (sexes and dates merged):
# reactionTime: stat=0.221, p=1.483e-34 NOT normal
# peakTime: stat=0.929, p=2.508e-11 NOT normal
# difference: stat=0.930, p=3.083e-11 NOT normal
# peakValue: stat=0.926, p=1.519e-11 NOT normal
# PTPA: stat=0.927, p=1.819e-11 NOT normal
# PTTA: stat=0.934, p=7.869e-11 NOT normal
# RMS: stat=0.929, p=2.465e-11 NOT normal
# tau: stat=0.048, p=3.952e-37 NOT normal
# AUC: stat=0.923, p=7.960e-12 NOT normal

# %% [markdown]
# ### ---> no change, even if not grouped by sex and / or date
# ### ---> data not normally distributed

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']
variables = ['peakValue', 'reactionTime', 'peakTime', 'tau']#[col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

plt.figure(figsize=(16, 9), dpi=200)
for var in variables:
    vals = pd.to_numeric(df[var], errors='coerce').dropna()
    norm_vals = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
    sns.kdeplot(
        norm_vals,
        label=var,
        fill=True,
        alpha=0.4,
        linewidth=2,
        bw_adjust=0.7,
        clip=(0, 1)
    )
plt.xlabel("Normalized Value", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

plt.figure(figsize=(16, 9), dpi=200)
for var in variables:
    vals = pd.to_numeric(df[var], errors='coerce').dropna()
    norm_vals = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
    sns.kdeplot(
        norm_vals,
        label=var,
        fill=True,
        alpha=0.4,
        linewidth=2,
        bw_adjust=0.7,
        clip=(0, 1)
    )
plt.xlabel("Normalized Value", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']

plt.figure(figsize=(10, 6), dpi=300)  # High quality output

for sex in df['sex'].unique():
    vals = df[df['sex'] == sex]['reactionTime'].dropna()
    sns.kdeplot(
        vals,
        label=f"{sex}",
        fill=True,
        alpha=0.5,
        linewidth=1.5,
        bw_adjust=0.7
    )

plt.xlabel("Reaction Time", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.title("Reaction Time Distribution by Sex", fontsize=18)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
from scipy.stats import shapiro, gamma, weibull_min, boxcox, lognorm, t, yeojohnson
import numpy as np
from sklearn.preprocessing import QuantileTransformer, PowerTransformer

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

def try_transformations(vals):
    results = {}
    # Original
    results['original'] = shapiro(vals)[1] if len(vals) > 2 else np.nan
    # Gamma
    if len(vals) > 2 and (vals > 0).all():
        params = gamma.fit(vals, floc=0)
        trans = gamma.cdf(vals, *params)
        results['gamma'] = shapiro(trans)[1]
    # Weibull
    if len(vals) > 2 and (vals > 0).all():
        params = weibull_min.fit(vals, floc=0)
        trans = weibull_min.cdf(vals, *params)
        results['weibull'] = shapiro(trans)[1]
    # Box-Cox
    if len(vals) > 2 and (vals > 0).all():
        trans, _ = boxcox(vals)
        results['boxcox'] = shapiro(trans)[1]
    # Lognormal
    if len(vals) > 2 and (vals > 0).all():
        params = lognorm.fit(vals, floc=0)
        trans = lognorm.cdf(vals, *params)
        results['lognorm'] = shapiro(trans)[1]
    # Student-t
    if len(vals) > 2:
        params = t.fit(vals)
        trans = t.cdf(vals, *params)
        results['student_t'] = shapiro(trans)[1]
    # Yeo-Johnson
    if len(vals) > 2:
        trans, _ = yeojohnson(vals)
        results['yeojohnson'] = shapiro(trans)[1]
    # Log
    if len(vals) > 2 and (vals > 0).all():
        trans = np.log(vals + 1e-6)
        results['log'] = shapiro(trans)[1]
    # Sqrt
    if len(vals) > 2 and (vals >= 0).all():
        trans = np.sqrt(vals)
        results['sqrt'] = shapiro(trans)[1]
    # Z-score
    if len(vals) > 2:
        trans = (vals - vals.mean()) / (vals.std() + 1e-8)
        results['zscore'] = shapiro(trans)[1]
    # Min-max
    if len(vals) > 2:
        trans = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
        results['minmax'] = shapiro(trans)[1]
    # Quantile (normal)
    if len(vals) > 2:
        qt = QuantileTransformer(output_distribution='normal', random_state=0, n_quantiles=min(len(vals), 1000))
        trans = qt.fit_transform(vals.values.reshape(-1, 1)).flatten()
        results['quantile'] = shapiro(trans)[1]
    # Power (Yeo-Johnson, sklearn)
    if len(vals) > 2:
        pt = PowerTransformer(method='yeo-johnson')
        trans = pt.fit_transform(vals.values.reshape(-1, 1)).flatten()
        results['power'] = shapiro(trans)[1]
    return results

for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        for var in variables:
            vals = pd.to_numeric(df[(df['sex'] == sex) & (df['date'] == date)][var], errors='coerce').dropna()
            res = try_transformations(vals)
            for method, p in res.items():
                print(f"{var:15} {method:10}: p={p:.3e} {'normal' if p > 0.05 else 'NOT normal'}")
# Out:
# Sex: female, Date: April16
# reactionTime    original  : p=2.548e-16 NOT normal
# reactionTime    gamma     : p=2.548e-16 NOT normal
# reactionTime    weibull   : p=2.548e-16 NOT normal
# reactionTime    boxcox    : p=1.000e+00 normal
# reactionTime    lognorm   : p=2.548e-16 NOT normal
# reactionTime    student_t : p=2.548e-16 NOT normal
# reactionTime    yeojohnson: p=2.548e-16 NOT normal
# reactionTime    log       : p=2.548e-16 NOT normal
# reactionTime    sqrt      : p=2.548e-16 NOT normal
# reactionTime    zscore    : p=2.548e-16 NOT normal
# reactionTime    minmax    : p=2.548e-16 NOT normal
# reactionTime    quantile  : p=2.548e-16 NOT normal
# reactionTime    power     : p=2.548e-16 NOT normal
# peakTime        original  : p=1.151e-03 NOT normal
# peakTime        gamma     : p=6.503e-05 NOT normal
# peakTime        weibull   : p=2.837e-05 NOT normal
# peakTime        boxcox    : p=3.439e-03 NOT normal
# peakTime        lognorm   : p=6.881e-05 NOT normal
# peakTime        student_t : p=5.749e-05 NOT normal
# peakTime        yeojohnson: p=3.446e-03 NOT normal
# peakTime        log       : p=4.732e-04 NOT normal
# peakTime        sqrt      : p=7.624e-04 NOT normal
# peakTime        zscore    : p=1.151e-03 NOT normal
# peakTime        minmax    : p=1.151e-03 NOT normal
# peakTime        quantile  : p=2.024e-05 NOT normal
# peakTime        power     : p=3.446e-03 NOT normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# difference      original  : p=1.272e-03 NOT normal
# difference      gamma     : p=6.677e-05 NOT normal
# difference      weibull   : p=2.937e-05 NOT normal
# difference      boxcox    : p=3.567e-03 NOT normal
# difference      lognorm   : p=7.088e-05 NOT normal
# difference      student_t : p=5.856e-05 NOT normal
# difference      yeojohnson: p=3.575e-03 NOT normal
# difference      log       : p=4.938e-04 NOT normal
# difference      sqrt      : p=8.231e-04 NOT normal
# difference      zscore    : p=1.272e-03 NOT normal
# difference      minmax    : p=1.272e-03 NOT normal
# difference      quantile  : p=2.058e-05 NOT normal
# difference      power     : p=3.575e-03 NOT normal
# peakValue       original  : p=6.010e-02 normal
# peakValue       gamma     : p=6.621e-04 NOT normal
# peakValue       weibull   : p=2.973e-03 NOT normal
# peakValue       boxcox    : p=1.034e-01 normal
# peakValue       lognorm   : p=4.628e-04 NOT normal
# peakValue       student_t : p=1.179e-03 NOT normal
# peakValue       yeojohnson: p=1.041e-01 normal
# peakValue       log       : p=7.434e-03 NOT normal
# peakValue       sqrt      : p=2.403e-02 NOT normal
# peakValue       zscore    : p=6.010e-02 normal
# peakValue       minmax    : p=6.010e-02 normal
# peakValue       quantile  : p=3.846e-06 NOT normal
# peakValue       power     : p=1.041e-01 normal
# PTPA            original  : p=2.112e-01 normal
# PTPA            gamma     : p=1.945e-03 NOT normal
# PTPA            weibull   : p=6.146e-03 NOT normal
# PTPA            boxcox    : p=2.462e-01 normal
# PTPA            lognorm   : p=1.433e-03 NOT normal
# PTPA            student_t : p=3.016e-03 NOT normal
# PTPA            yeojohnson: p=2.474e-01 normal
# PTPA            log       : p=3.895e-02 NOT normal
# PTPA            sqrt      : p=1.080e-01 normal
# PTPA            zscore    : p=2.112e-01 normal
# PTPA            minmax    : p=2.112e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=2.474e-01 normal
# PTTA            original  : p=2.667e-01 normal
# PTTA            gamma     : p=4.303e-03 NOT normal
# PTTA            weibull   : p=1.036e-02 NOT normal
# PTTA            boxcox    : p=2.374e-01 normal
# PTTA            lognorm   : p=3.363e-03 NOT normal
# PTTA            student_t : p=5.768e-03 NOT normal
# PTTA            yeojohnson: p=2.380e-01 normal
# PTTA            log       : p=1.048e-01 normal
# PTTA            sqrt      : p=2.112e-01 normal
# PTTA            zscore    : p=2.667e-01 normal
# PTTA            minmax    : p=2.667e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=2.380e-01 normal
# RMS             original  : p=8.690e-03 NOT normal
# RMS             gamma     : p=2.006e-04 NOT normal
# RMS             weibull   : p=8.824e-04 NOT normal
# RMS             boxcox    : p=3.634e-02 NOT normal
# RMS             lognorm   : p=1.314e-04 NOT normal
# RMS             student_t : p=3.989e-04 NOT normal
# RMS             yeojohnson: p=3.797e-02 NOT normal
# RMS             log       : p=7.025e-04 NOT normal
# RMS             sqrt      : p=2.678e-03 NOT normal
# RMS             zscore    : p=8.690e-03 NOT normal
# RMS             minmax    : p=8.690e-03 NOT normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=3.797e-02 NOT normal
# tau             original  : p=4.249e-01 normal
# tau             gamma     : p=1.419e-03 NOT normal
# tau             weibull   : p=3.537e-03 NOT normal
# tau             boxcox    : p=4.247e-01 normal
# tau             lognorm   : p=1.282e-03 NOT normal
# tau             student_t : p=1.574e-03 NOT normal
# tau             yeojohnson: p=4.249e-01 normal
# tau             log       : p=1.193e-01 normal
# tau             sqrt      : p=3.063e-01 normal
# tau             zscore    : p=4.249e-01 normal
# tau             minmax    : p=4.249e-01 normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=4.249e-01 normal
# AUC             original  : p=3.100e-02 NOT normal
# AUC             gamma     : p=1.270e-03 NOT normal
# AUC             weibull   : p=9.024e-03 NOT normal
# AUC             boxcox    : p=1.043e-01 normal
# AUC             lognorm   : p=6.925e-04 NOT normal
# AUC             student_t : p=3.367e-03 NOT normal
# AUC             yeojohnson: p=1.043e-01 normal
# AUC             log       : p=1.487e-03 NOT normal
# AUC             sqrt      : p=7.827e-03 NOT normal
# AUC             zscore    : p=3.100e-02 NOT normal
# AUC             minmax    : p=3.100e-02 NOT normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=1.043e-01 normal
#
# Sex: female, Date: June26
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# reactionTime    original  : p=3.313e-15 NOT normal
# reactionTime    gamma     : p=3.509e-15 NOT normal
# reactionTime    weibull   : p=3.662e-15 NOT normal
# reactionTime    boxcox    : p=1.000e+00 normal
# reactionTime    lognorm   : p=3.508e-15 NOT normal
# reactionTime    student_t : p=3.501e-15 NOT normal
# reactionTime    yeojohnson: p=3.501e-15 NOT normal
# reactionTime    log       : p=3.563e-15 NOT normal
# reactionTime    sqrt      : p=3.444e-15 NOT normal
# reactionTime    zscore    : p=3.313e-15 NOT normal
# reactionTime    minmax    : p=3.313e-15 NOT normal
# reactionTime    quantile  : p=4.011e-15 NOT normal
# reactionTime    power     : p=3.501e-15 NOT normal
# peakTime        original  : p=3.859e-03 NOT normal
# peakTime        gamma     : p=1.125e-03 NOT normal
# peakTime        weibull   : p=3.475e-03 NOT normal
# peakTime        boxcox    : p=4.454e-02 NOT normal
# peakTime        lognorm   : p=8.421e-04 NOT normal
# peakTime        student_t : p=1.700e-03 NOT normal
# peakTime        yeojohnson: p=4.467e-02 NOT normal
# peakTime        log       : p=2.110e-04 NOT normal
# peakTime        sqrt      : p=1.001e-03 NOT normal
# peakTime        zscore    : p=3.859e-03 NOT normal
# peakTime        minmax    : p=3.859e-03 NOT normal
# peakTime        quantile  : p=9.853e-06 NOT normal
# peakTime        power     : p=4.467e-02 NOT normal
# difference      original  : p=5.183e-03 NOT normal
# difference      gamma     : p=1.587e-03 NOT normal
# difference      weibull   : p=4.661e-03 NOT normal
# difference      boxcox    : p=5.311e-02 normal
# difference      lognorm   : p=1.149e-03 NOT normal
# difference      student_t : p=2.608e-03 NOT normal
# difference      yeojohnson: p=5.327e-02 normal
# difference      log       : p=2.045e-04 NOT normal
# difference      sqrt      : p=1.170e-03 NOT normal
# difference      zscore    : p=5.183e-03 NOT normal
# difference      minmax    : p=5.183e-03 NOT normal
# difference      quantile  : p=9.762e-06 NOT normal
# difference      power     : p=5.327e-02 normal
# peakValue       original  : p=8.677e-02 normal
# peakValue       gamma     : p=2.808e-04 NOT normal
# peakValue       weibull   : p=9.293e-04 NOT normal
# peakValue       boxcox    : p=1.588e-01 normal
# peakValue       lognorm   : p=1.906e-04 NOT normal
# peakValue       student_t : p=5.111e-04 NOT normal
# peakValue       yeojohnson: p=1.601e-01 normal
# peakValue       log       : p=6.232e-03 NOT normal
# peakValue       sqrt      : p=2.972e-02 NOT normal
# peakValue       zscore    : p=8.677e-02 normal
# peakValue       minmax    : p=8.677e-02 normal
# peakValue       quantile  : p=2.354e-04 NOT normal
# peakValue       power     : p=1.601e-01 normal
# PTPA            original  : p=7.249e-02 normal
# PTPA            gamma     : p=2.591e-04 NOT normal
# PTPA            weibull   : p=8.148e-04 NOT normal
# PTPA            boxcox    : p=1.164e-01 normal
# PTPA            lognorm   : p=1.751e-04 NOT normal
# PTPA            student_t : p=4.669e-04 NOT normal
# PTPA            yeojohnson: p=1.173e-01 normal
# PTPA            log       : p=6.968e-03 NOT normal
# PTPA            sqrt      : p=2.809e-02 NOT normal
# PTPA            zscore    : p=7.249e-02 normal
# PTPA            minmax    : p=7.249e-02 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=1.173e-01 normal
# PTTA            original  : p=6.548e-03 NOT normal
# PTTA            gamma     : p=5.568e-05 NOT normal
# PTTA            weibull   : p=2.083e-04 NOT normal
# PTTA            boxcox    : p=1.312e-02 NOT normal
# PTTA            lognorm   : p=3.582e-05 NOT normal
# PTTA            student_t : p=1.156e-04 NOT normal
# PTTA            yeojohnson: p=1.329e-02 NOT normal
# PTTA            log       : p=7.887e-04 NOT normal
# PTTA            sqrt      : p=2.601e-03 NOT normal
# PTTA            zscore    : p=6.548e-03 NOT normal
# PTTA            minmax    : p=6.548e-03 NOT normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=1.329e-02 NOT normal
# RMS             original  : p=8.113e-02 normal
# RMS             gamma     : p=5.683e-04 NOT normal
# RMS             weibull   : p=1.146e-03 NOT normal
# RMS             boxcox    : p=1.012e-01 normal
# RMS             lognorm   : p=3.981e-04 NOT normal
# RMS             student_t : p=8.517e-04 NOT normal
# RMS             yeojohnson: p=1.025e-01 normal
# RMS             log       : p=6.816e-03 NOT normal
# RMS             sqrt      : p=3.357e-02 NOT normal
# RMS             zscore    : p=8.113e-02 normal
# RMS             minmax    : p=8.113e-02 normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=1.025e-01 normal
# tau             original  : p=6.438e-01 normal
# tau             gamma     : p=1.398e-02 NOT normal
# tau             weibull   : p=2.263e-02 NOT normal
# tau             boxcox    : p=7.374e-01 normal
# tau             lognorm   : p=9.588e-03 NOT normal
# tau             student_t : p=1.632e-02 NOT normal
# tau             yeojohnson: p=7.363e-01 normal
# tau             log       : p=2.016e-01 normal
# tau             sqrt      : p=6.734e-01 normal
# tau             zscore    : p=6.438e-01 normal
# tau             minmax    : p=6.438e-01 normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=7.363e-01 normal
# AUC             original  : p=1.783e-01 normal
# AUC             gamma     : p=4.339e-03 NOT normal
# AUC             weibull   : p=5.083e-03 NOT normal
# AUC             boxcox    : p=3.924e-01 normal
# AUC             lognorm   : p=3.577e-03 NOT normal
# AUC             student_t : p=3.397e-03 NOT normal
# AUC             yeojohnson: p=3.923e-01 normal
# AUC             log       : p=2.485e-01 normal
# AUC             sqrt      : p=3.871e-01 normal
# AUC             zscore    : p=1.783e-01 normal
# AUC             minmax    : p=1.783e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=3.923e-01 normal
#
# Sex: female, Date: May20
# reactionTime    original  : p=1.081e-15 NOT normal
# reactionTime    gamma     : p=1.069e-15 NOT normal
# reactionTime    weibull   : p=1.073e-15 NOT normal
# reactionTime    boxcox    : p=1.069e-15 NOT normal
# reactionTime    lognorm   : p=1.069e-15 NOT normal
# reactionTime    student_t : p=1.069e-15 NOT normal
# reactionTime    yeojohnson: p=1.069e-15 NOT normal
# reactionTime    log       : p=1.127e-15 NOT normal
# reactionTime    sqrt      : p=1.108e-15 NOT normal
# reactionTime    zscore    : p=1.081e-15 NOT normal
# reactionTime    minmax    : p=1.081e-15 NOT normal
# reactionTime    quantile  : p=1.135e-15 NOT normal
# reactionTime    power     : p=1.069e-15 NOT normal
# peakTime        original  : p=9.486e-04 NOT normal
# peakTime        gamma     : p=4.339e-05 NOT normal
# peakTime        weibull   : p=1.297e-04 NOT normal
# peakTime        boxcox    : p=1.185e-02 NOT normal
# peakTime        lognorm   : p=4.068e-05 NOT normal
# peakTime        student_t : p=4.265e-05 NOT normal
# peakTime        yeojohnson: p=1.188e-02 NOT normal
# peakTime        log       : p=2.680e-04 NOT normal
# peakTime        sqrt      : p=5.174e-04 NOT normal
# peakTime        zscore    : p=9.486e-04 NOT normal
# peakTime        minmax    : p=9.486e-04 NOT normal
# peakTime        quantile  : p=4.720e-05 NOT normal
# peakTime        power     : p=1.188e-02 NOT normal
# difference      original  : p=6.176e-04 NOT normal
# difference      gamma     : p=3.093e-05 NOT normal
# difference      weibull   : p=5.779e-05 NOT normal
# difference      boxcox    : p=7.479e-03 NOT normal
# difference      lognorm   : p=2.973e-05 NOT normal
# difference      student_t : p=3.312e-05 NOT normal
# difference      yeojohnson: p=7.505e-03 NOT normal
# difference      log       : p=1.724e-04 NOT normal
# difference      sqrt      : p=3.356e-04 NOT normal
# difference      zscore    : p=6.176e-04 NOT normal
# difference      minmax    : p=6.176e-04 NOT normal
# difference      quantile  : p=4.717e-05 NOT normal
# difference      power     : p=7.505e-03 NOT normal
# peakValue       original  : p=6.781e-02 normal
# peakValue       gamma     : p=5.350e-04 NOT normal
# peakValue       weibull   : p=9.081e-04 NOT normal
# peakValue       boxcox    : p=1.124e-01 normal
# peakValue       lognorm   : p=3.847e-04 NOT normal
# peakValue       student_t : p=7.329e-04 NOT normal
# peakValue       yeojohnson: p=1.133e-01 normal
# peakValue       log       : p=3.701e-03 NOT normal
# peakValue       sqrt      : p=2.122e-02 NOT normal
# peakValue       zscore    : p=6.781e-02 normal
# peakValue       minmax    : p=6.781e-02 normal
# peakValue       quantile  : p=2.149e-04 NOT normal
# peakValue       power     : p=1.133e-01 normal
# PTPA            original  : p=4.111e-02 NOT normal
# PTPA            gamma     : p=3.731e-04 NOT normal
# PTPA            weibull   : p=5.494e-04 NOT normal
# PTPA            boxcox    : p=6.289e-02 normal
# PTPA            lognorm   : p=2.834e-04 NOT normal
# PTPA            student_t : p=4.643e-04 NOT normal
# PTPA            yeojohnson: p=6.339e-02 normal
# PTPA            log       : p=2.766e-03 NOT normal
# PTPA            sqrt      : p=1.416e-02 NOT normal
# PTPA            zscore    : p=4.111e-02 NOT normal
# PTPA            minmax    : p=4.111e-02 NOT normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=6.339e-02 normal
# PTTA            original  : p=5.266e-02 normal
# PTTA            gamma     : p=3.969e-04 NOT normal
# PTTA            weibull   : p=4.987e-04 NOT normal
# PTTA            boxcox    : p=6.534e-02 normal
# PTTA            lognorm   : p=3.045e-04 NOT normal
# PTTA            student_t : p=4.489e-04 NOT normal
# PTTA            yeojohnson: p=6.575e-02 normal
# PTTA            log       : p=4.345e-03 NOT normal
# PTTA            sqrt      : p=2.120e-02 NOT normal
# PTTA            zscore    : p=5.266e-02 normal
# PTTA            minmax    : p=5.266e-02 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=6.575e-02 normal
# RMS             original  : p=1.205e-01 normal
# RMS             gamma     : p=7.540e-04 NOT normal
# RMS             weibull   : p=1.478e-03 NOT normal
# RMS             boxcox    : p=1.758e-01 normal
# RMS             lognorm   : p=5.191e-04 NOT normal
# RMS             student_t : p=1.095e-03 NOT normal
# RMS             yeojohnson: p=1.799e-01 normal
# RMS             log       : p=4.824e-03 NOT normal
# RMS             sqrt      : p=3.485e-02 NOT normal
# RMS             zscore    : p=1.205e-01 normal
# RMS             minmax    : p=1.205e-01 normal
# RMS             quantile  : p=2.392e-04 NOT normal
# RMS             power     : p=1.799e-01 normal
# tau             original  : p=8.515e-01 normal
# tau             gamma     : p=5.758e-02 normal
# tau             weibull   : p=7.967e-02 normal
# tau             boxcox    : p=8.921e-01 normal
# tau             lognorm   : p=4.578e-02 NOT normal
# tau             student_t : p=6.143e-02 normal
# tau             yeojohnson: p=8.922e-01 normal
# tau             log       : p=3.026e-01 normal
# tau             sqrt      : p=8.225e-01 normal
# tau             zscore    : p=8.515e-01 normal
# tau             minmax    : p=8.515e-01 normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=8.922e-01 normal
# AUC             original  : p=4.889e-01 normal
# AUC             gamma     : p=1.811e-02 NOT normal
# AUC             weibull   : p=2.928e-02 NOT normal
# AUC             boxcox    : p=5.199e-01 normal
# AUC             lognorm   : p=1.202e-02 NOT normal
# AUC             student_t : p=2.239e-02 NOT normal
# AUC             yeojohnson: p=5.199e-01 normal
# AUC             log       : p=1.459e-01 normal
# AUC             sqrt      : p=4.607e-01 normal
# AUC             zscore    : p=4.889e-01 normal
# AUC             minmax    : p=4.889e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=5.199e-01 normal
#
# Sex: male, Date: April16
# reactionTime    original  : p=6.415e-14 NOT normal
# reactionTime    gamma     : p=1.927e-13 NOT normal
# reactionTime    weibull   : p=2.421e-13 NOT normal
# reactionTime    boxcox    : p=1.468e-13 NOT normal
# reactionTime    lognorm   : p=1.864e-13 NOT normal
# reactionTime    student_t : p=1.441e-13 NOT normal
# reactionTime    yeojohnson: p=1.496e-13 NOT normal
# reactionTime    log       : p=1.297e-13 NOT normal
# reactionTime    sqrt      : p=9.427e-14 NOT normal
# reactionTime    zscore    : p=6.415e-14 NOT normal
# reactionTime    minmax    : p=6.415e-14 NOT normal
# reactionTime    quantile  : p=2.434e-13 NOT normal
# reactionTime    power     : p=1.496e-13 NOT normal
# peakTime        original  : p=3.241e-02 NOT normal
# peakTime        gamma     : p=2.042e-03 NOT normal
# peakTime        weibull   : p=2.617e-03 NOT normal
# peakTime        boxcox    : p=3.301e-02 NOT normal
# peakTime        lognorm   : p=1.842e-03 NOT normal
# peakTime        student_t : p=2.152e-03 NOT normal
# peakTime        yeojohnson: p=3.306e-02 NOT normal
# peakTime        log       : p=2.480e-02 NOT normal
# peakTime        sqrt      : p=3.405e-02 NOT normal
# peakTime        zscore    : p=3.241e-02 NOT normal
# peakTime        minmax    : p=3.241e-02 NOT normal
# peakTime        quantile  : p=1.636e-06 NOT normal
# peakTime        power     : p=3.306e-02 NOT normal
# difference      original  : p=3.329e-02 NOT normal
# difference      gamma     : p=2.345e-03 NOT normal
# difference      weibull   : p=2.793e-03 NOT normal
# difference      boxcox    : p=3.642e-02 NOT normal
# difference      lognorm   : p=2.121e-03 NOT normal
# difference      student_t : p=2.367e-03 NOT normal
# difference      yeojohnson: p=3.647e-02 NOT normal
# difference      log       : p=2.811e-02 NOT normal
# difference      sqrt      : p=3.820e-02 NOT normal
# difference      zscore    : p=3.329e-02 NOT normal
# difference      minmax    : p=3.329e-02 NOT normal
# difference      quantile  : p=1.605e-06 NOT normal
# difference      power     : p=3.647e-02 NOT normal
# peakValue       original  : p=6.998e-01 normal
# peakValue       gamma     : p=9.024e-03 NOT normal
# peakValue       weibull   : p=8.097e-03 NOT normal
# peakValue       boxcox    : p=7.120e-01 normal
# peakValue       lognorm   : p=8.083e-03 NOT normal
# peakValue       student_t : p=7.859e-03 NOT normal
# peakValue       yeojohnson: p=7.123e-01 normal
# peakValue       log       : p=1.128e-01 normal
# peakValue       sqrt      : p=4.376e-01 normal
# peakValue       zscore    : p=6.998e-01 normal
# peakValue       minmax    : p=6.998e-01 normal
# peakValue       quantile  : p=2.363e-04 NOT normal
# peakValue       power     : p=7.123e-01 normal
# PTPA            original  : p=8.788e-01 normal
# PTPA            gamma     : p=1.374e-02 NOT normal
# PTPA            weibull   : p=1.288e-02 NOT normal
# PTPA            boxcox    : p=8.768e-01 normal
# PTPA            lognorm   : p=1.242e-02 NOT normal
# PTPA            student_t : p=1.176e-02 NOT normal
# PTPA            yeojohnson: p=8.769e-01 normal
# PTPA            log       : p=2.493e-01 normal
# PTPA            sqrt      : p=7.082e-01 normal
# PTPA            zscore    : p=8.788e-01 normal
# PTPA            minmax    : p=8.788e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=8.769e-01 normal
# PTTA            original  : p=9.742e-01 normal
# PTTA            gamma     : p=3.749e-02 NOT normal
# PTTA            weibull   : p=4.510e-02 NOT normal
# PTTA            boxcox    : p=9.744e-01 normal
# PTTA            lognorm   : p=2.924e-02 NOT normal
# PTTA            student_t : p=3.929e-02 NOT normal
# PTTA            yeojohnson: p=9.744e-01 normal
# PTTA            log       : p=1.811e-01 normal
# PTTA            sqrt      : p=7.753e-01 normal
# PTTA            zscore    : p=9.742e-01 normal
# PTTA            minmax    : p=9.742e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=9.744e-01 normal
# RMS             original  : p=2.988e-01 normal
# RMS             gamma     : p=3.278e-03 NOT normal
# RMS             weibull   : p=2.540e-03 NOT normal
# RMS             boxcox    : p=3.167e-01 normal
# RMS             lognorm   : p=3.098e-03 NOT normal
# RMS             student_t : p=2.669e-03 NOT normal
# RMS             yeojohnson: p=3.175e-01 normal
# RMS             log       : p=3.890e-02 NOT normal
# RMS             sqrt      : p=1.597e-01 normal
# RMS             zscore    : p=2.988e-01 normal
# RMS             minmax    : p=2.988e-01 normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=3.175e-01 normal
# tau             original  : p=1.148e-07 NOT normal
# tau             gamma     : p=5.850e-02 normal
# tau             weibull   : p=4.429e-01 normal
# tau             boxcox    : p=1.968e-01 normal
# tau             lognorm   : p=3.319e-02 NOT normal
# tau             student_t : p=4.446e-03 NOT normal
# tau             yeojohnson: p=2.028e-01 normal
# tau             log       : p=2.363e-02 NOT normal
# tau             sqrt      : p=9.044e-05 NOT normal
# tau             zscore    : p=1.148e-07 NOT normal
# tau             minmax    : p=1.148e-07 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=2.028e-01 normal
# AUC             original  : p=2.736e-01 normal
# AUC             gamma     : p=1.771e-03 NOT normal
# AUC             weibull   : p=2.024e-03 NOT normal
# AUC             boxcox    : p=3.564e-01 normal
# AUC             lognorm   : p=1.788e-03 NOT normal
# AUC             student_t : p=1.357e-03 NOT normal
# AUC             yeojohnson: p=3.564e-01 normal
# AUC             log       : p=9.114e-02 normal
# AUC             sqrt      : p=3.337e-01 normal
# AUC             zscore    : p=2.736e-01 normal
# AUC             minmax    : p=2.736e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=3.564e-01 normal
#
# Sex: male, Date: June26
# reactionTime    original  : p=1.069e-15 NOT normal
# reactionTime    gamma     : p=1.069e-15 NOT normal
# reactionTime    weibull   : p=1.069e-15 NOT normal
# reactionTime    boxcox    : p=1.000e+00 normal
# reactionTime    lognorm   : p=1.069e-15 NOT normal
# reactionTime    student_t : p=1.069e-15 NOT normal
# reactionTime    yeojohnson: p=1.069e-15 NOT normal
# reactionTime    log       : p=1.069e-15 NOT normal
# reactionTime    sqrt      : p=1.069e-15 NOT normal
# reactionTime    zscore    : p=1.069e-15 NOT normal
# reactionTime    minmax    : p=1.069e-15 NOT normal
# reactionTime    quantile  : p=1.069e-15 NOT normal
# reactionTime    power     : p=1.069e-15 NOT normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# peakTime        original  : p=1.746e-03 NOT normal
# peakTime        gamma     : p=9.183e-04 NOT normal
# peakTime        weibull   : p=7.456e-04 NOT normal
# peakTime        boxcox    : p=1.541e-01 normal
# peakTime        lognorm   : p=9.632e-04 NOT normal
# peakTime        student_t : p=8.112e-04 NOT normal
# peakTime        yeojohnson: p=1.520e-01 normal
# peakTime        log       : p=2.236e-02 NOT normal
# peakTime        sqrt      : p=6.996e-03 NOT normal
# peakTime        zscore    : p=1.746e-03 NOT normal
# peakTime        minmax    : p=1.746e-03 NOT normal
# peakTime        quantile  : p=1.326e-04 NOT normal
# peakTime        power     : p=1.520e-01 normal
# difference      original  : p=2.504e-03 NOT normal
# difference      gamma     : p=1.064e-03 NOT normal
# difference      weibull   : p=9.521e-04 NOT normal
# difference      boxcox    : p=2.378e-01 normal
# difference      lognorm   : p=1.113e-03 NOT normal
# difference      student_t : p=9.572e-04 NOT normal
# difference      yeojohnson: p=2.343e-01 normal
# difference      log       : p=4.355e-02 NOT normal
# difference      sqrt      : p=1.208e-02 NOT normal
# difference      zscore    : p=2.504e-03 NOT normal
# difference      minmax    : p=2.504e-03 NOT normal
# difference      quantile  : p=1.326e-04 NOT normal
# difference      power     : p=2.343e-01 normal
# peakValue       original  : p=1.343e-02 NOT normal
# peakValue       gamma     : p=4.302e-05 NOT normal
# peakValue       weibull   : p=2.327e-04 NOT normal
# peakValue       boxcox    : p=1.120e-02 NOT normal
# peakValue       lognorm   : p=2.117e-05 NOT normal
# peakValue       student_t : p=1.486e-04 NOT normal
# peakValue       yeojohnson: p=1.124e-02 NOT normal
# peakValue       log       : p=1.137e-03 NOT normal
# peakValue       sqrt      : p=5.065e-03 NOT normal
# peakValue       zscore    : p=1.343e-02 NOT normal
# peakValue       minmax    : p=1.343e-02 NOT normal
# peakValue       quantile  : p=2.367e-04 NOT normal
# peakValue       power     : p=1.124e-02 NOT normal
# PTPA            original  : p=7.046e-03 NOT normal
# PTPA            gamma     : p=2.162e-05 NOT normal
# PTPA            weibull   : p=1.251e-04 NOT normal
# PTPA            boxcox    : p=6.233e-03 NOT normal
# PTPA            lognorm   : p=1.066e-05 NOT normal
# PTPA            student_t : p=7.921e-05 NOT normal
# PTPA            yeojohnson: p=6.268e-03 NOT normal
# PTPA            log       : p=5.206e-04 NOT normal
# PTPA            sqrt      : p=2.381e-03 NOT normal
# PTPA            zscore    : p=7.046e-03 NOT normal
# PTPA            minmax    : p=7.046e-03 NOT normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=6.268e-03 NOT normal
# PTTA            original  : p=1.003e-02 NOT normal
# PTTA            gamma     : p=3.743e-05 NOT normal
# PTTA            weibull   : p=1.918e-04 NOT normal
# PTTA            boxcox    : p=8.150e-03 NOT normal
# PTTA            lognorm   : p=1.949e-05 NOT normal
# PTTA            student_t : p=1.154e-04 NOT normal
# PTTA            yeojohnson: p=8.173e-03 NOT normal
# PTTA            log       : p=1.162e-03 NOT normal
# PTTA            sqrt      : p=4.662e-03 NOT normal
# PTTA            zscore    : p=1.003e-02 NOT normal
# PTTA            minmax    : p=1.003e-02 NOT normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=8.173e-03 NOT normal
# RMS             original  : p=1.092e-03 NOT normal
# RMS             gamma     : p=6.247e-06 NOT normal
# RMS             weibull   : p=3.194e-05 NOT normal
# RMS             boxcox    : p=1.221e-03 NOT normal
# RMS             lognorm   : p=3.031e-06 NOT normal
# RMS             student_t : p=2.456e-05 NOT normal
# RMS             yeojohnson: p=1.259e-03 NOT normal
# RMS             log       : p=7.735e-05 NOT normal
# RMS             sqrt      : p=3.206e-04 NOT normal
# RMS             zscore    : p=1.092e-03 NOT normal
# RMS             minmax    : p=1.092e-03 NOT normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=1.259e-03 NOT normal
# tau             original  : p=3.462e-01 normal
# tau             gamma     : p=6.371e-02 normal
# tau             weibull   : p=3.647e-02 NOT normal
# tau             boxcox    : p=3.831e-01 normal
# tau             lognorm   : p=7.487e-02 normal
# tau             student_t : p=1.450e-02 NOT normal
# tau             yeojohnson: p=3.826e-01 normal
# tau             log       : p=2.609e-02 NOT normal
# tau             sqrt      : p=1.524e-01 normal
# tau             zscore    : p=3.462e-01 normal
# tau             minmax    : p=3.462e-01 normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=3.826e-01 normal
# AUC             original  : p=4.395e-03 NOT normal
# AUC             gamma     : p=2.126e-05 NOT normal
# AUC             weibull   : p=8.092e-05 NOT normal
# AUC             boxcox    : p=4.200e-03 NOT normal
# AUC             lognorm   : p=1.191e-05 NOT normal
# AUC             student_t : p=5.659e-05 NOT normal
# AUC             yeojohnson: p=4.201e-03 NOT normal
# AUC             log       : p=5.665e-04 NOT normal
# AUC             sqrt      : p=1.848e-03 NOT normal
# AUC             zscore    : p=4.395e-03 NOT normal
# AUC             minmax    : p=4.395e-03 NOT normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=4.201e-03 NOT normal
#
# Sex: male, Date: May20
# reactionTime    original  : p=2.973e-14 NOT normal
# reactionTime    gamma     : p=2.743e-14 NOT normal
# reactionTime    weibull   : p=3.094e-14 NOT normal
# reactionTime    boxcox    : p=2.630e-14 NOT normal
# reactionTime    lognorm   : p=2.732e-14 NOT normal
# reactionTime    student_t : p=2.630e-14 NOT normal
# reactionTime    yeojohnson: p=2.630e-14 NOT normal
# reactionTime    log       : p=3.188e-14 NOT normal
# reactionTime    sqrt      : p=3.088e-14 NOT normal
# reactionTime    zscore    : p=2.973e-14 NOT normal
# reactionTime    minmax    : p=2.973e-14 NOT normal
# reactionTime    quantile  : p=3.397e-14 NOT normal
# reactionTime    power     : p=2.630e-14 NOT normal
# peakTime        original  : p=4.401e-03 NOT normal
# peakTime        gamma     : p=8.204e-05 NOT normal
# peakTime        weibull   : p=8.578e-05 NOT normal
# peakTime        boxcox    : p=4.607e-03 NOT normal
# peakTime        lognorm   : p=8.038e-05 NOT normal
# peakTime        student_t : p=7.828e-05 NOT normal
# peakTime        yeojohnson: p=4.597e-03 NOT normal
# peakTime        log       : p=3.985e-03 NOT normal
# peakTime        sqrt      : p=4.584e-03 NOT normal
# peakTime        zscore    : p=4.401e-03 NOT normal
# peakTime        minmax    : p=4.401e-03 NOT normal
# peakTime        quantile  : p=1.377e-04 NOT normal
# peakTime        power     : p=4.597e-03 NOT normal
# difference      original  : p=5.350e-03 NOT normal
# difference      gamma     : p=8.983e-05 NOT normal
# difference      weibull   : p=9.228e-05 NOT normal
# difference      boxcox    : p=5.540e-03 NOT normal
# difference      lognorm   : p=8.785e-05 NOT normal
# difference      student_t : p=8.435e-05 NOT normal
# difference      yeojohnson: p=5.528e-03 NOT normal
# difference      log       : p=4.442e-03 NOT normal
# difference      sqrt      : p=5.437e-03 NOT normal
# difference      zscore    : p=5.350e-03 NOT normal
# difference      minmax    : p=5.350e-03 NOT normal
# difference      quantile  : p=1.343e-04 NOT normal
# difference      power     : p=5.528e-03 NOT normal
# peakValue       original  : p=1.851e-01 normal
# peakValue       gamma     : p=1.235e-03 NOT normal
# peakValue       weibull   : p=4.387e-03 NOT normal
# peakValue       boxcox    : p=2.238e-01 normal
# peakValue       lognorm   : p=8.953e-04 NOT normal
# peakValue       student_t : p=2.009e-03 NOT normal
# peakValue       yeojohnson: p=2.242e-01 normal
# peakValue       log       : p=3.685e-02 NOT normal
# peakValue       sqrt      : p=9.863e-02 normal
# peakValue       zscore    : p=1.851e-01 normal
# peakValue       minmax    : p=1.851e-01 normal
# peakValue       quantile  : p=2.330e-04 NOT normal
# peakValue       power     : p=2.242e-01 normal
# PTPA            original  : p=2.516e-01 normal
# PTPA            gamma     : p=2.009e-03 NOT normal
# PTPA            weibull   : p=6.650e-03 NOT normal
# PTPA            boxcox    : p=2.760e-01 normal
# PTPA            lognorm   : p=1.480e-03 NOT normal
# PTPA            student_t : p=3.148e-03 NOT normal
# PTPA            yeojohnson: p=2.763e-01 normal
# PTPA            log       : p=5.743e-02 normal
# PTPA            sqrt      : p=1.455e-01 normal
# PTPA            zscore    : p=2.516e-01 normal
# PTPA            minmax    : p=2.516e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=2.763e-01 normal
# PTTA            original  : p=4.074e-01 normal
# PTTA            gamma     : p=3.610e-03 NOT normal
# PTTA            weibull   : p=1.328e-02 NOT normal
# PTTA            boxcox    : p=5.304e-01 normal
# PTTA            lognorm   : p=2.601e-03 NOT normal
# PTTA            student_t : p=5.890e-03 NOT normal
# PTTA            yeojohnson: p=5.311e-01 normal
# PTTA            log       : p=5.353e-02 normal
# PTTA            sqrt      : p=1.865e-01 normal
# PTTA            zscore    : p=4.074e-01 normal
# PTTA            minmax    : p=4.074e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=5.311e-01 normal
# RMS             original  : p=4.623e-02 NOT normal
# RMS             gamma     : p=3.507e-04 NOT normal
# RMS             weibull   : p=6.967e-04 NOT normal
# RMS             boxcox    : p=8.262e-02 normal
# RMS             lognorm   : p=2.860e-04 NOT normal
# RMS             student_t : p=4.591e-04 NOT normal
# RMS             yeojohnson: p=8.345e-02 normal
# RMS             log       : p=7.358e-03 NOT normal
# RMS             sqrt      : p=2.120e-02 NOT normal
# RMS             zscore    : p=4.623e-02 NOT normal
# RMS             minmax    : p=4.623e-02 NOT normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=8.345e-02 normal
# tau             original  : p=1.045e-15 NOT normal
# tau             student_t : p=3.249e-03 NOT normal
# tau             yeojohnson: p=2.638e-15 NOT normal
# tau             zscore    : p=1.045e-15 NOT normal
# tau             minmax    : p=1.045e-15 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=2.638e-15 NOT normal
# AUC             original  : p=2.941e-01 normal
# AUC             gamma     : p=1.807e-03 NOT normal
# AUC             weibull   : p=6.965e-03 NOT normal
# AUC             boxcox    : p=3.981e-01 normal
# AUC             lognorm   : p=1.109e-03 NOT normal
# AUC             student_t : p=3.616e-03 NOT normal
# AUC             yeojohnson: p=3.982e-01 normal
# AUC             log       : p=1.916e-02 NOT normal
# AUC             sqrt      : p=1.056e-01 normal
# AUC             zscore    : p=2.941e-01 normal
# AUC             minmax    : p=2.941e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=3.982e-01 normal

# %% [markdown]
# ### ---> Box-Cox could work, especially for strength metrics which are already closer to normality by default

# %%
from scipy.stats import boxcox, shapiro
import numpy as np

df = dfs['RESULTS_MERGED']
metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

print("\nBox-Cox normality results (split by sex and date):")
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        for metric in metrics:
            vals = pd.to_numeric(df[(df['sex'] == sex) & (df['date'] == date)][metric], errors='coerce').dropna()
            # Box-Cox requires all values > 0 and at least 3 samples
            if len(vals) > 2 and (vals > 0).all():
                transformed, _ = boxcox(vals)
                stat, p = shapiro(transformed)
                print(f"{metric:15}: p={p:.3e} {'normal' if p > 0.05 else 'NOT normal'}")
            else:
                print(f"{metric:15}: Not enough data or non-positive values")
# Out:
# Box-Cox normality results (split by sex and date):
#
# Sex: female, Date: April16
# reactionTime   : p=1.000e+00 normal
# peakTime       : p=3.439e-03 NOT normal
# difference     : p=3.567e-03 NOT normal
# peakValue      : p=1.034e-01 normal
# PTPA           : p=2.462e-01 normal
# PTTA           : p=2.374e-01 normal
# RMS            : p=3.634e-02 NOT normal
# tau            : p=4.247e-01 normal
# AUC            : p=1.043e-01 normal
#
# Sex: female, Date: June26
# reactionTime   : p=1.000e+00 normal
# peakTime       : p=4.454e-02 NOT normal
# difference     : p=5.311e-02 normal
# peakValue      : p=1.588e-01 normal
# PTPA           : p=1.164e-01 normal
# PTTA           : p=1.312e-02 NOT normal
# RMS            : p=1.012e-01 normal
# tau            : p=7.374e-01 normal
# AUC            : p=3.924e-01 normal
#
# Sex: female, Date: May20
# reactionTime   : p=1.069e-15 NOT normal
# peakTime       : p=1.185e-02 NOT normal
# difference     : p=7.479e-03 NOT normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# peakValue      : p=1.124e-01 normal
# PTPA           : p=6.289e-02 normal
# PTTA           : p=6.534e-02 normal
# RMS            : p=1.758e-01 normal
# tau            : p=8.921e-01 normal
# AUC            : p=5.199e-01 normal
#
# Sex: male, Date: April16
# reactionTime   : p=1.468e-13 NOT normal
# peakTime       : p=3.301e-02 NOT normal
# difference     : p=3.642e-02 NOT normal
# peakValue      : p=7.120e-01 normal
# PTPA           : p=8.768e-01 normal
# PTTA           : p=9.744e-01 normal
# RMS            : p=3.167e-01 normal
# tau            : p=1.968e-01 normal
# AUC            : p=3.564e-01 normal
#
# Sex: male, Date: June26
# reactionTime   : p=1.000e+00 normal
# peakTime       : p=1.541e-01 normal
# difference     : p=2.378e-01 normal
# peakValue      : p=1.120e-02 NOT normal
# PTPA           : p=6.233e-03 NOT normal
# PTTA           : p=8.150e-03 NOT normal
# RMS            : p=1.221e-03 NOT normal
# tau            : p=3.831e-01 normal
# AUC            : p=4.200e-03 NOT normal
#
# Sex: male, Date: May20
# reactionTime   : p=2.630e-14 NOT normal
# peakTime       : p=4.607e-03 NOT normal
# difference     : p=5.540e-03 NOT normal
# peakValue      : p=2.238e-01 normal
# PTPA           : p=2.760e-01 normal
# PTTA           : p=5.304e-01 normal
# RMS            : p=8.262e-02 normal
# tau            : Not enough data or non-positive values
# AUC            : p=3.981e-01 normal

# %% [markdown]
# ### ---> not great, use non-parametric tests instead

# %% [markdown]
# ---

# %% [markdown]
# ## Uniformity

# %%
from scipy.stats import kstest

metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
        for metric in metrics:
            vals = pd.to_numeric(df_sub[metric], errors='coerce').dropna()
            if len(vals) > 2:
                stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
            else:
                print(f"{metric}: Not enough data")
# Out:
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.333, p=7.512e-06 NOT uniform
# difference: KS stat=0.325, p=1.415e-05 NOT uniform
# peakValue: KS stat=0.194, p=2.904e-02 NOT uniform
# PTPA: KS stat=0.171, p=7.384e-02 uniform
# PTTA: KS stat=0.205, p=1.855e-02 NOT uniform
# RMS: KS stat=0.132, p=2.781e-01 uniform
# tau: KS stat=0.236, p=4.008e-03 NOT uniform
# AUC: KS stat=0.159, p=1.153e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.283, p=2.589e-04 NOT uniform
# difference: KS stat=0.283, p=2.589e-04 NOT uniform
# peakValue: KS stat=0.143, p=2.012e-01 uniform
# PTPA: KS stat=0.132, p=2.785e-01 uniform
# PTTA: KS stat=0.171, p=7.538e-02 uniform
# RMS: KS stat=0.167, p=8.583e-02 uniform
# tau: KS stat=0.116, p=4.297e-01 uniform
# AUC: KS stat=0.128, p=3.141e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.292, p=1.420e-04 NOT uniform
# difference: KS stat=0.292, p=1.420e-04 NOT uniform
# peakValue: KS stat=0.126, p=3.335e-01 uniform
# PTPA: KS stat=0.121, p=3.803e-01 uniform
# PTTA: KS stat=0.125, p=3.398e-01 uniform
# RMS: KS stat=0.142, p=2.027e-01 uniform
# tau: KS stat=0.165, p=9.473e-02 uniform
# AUC: KS stat=0.186, p=4.162e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.131, p=2.891e-01 uniform
# difference: KS stat=0.141, p=2.139e-01 uniform
# peakValue: KS stat=0.129, p=3.058e-01 uniform
# PTPA: KS stat=0.127, p=3.212e-01 uniform
# PTTA: KS stat=0.142, p=2.075e-01 uniform
# RMS: KS stat=0.164, p=9.618e-02 uniform
# tau: KS stat=0.598, p=5.309e-19 NOT uniform
# AUC: KS stat=0.186, p=4.194e-02 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.408, p=1.246e-08 NOT uniform
# difference: KS stat=0.394, p=4.751e-08 NOT uniform
# peakValue: KS stat=0.163, p=9.974e-02 uniform
# PTPA: KS stat=0.206, p=1.697e-02 NOT uniform
# PTTA: KS stat=0.246, p=2.328e-03 NOT uniform
# RMS: KS stat=0.144, p=1.929e-01 uniform
# tau: KS stat=0.304, p=6.186e-05 NOT uniform
# AUC: KS stat=0.099, p=6.231e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.113, p=4.612e-01 uniform
# difference: KS stat=0.113, p=4.612e-01 uniform
# peakValue: KS stat=0.141, p=2.100e-01 uniform
# PTPA: KS stat=0.136, p=2.447e-01 uniform
# PTTA: KS stat=0.159, p=1.154e-01 uniform
# RMS: KS stat=0.126, p=3.258e-01 uniform
# tau: KS stat=0.734, p=3.028e-30 NOT uniform
# AUC: KS stat=0.149, p=1.615e-01 uniform

# %% [markdown]
# ### ---> not too uniform

# %%
from scipy.stats import gamma, weibull_min, boxcox, lognorm, t, kstest, yeojohnson
import numpy as np
import pandas as pd

try:
    from sklearn.preprocessing import QuantileTransformer, PowerTransformer
    sklearn_available = True
except ImportError:
    sklearn_available = False

df = dfs['RESULTS_MERGED']
metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

def test_uniformity_grouped(transform_func, df, metrics, label):
    print(f"\n{label} transformation (grouped by sex and date):")
    for sex in df['sex'].unique():
        for date in df['date'].unique():
            df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
            if len(df_sub) < 3:
                continue
            transformed = transform_func(df_sub, metrics)
            print(f"\nSex: {sex}, Date: {date}")
            for metric in metrics:
                vals = pd.to_numeric(transformed[metric], errors='coerce').dropna()
                if len(vals) > 2:
                    stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                    print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
                else:
                    print(f"{metric}: Not enough data")

def gamma_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals > 0).all():
            params = gamma.fit(vals, floc=0)
            df_copy[metric] = gamma.cdf(pd.to_numeric(df_copy[metric], errors='coerce'), *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def weibull_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            params = weibull_min.fit(vals, floc=0)
            df_copy[metric] = weibull_min.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def boxcox_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            transformed, _ = boxcox(vals)
            df_copy.loc[vals.index, metric] = transformed
        else:
            df_copy[metric] = np.nan
    return df_copy

def lognorm_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            params = lognorm.fit(vals, floc=0)
            df_copy[metric] = lognorm.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def student_t_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2:
            params = t.fit(vals)
            df_copy[metric] = t.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def yeojohnson_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            transformed, _ = yeojohnson(vals)
            df_copy.loc[vals.index, metric] = transformed
        else:
            df_copy[metric] = np.nan
    return df_copy

def log_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals > 0).all():
            df_copy.loc[vals.index, metric] = np.log(vals + 1e-6)
        else:
            df_copy[metric] = np.nan
    return df_copy

def sqrt_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals >= 0).all():
            df_copy.loc[vals.index, metric] = np.sqrt(vals)
        else:
            df_copy[metric] = np.nan
    return df_copy

def zscore_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            df_copy.loc[vals.index, metric] = (vals - vals.mean()) / (vals.std() + 1e-8)
        else:
            df_copy[metric] = np.nan
    return df_copy

def minmax_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            df_copy.loc[vals.index, metric] = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
        else:
            df_copy[metric] = np.nan
    return df_copy

if sklearn_available:
    def quantile_transform(df, metrics):
        df_copy = df.copy()
        qt = QuantileTransformer(output_distribution='uniform', random_state=0)
        for metric in metrics:
            vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna().values.reshape(-1, 1)
            if len(vals) > 2:
                transformed = qt.fit_transform(vals).flatten()
                df_copy.loc[df_copy[metric].dropna().index, metric] = transformed
            else:
                df_copy[metric] = np.nan
        return df_copy

    def power_transform(df, metrics):
        df_copy = df.copy()
        pt = PowerTransformer(method='yeo-johnson')
        for metric in metrics:
            vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna().values.reshape(-1, 1)
            if len(vals) > 2:
                transformed = pt.fit_transform(vals).flatten()
                df_copy.loc[df_copy[metric].dropna().index, metric] = transformed
            else:
                df_copy[metric] = np.nan
        return df_copy

# Run all transformations grouped by sex and date
test_uniformity_grouped(gamma_transform, df, metrics, "Gamma")
test_uniformity_grouped(weibull_transform, df, metrics, "Weibull")
test_uniformity_grouped(boxcox_transform, df, metrics, "Box-Cox")
test_uniformity_grouped(lognorm_transform, df, metrics, "Lognormal")
test_uniformity_grouped(student_t_transform, df, metrics, "Student-t")
test_uniformity_grouped(yeojohnson_transform, df, metrics, "Yeo-Johnson")
test_uniformity_grouped(log_transform, df, metrics, "Log")
test_uniformity_grouped(sqrt_transform, df, metrics, "Sqrt")
test_uniformity_grouped(zscore_transform, df, metrics, "Z-score")
test_uniformity_grouped(minmax_transform, df, metrics, "Min-max")

if sklearn_available:
    test_uniformity_grouped(quantile_transform, df, metrics, "Quantile (uniform)")
    test_uniformity_grouped(power_transform, df, metrics, "Power (Yeo-Johnson, sklearn)")
else:
    print("\nscikit-learn not available: skipping quantile and power transforms.")
# Out:
# Gamma transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.212, p=1.296e-02 NOT uniform
# difference: KS stat=0.214, p=1.205e-02 NOT uniform
# peakValue: KS stat=0.123, p=3.619e-01 uniform
# PTPA: KS stat=0.123, p=3.559e-01 uniform
# PTTA: KS stat=0.117, p=4.165e-01 uniform
# RMS: KS stat=0.145, p=1.876e-01 uniform
# tau: KS stat=0.148, p=1.724e-01 uniform
# AUC: KS stat=0.146, p=1.791e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.236, p=3.872e-03 NOT uniform
# difference: KS stat=0.204, p=1.871e-02 NOT uniform
# peakValue: KS stat=0.156, p=1.292e-01 uniform
# PTPA: KS stat=0.149, p=1.642e-01 uniform
# PTTA: KS stat=0.199, p=2.361e-02 NOT uniform
# RMS: KS stat=0.170, p=7.775e-02 uniform
# tau: KS stat=0.115, p=4.383e-01 uniform
# AUC: KS stat=0.082, p=8.352e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.202, p=2.125e-02 NOT uniform
# difference: KS stat=0.193, p=3.053e-02 NOT uniform
# peakValue: KS stat=0.152, p=1.506e-01 uniform
# PTPA: KS stat=0.169, p=8.238e-02 uniform
# PTTA: KS stat=0.180, p=5.221e-02 uniform
# RMS: KS stat=0.156, p=1.279e-01 uniform
# tau: KS stat=0.082, p=8.281e-01 uniform
# AUC: KS stat=0.091, p=7.261e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.100, p=6.197e-01 uniform
# PTPA: KS stat=0.078, p=8.720e-01 uniform
# PTTA: KS stat=0.096, p=6.666e-01 uniform
# RMS: KS stat=0.145, p=1.846e-01 uniform
# tau: KS stat=0.091, p=7.244e-01 uniform
# AUC: KS stat=0.112, p=4.772e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.178, p=5.796e-02 uniform
# difference: KS stat=0.161, p=1.103e-01 uniform
# peakValue: KS stat=0.206, p=1.711e-02 NOT uniform
# PTPA: KS stat=0.202, p=2.107e-02 NOT uniform
# PTTA: KS stat=0.185, p=4.407e-02 NOT uniform
# RMS: KS stat=0.240, p=3.220e-03 NOT uniform
# tau: KS stat=0.082, p=8.356e-01 uniform
# AUC: KS stat=0.187, p=3.928e-02 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.174, p=6.587e-02 uniform
# difference: KS stat=0.178, p=5.716e-02 uniform
# peakValue: KS stat=0.150, p=1.610e-01 uniform
# PTPA: KS stat=0.141, p=2.139e-01 uniform
# PTTA: KS stat=0.104, p=5.660e-01 uniform
# RMS: KS stat=0.162, p=1.054e-01 uniform
# tau: Not enough data
# AUC: KS stat=0.149, p=1.635e-01 uniform
#
# Weibull transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.174, p=6.717e-02 uniform
# difference: KS stat=0.171, p=7.451e-02 uniform
# peakValue: KS stat=0.131, p=2.837e-01 uniform
# PTPA: KS stat=0.129, p=2.996e-01 uniform
# PTTA: KS stat=0.123, p=3.548e-01 uniform
# RMS: KS stat=0.138, p=2.358e-01 uniform
# tau: KS stat=0.121, p=3.790e-01 uniform
# AUC: KS stat=0.127, p=3.169e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.142, p=2.045e-01 uniform
# difference: KS stat=0.143, p=2.018e-01 uniform
# peakValue: KS stat=0.115, p=4.385e-01 uniform
# PTPA: KS stat=0.124, p=3.517e-01 uniform
# PTTA: KS stat=0.130, p=2.916e-01 uniform
# RMS: KS stat=0.109, p=5.057e-01 uniform
# tau: KS stat=0.079, p=8.644e-01 uniform
# AUC: KS stat=0.081, p=8.406e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.144, p=1.931e-01 uniform
# difference: KS stat=0.161, p=1.085e-01 uniform
# peakValue: KS stat=0.094, p=6.862e-01 uniform
# PTPA: KS stat=0.116, p=4.292e-01 uniform
# PTTA: KS stat=0.138, p=2.351e-01 uniform
# RMS: KS stat=0.094, p=6.950e-01 uniform
# tau: KS stat=0.084, p=8.126e-01 uniform
# AUC: KS stat=0.116, p=4.340e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.137, p=2.382e-01 uniform
# difference: KS stat=0.139, p=2.276e-01 uniform
# peakValue: KS stat=0.080, p=8.478e-01 uniform
# PTPA: KS stat=0.109, p=5.070e-01 uniform
# PTTA: KS stat=0.068, p=9.503e-01 uniform
# RMS: KS stat=0.094, p=6.933e-01 uniform
# tau: KS stat=0.172, p=7.208e-02 uniform
# AUC: KS stat=0.108, p=5.206e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.195, p=2.831e-02 NOT uniform
# difference: KS stat=0.183, p=4.685e-02 NOT uniform
# peakValue: KS stat=0.177, p=5.928e-02 uniform
# PTPA: KS stat=0.187, p=4.042e-02 NOT uniform
# PTTA: KS stat=0.183, p=4.743e-02 NOT uniform
# RMS: KS stat=0.207, p=1.641e-02 NOT uniform
# tau: KS stat=0.103, p=5.756e-01 uniform
# AUC: KS stat=0.176, p=6.124e-02 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.180, p=5.210e-02 uniform
# difference: KS stat=0.178, p=5.722e-02 uniform
# peakValue: KS stat=0.108, p=5.142e-01 uniform
# PTPA: KS stat=0.098, p=6.419e-01 uniform
# PTTA: KS stat=0.096, p=6.689e-01 uniform
# RMS: KS stat=0.106, p=5.477e-01 uniform
# tau: Not enough data
# AUC: KS stat=0.083, p=8.220e-01 uniform
#
# Box-Cox transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=nan, p=nan NOT uniform
# peakTime: KS stat=0.172, p=7.255e-02 uniform
# difference: KS stat=0.169, p=8.144e-02 uniform
# peakValue: KS stat=0.221, p=8.433e-03 NOT uniform
# PTPA: KS stat=0.182, p=4.802e-02 NOT uniform
# PTTA: KS stat=0.178, p=5.758e-02 uniform
# RMS: KS stat=0.176, p=6.189e-02 uniform
# tau: KS stat=0.235, p=4.084e-03 NOT uniform
# AUC: KS stat=0.156, p=1.290e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=nan, p=nan NOT uniform
# peakTime: KS stat=0.148, p=1.686e-01 uniform
# difference: KS stat=0.141, p=2.129e-01 uniform
# peakValue: KS stat=0.116, p=4.317e-01 uniform
# PTPA: KS stat=0.096, p=6.619e-01 uniform
# PTTA: KS stat=0.105, p=5.553e-01 uniform
# RMS: KS stat=0.123, p=3.610e-01 uniform
# tau: KS stat=0.138, p=2.305e-01 uniform
# AUC: KS stat=0.172, p=7.107e-02 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2148: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2148: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# peakTime: KS stat=0.270, p=5.649e-04 NOT uniform
# difference: KS stat=0.281, p=2.891e-04 NOT uniform
# peakValue: KS stat=0.132, p=2.805e-01 uniform
# PTPA: KS stat=0.145, p=1.877e-01 uniform
# PTTA: KS stat=0.143, p=1.988e-01 uniform
# RMS: KS stat=0.101, p=6.006e-01 uniform
# tau: KS stat=0.181, p=5.081e-02 uniform
# AUC: KS stat=0.141, p=2.108e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.120, p=3.833e-01 uniform
# PTPA: KS stat=0.127, p=3.181e-01 uniform
# PTTA: KS stat=0.141, p=2.133e-01 uniform
# RMS: KS stat=0.141, p=2.125e-01 uniform
# tau: KS stat=0.308, p=4.884e-05 NOT uniform
# AUC: KS stat=0.227, p=6.244e-03 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=nan, p=nan NOT uniform
# peakTime: KS stat=0.183, p=4.754e-02 NOT uniform
# difference: KS stat=0.173, p=7.101e-02 uniform
# peakValue: KS stat=0.150, p=1.615e-01 uniform
# PTPA: KS stat=0.199, p=2.394e-02 NOT uniform
# PTTA: KS stat=0.225, p=7.088e-03 NOT uniform
# RMS: KS stat=0.149, p=1.634e-01 uniform
# tau: KS stat=0.285, p=2.243e-04 NOT uniform
# AUC: KS stat=0.100, p=6.129e-01 uniform
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2148: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.129, p=3.047e-01 uniform
# difference: KS stat=0.129, p=3.016e-01 uniform
# peakValue: KS stat=0.160, p=1.112e-01 uniform
# PTPA: KS stat=0.147, p=1.778e-01 uniform
# PTTA: KS stat=0.185, p=4.280e-02 NOT uniform
# RMS: KS stat=0.106, p=5.463e-01 uniform
# tau: Not enough data
# AUC: KS stat=0.107, p=5.288e-01 uniform
#
# Lognormal transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.217, p=1.051e-02 NOT uniform
# difference: KS stat=0.218, p=9.612e-03 NOT uniform
# peakValue: KS stat=0.137, p=2.388e-01 uniform
# PTPA: KS stat=0.121, p=3.772e-01 uniform
# PTTA: KS stat=0.115, p=4.452e-01 uniform
# RMS: KS stat=0.163, p=1.007e-01 uniform
# tau: KS stat=0.159, p=1.156e-01 uniform
# AUC: KS stat=0.162, p=1.039e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.249, p=1.911e-03 NOT uniform
# difference: KS stat=0.220, p=8.922e-03 NOT uniform
# peakValue: KS stat=0.171, p=7.587e-02 uniform
# PTPA: KS stat=0.165, p=9.526e-02 uniform
# PTTA: KS stat=0.217, p=1.026e-02 NOT uniform
# RMS: KS stat=0.186, p=4.163e-02 NOT uniform
# tau: KS stat=0.142, p=2.065e-01 uniform
# AUC: KS stat=0.096, p=6.705e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.208, p=1.606e-02 NOT uniform
# difference: KS stat=0.200, p=2.327e-02 NOT uniform
# peakValue: KS stat=0.168, p=8.574e-02 uniform
# PTPA: KS stat=0.183, p=4.658e-02 NOT uniform
# PTTA: KS stat=0.193, p=3.081e-02 NOT uniform
# RMS: KS stat=0.180, p=5.326e-02 uniform
# tau: KS stat=0.099, p=6.261e-01 uniform
# AUC: KS stat=0.095, p=6.822e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.116, p=4.262e-01 uniform
# PTPA: KS stat=0.092, p=7.147e-01 uniform
# PTTA: KS stat=0.115, p=4.390e-01 uniform
# RMS: KS stat=0.157, p=1.261e-01 uniform
# tau: KS stat=0.083, p=8.232e-01 uniform
# AUC: KS stat=0.129, p=2.993e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.173, p=6.965e-02 uniform
# difference: KS stat=0.156, p=1.317e-01 uniform
# peakValue: KS stat=0.238, p=3.565e-03 NOT uniform
# PTPA: KS stat=0.232, p=4.767e-03 NOT uniform
# PTTA: KS stat=0.212, p=1.294e-02 NOT uniform
# RMS: KS stat=0.275, p=4.355e-04 NOT uniform
# tau: KS stat=0.087, p=7.792e-01 uniform
# AUC: KS stat=0.218, p=9.750e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.180, p=5.208e-02 uniform
# difference: KS stat=0.184, p=4.478e-02 NOT uniform
# peakValue: KS stat=0.164, p=9.836e-02 uniform
# PTPA: KS stat=0.156, p=1.308e-01 uniform
# PTTA: KS stat=0.121, p=3.797e-01 uniform
# RMS: KS stat=0.174, p=6.727e-02 uniform
# tau: Not enough data
# AUC: KS stat=0.166, p=8.976e-02 uniform
#
# Student-t transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.204, p=1.945e-02 NOT uniform
# difference: KS stat=0.204, p=1.865e-02 NOT uniform
# peakValue: KS stat=0.128, p=3.119e-01 uniform
# PTPA: KS stat=0.128, p=3.142e-01 uniform
# PTTA: KS stat=0.123, p=3.611e-01 uniform
# RMS: KS stat=0.125, p=3.346e-01 uniform
# tau: KS stat=0.123, p=3.551e-01 uniform
# AUC: KS stat=0.122, p=3.724e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.204, p=1.872e-02 NOT uniform
# difference: KS stat=0.175, p=6.331e-02 uniform
# peakValue: KS stat=0.126, p=3.285e-01 uniform
# PTPA: KS stat=0.121, p=3.814e-01 uniform
# PTTA: KS stat=0.161, p=1.078e-01 uniform
# RMS: KS stat=0.137, p=2.419e-01 uniform
# tau: KS stat=0.073, p=9.167e-01 uniform
# AUC: KS stat=0.090, p=7.405e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.182, p=4.818e-02 NOT uniform
# difference: KS stat=0.181, p=5.093e-02 uniform
# peakValue: KS stat=0.119, p=3.974e-01 uniform
# PTPA: KS stat=0.139, p=2.251e-01 uniform
# PTTA: KS stat=0.155, p=1.339e-01 uniform
# RMS: KS stat=0.117, p=4.232e-01 uniform
# tau: KS stat=0.064, p=9.695e-01 uniform
# AUC: KS stat=0.094, p=6.854e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.921e-01 uniform
# difference: KS stat=0.130, p=2.962e-01 uniform
# peakValue: KS stat=0.084, p=8.070e-01 uniform
# PTPA: KS stat=0.076, p=8.871e-01 uniform
# PTTA: KS stat=0.060, p=9.834e-01 uniform
# RMS: KS stat=0.122, p=3.700e-01 uniform
# tau: KS stat=0.082, p=8.306e-01 uniform
# AUC: KS stat=0.103, p=5.858e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.180, p=5.356e-02 uniform
# difference: KS stat=0.162, p=1.064e-01 uniform
# peakValue: KS stat=0.179, p=5.572e-02 uniform
# PTPA: KS stat=0.188, p=3.881e-02 NOT uniform
# PTTA: KS stat=0.185, p=4.367e-02 NOT uniform
# RMS: KS stat=0.208, p=1.590e-02 NOT uniform
# tau: KS stat=0.071, p=9.325e-01 uniform
# AUC: KS stat=0.176, p=6.253e-02 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.162, p=1.041e-01 uniform
# difference: KS stat=0.166, p=9.170e-02 uniform
# peakValue: KS stat=0.121, p=3.813e-01 uniform
# PTPA: KS stat=0.110, p=4.924e-01 uniform
# PTTA: KS stat=0.084, p=8.142e-01 uniform
# RMS: KS stat=0.137, p=2.394e-01 uniform
# tau: KS stat=0.113, p=4.611e-01 uniform
# AUC: KS stat=0.114, p=4.490e-01 uniform
#
# Yeo-Johnson transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.172, p=7.299e-02 uniform
# difference: KS stat=0.169, p=8.190e-02 uniform
# peakValue: KS stat=0.222, p=8.243e-03 NOT uniform
# PTPA: KS stat=0.183, p=4.730e-02 NOT uniform
# PTTA: KS stat=0.178, p=5.687e-02 uniform
# RMS: KS stat=0.178, p=5.750e-02 uniform
# tau: KS stat=0.236, p=4.025e-03 NOT uniform
# AUC: KS stat=0.156, p=1.290e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.148, p=1.710e-01 uniform
# difference: KS stat=0.141, p=2.146e-01 uniform
# peakValue: KS stat=0.116, p=4.270e-01 uniform
# PTPA: KS stat=0.097, p=6.579e-01 uniform
# PTTA: KS stat=0.104, p=5.661e-01 uniform
# RMS: KS stat=0.121, p=3.793e-01 uniform
# tau: KS stat=0.138, p=2.343e-01 uniform
# AUC: KS stat=0.172, p=7.112e-02 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.270, p=5.577e-04 NOT uniform
# difference: KS stat=0.281, p=2.835e-04 NOT uniform
# peakValue: KS stat=0.132, p=2.764e-01 uniform
# PTPA: KS stat=0.145, p=1.846e-01 uniform
# PTTA: KS stat=0.144, p=1.957e-01 uniform
# RMS: KS stat=0.099, p=6.257e-01 uniform
# tau: KS stat=0.181, p=5.112e-02 uniform
# AUC: KS stat=0.141, p=2.107e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.120, p=3.854e-01 uniform
# PTPA: KS stat=0.127, p=3.199e-01 uniform
# PTTA: KS stat=0.141, p=2.142e-01 uniform
# RMS: KS stat=0.140, p=2.174e-01 uniform
# tau: KS stat=0.307, p=5.170e-05 NOT uniform
# AUC: KS stat=0.227, p=6.247e-03 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.183, p=4.725e-02 NOT uniform
# difference: KS stat=0.173, p=7.062e-02 uniform
# peakValue: KS stat=0.150, p=1.596e-01 uniform
# PTPA: KS stat=0.199, p=2.358e-02 NOT uniform
# PTTA: KS stat=0.225, p=6.988e-03 NOT uniform
# RMS: KS stat=0.150, p=1.565e-01 uniform
# tau: KS stat=0.285, p=2.213e-04 NOT uniform
# AUC: KS stat=0.100, p=6.130e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.128, p=3.102e-01 uniform
# difference: KS stat=0.128, p=3.079e-01 uniform
# peakValue: KS stat=0.161, p=1.105e-01 uniform
# PTPA: KS stat=0.147, p=1.769e-01 uniform
# PTTA: KS stat=0.185, p=4.251e-02 NOT uniform
# RMS: KS stat=0.106, p=5.393e-01 uniform
# tau: KS stat=0.540, p=2.829e-15 NOT uniform
# AUC: KS stat=0.107, p=5.288e-01 uniform
#
# Log transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.372, p=3.183e-07 NOT uniform
# difference: KS stat=0.367, p=5.039e-07 NOT uniform
# peakValue: KS stat=0.139, p=2.257e-01 uniform
# PTPA: KS stat=0.132, p=2.744e-01 uniform
# PTTA: KS stat=0.133, p=2.706e-01 uniform
# RMS: KS stat=0.179, p=5.524e-02 uniform
# tau: KS stat=0.184, p=4.525e-02 NOT uniform
# AUC: KS stat=0.249, p=1.903e-03 NOT uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.358, p=1.036e-06 NOT uniform
# difference: KS stat=0.365, p=5.848e-07 NOT uniform
# peakValue: KS stat=0.262, p=9.153e-04 NOT uniform
# PTPA: KS stat=0.255, p=1.393e-03 NOT uniform
# PTTA: KS stat=0.282, p=2.652e-04 NOT uniform
# RMS: KS stat=0.300, p=8.536e-05 NOT uniform
# tau: KS stat=0.241, p=3.029e-03 NOT uniform
# AUC: KS stat=0.226, p=6.552e-03 NOT uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.336, p=6.314e-06 NOT uniform
# difference: KS stat=0.339, p=4.877e-06 NOT uniform
# peakValue: KS stat=0.254, p=1.472e-03 NOT uniform
# PTPA: KS stat=0.229, p=5.828e-03 NOT uniform
# PTTA: KS stat=0.262, p=9.009e-04 NOT uniform
# RMS: KS stat=0.279, p=3.388e-04 NOT uniform
# tau: KS stat=0.285, p=2.191e-04 NOT uniform
# AUC: KS stat=0.184, p=4.515e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.237, p=3.730e-03 NOT uniform
# PTPA: KS stat=0.231, p=5.259e-03 NOT uniform
# PTTA: KS stat=0.270, p=5.626e-04 NOT uniform
# RMS: KS stat=0.275, p=4.097e-04 NOT uniform
# tau: KS stat=0.399, p=2.782e-08 NOT uniform
# AUC: KS stat=0.335, p=6.864e-06 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.330, p=9.893e-06 NOT uniform
# difference: KS stat=0.305, p=5.905e-05 NOT uniform
# peakValue: KS stat=0.243, p=2.726e-03 NOT uniform
# PTPA: KS stat=0.224, p=7.491e-03 NOT uniform
# PTTA: KS stat=0.178, p=5.630e-02 uniform
# RMS: KS stat=0.285, p=2.287e-04 NOT uniform
# tau: KS stat=0.398, p=3.131e-08 NOT uniform
# AUC: KS stat=0.238, p=3.648e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.167, p=8.780e-02 uniform
# difference: KS stat=0.173, p=7.098e-02 uniform
# peakValue: KS stat=0.201, p=2.222e-02 NOT uniform
# PTPA: KS stat=0.155, p=1.361e-01 uniform
# PTTA: KS stat=0.150, p=1.610e-01 uniform
# RMS: KS stat=0.209, p=1.517e-02 NOT uniform
# tau: Not enough data
# AUC: KS stat=0.270, p=5.684e-04 NOT uniform
#
# Sqrt transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.353, p=1.622e-06 NOT uniform
# difference: KS stat=0.346, p=2.834e-06 NOT uniform
# peakValue: KS stat=0.166, p=9.077e-02 uniform
# PTPA: KS stat=0.143, p=1.983e-01 uniform
# PTTA: KS stat=0.167, p=8.739e-02 uniform
# RMS: KS stat=0.135, p=2.526e-01 uniform
# tau: KS stat=0.193, p=3.142e-02 NOT uniform
# AUC: KS stat=0.204, p=1.926e-02 NOT uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.321, p=1.953e-05 NOT uniform
# difference: KS stat=0.324, p=1.518e-05 NOT uniform
# peakValue: KS stat=0.201, p=2.156e-02 NOT uniform
# PTPA: KS stat=0.193, p=3.035e-02 NOT uniform
# PTTA: KS stat=0.227, p=6.219e-03 NOT uniform
# RMS: KS stat=0.233, p=4.680e-03 NOT uniform
# tau: KS stat=0.166, p=9.205e-02 uniform
# AUC: KS stat=0.163, p=1.023e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.314, p=3.208e-05 NOT uniform
# difference: KS stat=0.315, p=2.850e-05 NOT uniform
# peakValue: KS stat=0.189, p=3.717e-02 NOT uniform
# PTPA: KS stat=0.164, p=9.581e-02 uniform
# PTTA: KS stat=0.191, p=3.324e-02 NOT uniform
# RMS: KS stat=0.209, p=1.497e-02 NOT uniform
# tau: KS stat=0.219, p=9.516e-03 NOT uniform
# AUC: KS stat=0.122, p=3.637e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.181, p=5.019e-02 uniform
# PTPA: KS stat=0.174, p=6.615e-02 uniform
# PTTA: KS stat=0.205, p=1.850e-02 NOT uniform
# RMS: KS stat=0.218, p=9.611e-03 NOT uniform
# tau: KS stat=0.501, p=4.522e-13 NOT uniform
# AUC: KS stat=0.256, p=1.301e-03 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.369, p=4.264e-07 NOT uniform
# difference: KS stat=0.349, p=2.154e-06 NOT uniform
# peakValue: KS stat=0.168, p=8.401e-02 uniform
# PTPA: KS stat=0.156, p=1.276e-01 uniform
# PTTA: KS stat=0.193, p=3.094e-02 NOT uniform
# RMS: KS stat=0.211, p=1.396e-02 NOT uniform
# tau: KS stat=0.350, p=1.978e-06 NOT uniform
# AUC: KS stat=0.167, p=8.643e-02 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.139, p=2.244e-01 uniform
# difference: KS stat=0.142, p=2.066e-01 uniform
# peakValue: KS stat=0.156, p=1.292e-01 uniform
# PTPA: KS stat=0.112, p=4.685e-01 uniform
# PTTA: KS stat=0.123, p=3.592e-01 uniform
# RMS: KS stat=0.168, p=8.354e-02 uniform
# tau: Not enough data
# AUC: KS stat=0.210, p=1.458e-02 NOT uniform
#
# Z-score transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.333, p=7.512e-06 NOT uniform
# difference: KS stat=0.325, p=1.415e-05 NOT uniform
# peakValue: KS stat=0.194, p=2.904e-02 NOT uniform
# PTPA: KS stat=0.171, p=7.384e-02 uniform
# PTTA: KS stat=0.205, p=1.855e-02 NOT uniform
# RMS: KS stat=0.132, p=2.781e-01 uniform
# tau: KS stat=0.236, p=4.008e-03 NOT uniform
# AUC: KS stat=0.159, p=1.153e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.283, p=2.589e-04 NOT uniform
# difference: KS stat=0.283, p=2.589e-04 NOT uniform
# peakValue: KS stat=0.143, p=2.012e-01 uniform
# PTPA: KS stat=0.132, p=2.785e-01 uniform
# PTTA: KS stat=0.171, p=7.538e-02 uniform
# RMS: KS stat=0.167, p=8.583e-02 uniform
# tau: KS stat=0.116, p=4.297e-01 uniform
# AUC: KS stat=0.128, p=3.141e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.292, p=1.420e-04 NOT uniform
# difference: KS stat=0.292, p=1.420e-04 NOT uniform
# peakValue: KS stat=0.126, p=3.335e-01 uniform
# PTPA: KS stat=0.121, p=3.803e-01 uniform
# PTTA: KS stat=0.125, p=3.398e-01 uniform
# RMS: KS stat=0.142, p=2.027e-01 uniform
# tau: KS stat=0.165, p=9.473e-02 uniform
# AUC: KS stat=0.186, p=4.162e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.131, p=2.891e-01 uniform
# difference: KS stat=0.141, p=2.139e-01 uniform
# peakValue: KS stat=0.129, p=3.058e-01 uniform
# PTPA: KS stat=0.127, p=3.212e-01 uniform
# PTTA: KS stat=0.142, p=2.075e-01 uniform
# RMS: KS stat=0.164, p=9.618e-02 uniform
# tau: KS stat=0.598, p=5.309e-19 NOT uniform
# AUC: KS stat=0.186, p=4.194e-02 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.408, p=1.246e-08 NOT uniform
# difference: KS stat=0.394, p=4.751e-08 NOT uniform
# peakValue: KS stat=0.163, p=9.974e-02 uniform
# PTPA: KS stat=0.206, p=1.697e-02 NOT uniform
# PTTA: KS stat=0.246, p=2.328e-03 NOT uniform
# RMS: KS stat=0.144, p=1.929e-01 uniform
# tau: KS stat=0.304, p=6.186e-05 NOT uniform
# AUC: KS stat=0.099, p=6.231e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.113, p=4.612e-01 uniform
# difference: KS stat=0.113, p=4.612e-01 uniform
# peakValue: KS stat=0.141, p=2.100e-01 uniform
# PTPA: KS stat=0.136, p=2.447e-01 uniform
# PTTA: KS stat=0.159, p=1.154e-01 uniform
# RMS: KS stat=0.126, p=3.258e-01 uniform
# tau: KS stat=0.734, p=3.028e-30 NOT uniform
# AUC: KS stat=0.149, p=1.615e-01 uniform
#
# Min-max transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.333, p=7.512e-06 NOT uniform
# difference: KS stat=0.325, p=1.415e-05 NOT uniform
# peakValue: KS stat=0.194, p=2.904e-02 NOT uniform
# PTPA: KS stat=0.171, p=7.384e-02 uniform
# PTTA: KS stat=0.205, p=1.855e-02 NOT uniform
# RMS: KS stat=0.132, p=2.781e-01 uniform
# tau: KS stat=0.236, p=4.008e-03 NOT uniform
# AUC: KS stat=0.159, p=1.153e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.283, p=2.589e-04 NOT uniform
# difference: KS stat=0.283, p=2.589e-04 NOT uniform
# peakValue: KS stat=0.143, p=2.012e-01 uniform
# PTPA: KS stat=0.132, p=2.785e-01 uniform
# PTTA: KS stat=0.171, p=7.538e-02 uniform
# RMS: KS stat=0.167, p=8.583e-02 uniform
# tau: KS stat=0.116, p=4.297e-01 uniform
# AUC: KS stat=0.128, p=3.141e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.292, p=1.420e-04 NOT uniform
# difference: KS stat=0.292, p=1.420e-04 NOT uniform
# peakValue: KS stat=0.126, p=3.335e-01 uniform
# PTPA: KS stat=0.121, p=3.803e-01 uniform
# PTTA: KS stat=0.125, p=3.398e-01 uniform
# RMS: KS stat=0.142, p=2.027e-01 uniform
# tau: KS stat=0.165, p=9.473e-02 uniform
# AUC: KS stat=0.186, p=4.162e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.131, p=2.891e-01 uniform
# difference: KS stat=0.141, p=2.139e-01 uniform
# peakValue: KS stat=0.129, p=3.058e-01 uniform
# PTPA: KS stat=0.127, p=3.212e-01 uniform
# PTTA: KS stat=0.142, p=2.075e-01 uniform
# RMS: KS stat=0.164, p=9.618e-02 uniform
# tau: KS stat=0.598, p=5.309e-19 NOT uniform
# AUC: KS stat=0.186, p=4.194e-02 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.408, p=1.246e-08 NOT uniform
# difference: KS stat=0.394, p=4.751e-08 NOT uniform
# peakValue: KS stat=0.163, p=9.974e-02 uniform
# PTPA: KS stat=0.206, p=1.697e-02 NOT uniform
# PTTA: KS stat=0.246, p=2.328e-03 NOT uniform
# RMS: KS stat=0.144, p=1.929e-01 uniform
# tau: KS stat=0.304, p=6.186e-05 NOT uniform
# AUC: KS stat=0.099, p=6.231e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.113, p=4.612e-01 uniform
# difference: KS stat=0.113, p=4.612e-01 uniform
# peakValue: KS stat=0.141, p=2.100e-01 uniform
# PTPA: KS stat=0.136, p=2.447e-01 uniform
# PTTA: KS stat=0.159, p=1.154e-01 uniform
# RMS: KS stat=0.126, p=3.258e-01 uniform
# tau: KS stat=0.734, p=3.028e-30 NOT uniform
# AUC: KS stat=0.149, p=1.615e-01 uniform
#
# Quantile (uniform) transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.109, p=5.077e-01 uniform
# difference: KS stat=0.109, p=5.077e-01 uniform
# peakValue: KS stat=0.056, p=9.930e-01 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.057, p=9.913e-01 uniform
# difference: KS stat=0.057, p=9.907e-01 uniform
# peakValue: KS stat=0.034, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.135, p=2.585e-01 uniform
# difference: KS stat=0.135, p=2.585e-01 uniform
# peakValue: KS stat=0.025, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.031, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.021, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.071, p=9.333e-01 uniform
# difference: KS stat=0.071, p=9.333e-01 uniform
# peakValue: KS stat=0.019, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.060, p=9.823e-01 uniform
# difference: KS stat=0.060, p=9.823e-01 uniform
# peakValue: KS stat=0.026, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Power (Yeo-Johnson, sklearn) transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.172, p=7.299e-02 uniform
# difference: KS stat=0.169, p=8.190e-02 uniform
# peakValue: KS stat=0.222, p=8.243e-03 NOT uniform
# PTPA: KS stat=0.183, p=4.730e-02 NOT uniform
# PTTA: KS stat=0.178, p=5.687e-02 uniform
# RMS: KS stat=0.178, p=5.750e-02 uniform
# tau: KS stat=0.236, p=4.025e-03 NOT uniform
# AUC: KS stat=0.156, p=1.290e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.148, p=1.710e-01 uniform
# difference: KS stat=0.141, p=2.146e-01 uniform
# peakValue: KS stat=0.116, p=4.270e-01 uniform
# PTPA: KS stat=0.097, p=6.579e-01 uniform
# PTTA: KS stat=0.104, p=5.661e-01 uniform
# RMS: KS stat=0.121, p=3.793e-01 uniform
# tau: KS stat=0.138, p=2.343e-01 uniform
# AUC: KS stat=0.172, p=7.112e-02 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# peakTime: KS stat=0.270, p=5.577e-04 NOT uniform
# difference: KS stat=0.281, p=2.835e-04 NOT uniform
# peakValue: KS stat=0.132, p=2.764e-01 uniform
# PTPA: KS stat=0.145, p=1.846e-01 uniform
# PTTA: KS stat=0.144, p=1.957e-01 uniform
# RMS: KS stat=0.099, p=6.257e-01 uniform
# tau: KS stat=0.181, p=5.112e-02 uniform
# AUC: KS stat=0.141, p=2.107e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.130, p=2.980e-01 uniform
# difference: KS stat=0.130, p=2.980e-01 uniform
# peakValue: KS stat=0.120, p=3.854e-01 uniform
# PTPA: KS stat=0.127, p=3.199e-01 uniform
# PTTA: KS stat=0.141, p=2.142e-01 uniform
# RMS: KS stat=0.140, p=2.174e-01 uniform
# tau: KS stat=0.307, p=5.170e-05 NOT uniform
# AUC: KS stat=0.227, p=6.247e-03 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.183, p=4.725e-02 NOT uniform
# difference: KS stat=0.173, p=7.062e-02 uniform
# peakValue: KS stat=0.150, p=1.596e-01 uniform
# PTPA: KS stat=0.199, p=2.358e-02 NOT uniform
# PTTA: KS stat=0.225, p=6.988e-03 NOT uniform
# RMS: KS stat=0.150, p=1.565e-01 uniform
# tau: KS stat=0.285, p=2.213e-04 NOT uniform
# AUC: KS stat=0.100, p=6.130e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.128, p=3.102e-01 uniform
# difference: KS stat=0.128, p=3.079e-01 uniform
# peakValue: KS stat=0.161, p=1.105e-01 uniform
# PTPA: KS stat=0.147, p=1.769e-01 uniform
# PTTA: KS stat=0.185, p=4.251e-02 NOT uniform
# RMS: KS stat=0.106, p=5.393e-01 uniform
# tau: KS stat=0.540, p=2.829e-15 NOT uniform
# AUC: KS stat=0.107, p=5.288e-01 uniform

# %% [markdown]
# | Variable        | Most Suitable Fit/Transformation | Generally Good? | Notes                                                      |
# |-----------------|----------------------------------|-----------------|------------------------------------------------------------|
# | peakValue       | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | RMS             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | tau             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | AUC             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | reactionTime    | Quantile (uniform)               | No              | Sometimes uniform, but not consistent across all groups    |
# | peakTime        | No good fit                      | No              | No transformation yields uniformity                        |
# | difference      | Quantile (uniform)               | No              | Sometimes uniform, but not consistent across all groups    |
#
# **Notes:**
# - For strength metrics (peakValue, RMS, tau, AUC), Quantile (uniform) transformation is robust and generally good.
# - For reaction metrics (reactionTime, peakTime, difference), no transformation is consistently good; Quantile (uniform) is the best available for reactionTime and difference, but not reliable.
# - PeakTime cannot be made uniform with any tested transformation.

# %% [markdown]
# ### ---> use quantile

# %% [markdown]
# The Quantile (uniform) transformation maps each value in a variable to its rank in the sorted data, then rescales these ranks to a uniform distribution between 0 and 1. This is done using the empirical cumulative distribution function (ECDF), so the transformed data is evenly spread regardless of the original distribution.
#
# **Effect on analysis:**
# - Makes variables comparable by removing distributional differences.
# - Improves robustness for non-parametric statistics and tests that assume uniformity.
# - Destroys the original scale and spacing, so only rank order is preserved.
# - May obscure biological or experimental meaning if absolute values are important.
#
# Use quantile transformation when you need standardized, comparable variables and distributional assumptions are problematic, but be cautious if the original scale matters for interpretation.

# %%
# Suppress sklearn QuantileTransformer warning by setting n_quantiles to min(n_samples, 1000)
from sklearn.preprocessing import QuantileTransformer

def quantile_fit_df(df):
    df_copy = df.copy()
    numeric_cols = df_copy.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        vals = pd.to_numeric(df_copy[col], errors='coerce').dropna().values.reshape(-1, 1)
        n_samples = len(vals)
        if n_samples > 2:
            qt = QuantileTransformer(output_distribution='uniform', random_state=0, n_quantiles=min(n_samples, 1000))
            transformed = qt.fit_transform(vals).flatten()
            df_copy.loc[df_copy[col].dropna().index, col] = transformed
        else:
            df_copy[col] = np.nan
    return df_copy

""" fit_keys = list(dfs.keys())
for key in fit_keys:
    df = dfs[key]
    dfs[f"{key}_FIT"] = quantile_fit_df(df) """

print(f"Applied quantile fit and saved {len(dfs)} dataframes with '_FIT' suffix.")
# Out:
# Applied quantile fit and saved 13 dataframes with '_FIT' suffix.

# %%
from scipy.stats import kstest

metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
        for metric in metrics:
            vals = pd.to_numeric(df_sub[metric], errors='coerce').dropna()
            if len(vals) > 2:
                stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
            else:
                print(f"{metric}: Not enough data")
# Out:
# Sex: female, Date: April16
# reactionTime: KS stat=0.981, p=5.646e-94 NOT uniform
# peakTime: KS stat=0.333, p=7.512e-06 NOT uniform
# difference: KS stat=0.325, p=1.415e-05 NOT uniform
# peakValue: KS stat=0.194, p=2.904e-02 NOT uniform
# PTPA: KS stat=0.171, p=7.384e-02 uniform
# PTTA: KS stat=0.205, p=1.855e-02 NOT uniform
# RMS: KS stat=0.132, p=2.781e-01 uniform
# tau: KS stat=0.236, p=4.008e-03 NOT uniform
# AUC: KS stat=0.159, p=1.153e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.944, p=3.283e-68 NOT uniform
# peakTime: KS stat=0.283, p=2.589e-04 NOT uniform
# difference: KS stat=0.283, p=2.589e-04 NOT uniform
# peakValue: KS stat=0.143, p=2.012e-01 uniform
# PTPA: KS stat=0.132, p=2.785e-01 uniform
# PTTA: KS stat=0.171, p=7.538e-02 uniform
# RMS: KS stat=0.167, p=8.583e-02 uniform
# tau: KS stat=0.116, p=4.297e-01 uniform
# AUC: KS stat=0.128, p=3.141e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.292, p=1.420e-04 NOT uniform
# difference: KS stat=0.292, p=1.420e-04 NOT uniform
# peakValue: KS stat=0.126, p=3.335e-01 uniform
# PTPA: KS stat=0.121, p=3.803e-01 uniform
# PTTA: KS stat=0.125, p=3.398e-01 uniform
# RMS: KS stat=0.142, p=2.027e-01 uniform
# tau: KS stat=0.165, p=9.473e-02 uniform
# AUC: KS stat=0.186, p=4.162e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.870, p=2.692e-48 NOT uniform
# peakTime: KS stat=0.131, p=2.891e-01 uniform
# difference: KS stat=0.141, p=2.139e-01 uniform
# peakValue: KS stat=0.129, p=3.058e-01 uniform
# PTPA: KS stat=0.127, p=3.212e-01 uniform
# PTTA: KS stat=0.142, p=2.075e-01 uniform
# RMS: KS stat=0.164, p=9.618e-02 uniform
# tau: KS stat=0.598, p=5.309e-19 NOT uniform
# AUC: KS stat=0.186, p=4.194e-02 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.963, p=1.017e-77 NOT uniform
# peakTime: KS stat=0.408, p=1.246e-08 NOT uniform
# difference: KS stat=0.394, p=4.751e-08 NOT uniform
# peakValue: KS stat=0.163, p=9.974e-02 uniform
# PTPA: KS stat=0.206, p=1.697e-02 NOT uniform
# PTTA: KS stat=0.246, p=2.328e-03 NOT uniform
# RMS: KS stat=0.144, p=1.929e-01 uniform
# tau: KS stat=0.304, p=6.186e-05 NOT uniform
# AUC: KS stat=0.099, p=6.231e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.907, p=3.146e-56 NOT uniform
# peakTime: KS stat=0.113, p=4.612e-01 uniform
# difference: KS stat=0.113, p=4.612e-01 uniform
# peakValue: KS stat=0.141, p=2.100e-01 uniform
# PTPA: KS stat=0.136, p=2.447e-01 uniform
# PTTA: KS stat=0.159, p=1.154e-01 uniform
# RMS: KS stat=0.126, p=3.258e-01 uniform
# tau: KS stat=0.734, p=3.028e-30 NOT uniform
# AUC: KS stat=0.149, p=1.615e-01 uniform

# %% [markdown]
# ### ---> uniformity improved

# %% [markdown]
# ---

# %%
import os

output_dir = "[2] Analyzer Results"
os.makedirs(output_dir, exist_ok=True)

for key, df in dfs.items():
    output_path = os.path.join(output_dir, f"{key}.xlsx")
    df.to_excel(output_path, index=False)

print(f"Saved {len(dfs)} dataframes to '{output_dir}' as .xlsx files.")
# Out:
# Saved 13 dataframes to '[2] Analyzer Results' as .xlsx files.
