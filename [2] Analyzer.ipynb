# %%
input_dir = "[1] Peakfinder Results" 

output_dir = "[2] Analyzer Results"

# %%
import os
import pandas as pd
import numpy as np
import ast

dfs = {}


files = [file for file in os.listdir(input_dir) if file.endswith(('.xlsx', '.xls')) and not file.startswith('OVERVIEW')]

for file in files:
    file_path = os.path.join(input_dir, file)
    dfs[file.split('.')[0]] = pd.read_excel(file_path)

framenames = list(dfs.keys())
results = framenames[0]
results_mtt = framenames[1]
results_tt = framenames[2]

print(f"Found {framenames} in {input_dir}.")

framenames.append('RESULTS_MERGED')
framenames.append('RESULTS_MERGED_MTT')
framenames.append('RESULTS_MERGED_TT')

experiments = dfs[results]['experiment'].unique().tolist()
variables = dfs[results].columns[4:].tolist()
parameters = dfs[results].columns[:4].tolist()
print(f"\nFound {len(experiments)} experiments, {len(variables)} variables and {len(parameters)} parameters:")
print(" "+', '.join(experiments))
print(" "+', '.join(variables))
print(" "+', '.join(parameters))



def average_list_columns(df):
    import numpy as np
    import ast

    def safe_mean(x):
        # If x is a string representing a list, convert to list
        if isinstance(x, str) and x.startswith('['):
            try:
                x = ast.literal_eval(x)
            except Exception:
                return np.nan
        # If x is a list, filter out None and np.nan
        if isinstance(x, list):
            x = [v for v in x if v is not None and not (isinstance(v, float) and np.isnan(v))]
            return np.mean(x) if len(x) > 0 else np.nan
        # If x is None or nan, return nan
        if x is None or (isinstance(x, float) and np.isnan(x)):
            return np.nan
        # Otherwise, return x
        return x

    df_copy = df.copy()
    for col in df_copy.columns:
        if df_copy[col].apply(lambda x: isinstance(x, list) or (isinstance(x, str) and x.startswith('['))).any():
            df_copy[col] = df_copy[col].apply(safe_mean)
    return df_copy

def average_across_dates(df):
    # Group by all columns except 'date' and the variables, then average variables across dates
    group_cols = [col for col in df.columns if col not in variables and col != 'date']
    averaged = df.groupby(group_cols, as_index=False)[variables].mean()
    return averaged

def average_across_experiment(df):
    # Group by all columns except 'experiment' and the variables, then average variables across experiment
    group_cols = [col for col in df.columns if col not in variables and col != 'experiment']
    averaged = df.groupby(group_cols, as_index=False)[variables].mean()
    return averaged



# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])


# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])

# Create date-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_TT_MERGED'])


# Create merged DataFrames with averaged values
dfs['RESULTS_MERGED'] = average_list_columns(dfs[results])
dfs['RESULTS_MTT_MERGED'] = average_list_columns(dfs[results_mtt])
dfs['RESULTS_TT_MERGED'] = average_list_columns(dfs[results_tt])

# Create date-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_DATE'] = average_across_dates(dfs['RESULTS_TT_MERGED'])

# Create experiment-averaged versions of each merged DataFrame
dfs['RESULTS_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_MERGED'])
dfs['RESULTS_MTT_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_MTT_MERGED'])
dfs['RESULTS_TT_MERGED_EXP'] = average_across_experiment(dfs['RESULTS_TT_MERGED'])

print(f"\nFound {len(dfs)} dataframes:")
print(list(dfs.keys()))
# Out:
# Found ['RESULTS', 'RESULTS_MT10', 'RESULTS_T10', 'SegmentOrder'] in [1] Peakfinder Results.
#
# Found 18 experiments, 9 variables and 4 parameters:
#  ASR_control, gap_depth, tone_in_noise, gap_duration_4, gap_duration_8, gap_duration_10, gap_duration_20, gap_duration_50, offset_PPI_4, offset_PPI_6, offset_PPI_8, offset_PPI_10, offset_PPI_12, offset_PPI_14, offset_PPI_16, offset_PPI_18, offset_PPI_20, offset_PPI_50
#  reactionTime, peakTime, difference, peakValue, PTPA, PTTA, RMS, tau, AUC
#  animal, sex, date, experiment
#
# Found 13 dataframes:
# ['RESULTS', 'RESULTS_MT10', 'RESULTS_T10', 'SegmentOrder', 'RESULTS_MERGED', 'RESULTS_MTT_MERGED', 'RESULTS_TT_MERGED', 'RESULTS_MERGED_DATE', 'RESULTS_MTT_MERGED_DATE', 'RESULTS_TT_MERGED_DATE', 'RESULTS_MERGED_EXP', 'RESULTS_MTT_MERGED_EXP', 'RESULTS_TT_MERGED_EXP']

# %% [markdown]
# ---

# %% [markdown]
# assume TT are discarded, repetitions have no effect and sex and date should be split

# %% [markdown]
# ---

# %% [markdown]
# # Normality

# %%
from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for sex in df['sex'].unique():
    for date in df['date'].unique():
        found_normal = []
        for var in variables:
            vals = df[(df['sex'] == sex) & (df['date'] == date)][var].dropna()
            if len(vals) > 2:
                stat, p = shapiro(vals)
                if p > 0.05:
                    found_normal.append(f"{var}: stat={stat:.3f}, p={p:.3e} normal")
            # else: skip
        if found_normal:
            print(f"\nSex: {sex}, Date: {date}")
            for line in found_normal:
                print(line)
# Out:
# Sex: female, Date: April16
# peakValue: stat=0.964, p=1.092e-01 normal
# PTPA: stat=0.966, p=1.327e-01 normal
# PTTA: stat=0.968, p=1.635e-01 normal
# RMS: stat=0.967, p=1.408e-01 normal
# AUC: stat=0.969, p=1.735e-01 normal
#
# Sex: female, Date: May20
# peakValue: stat=0.962, p=8.667e-02 normal
# PTPA: stat=0.962, p=8.561e-02 normal
# PTTA: stat=0.963, p=8.991e-02 normal
# RMS: stat=0.963, p=9.582e-02 normal
# AUC: stat=0.971, p=2.030e-01 normal
#
# Sex: male, Date: April16
# peakValue: stat=0.975, p=3.268e-01 normal
# PTPA: stat=0.971, p=2.116e-01 normal
# PTTA: stat=0.979, p=4.724e-01 normal
# RMS: stat=0.980, p=5.057e-01 normal
# AUC: stat=0.970, p=2.001e-01 normal
#
# Sex: male, Date: June26
# difference: stat=0.960, p=6.836e-02 normal
#
# Sex: male, Date: May20
# peakValue: stat=0.968, p=1.526e-01 normal
# PTPA: stat=0.969, p=1.789e-01 normal
# PTTA: stat=0.972, p=2.294e-01 normal

# %% [markdown]
# --> only rarely normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all dates, split by sex

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for sex in df['sex'].unique():
    print(f"\nSex: {sex} (all dates merged)")
    for var in variables:
        vals = df[df['sex'] == sex][var].dropna()
        if len(vals) > 2:
            stat, p = shapiro(vals)
            print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
        else:
            print(f"{var}: Not enough data")
# Out:
# Sex: female (all dates merged)
# reactionTime: stat=0.928, p=3.249e-07 NOT normal
# peakTime: stat=0.621, p=8.992e-19 NOT normal
# difference: stat=0.841, p=5.802e-12 NOT normal
# peakValue: stat=0.951, p=2.053e-05 NOT normal
# PTPA: stat=0.951, p=1.770e-05 NOT normal
# PTTA: stat=0.953, p=2.985e-05 NOT normal
# RMS: stat=0.962, p=2.078e-04 NOT normal
# tau: stat=0.919, p=7.672e-08 NOT normal
# AUC: stat=0.969, p=1.070e-03 NOT normal
#
# Sex: male (all dates merged)
# reactionTime: stat=0.881, p=4.117e-10 NOT normal
# peakTime: stat=0.879, p=3.545e-10 NOT normal
# difference: stat=0.925, p=1.950e-07 NOT normal
# peakValue: stat=0.951, p=1.980e-05 NOT normal
# PTPA: stat=0.951, p=1.838e-05 NOT normal
# PTTA: stat=0.949, p=1.328e-05 NOT normal
# RMS: stat=0.941, p=2.888e-06 NOT normal
# tau: stat=0.984, p=6.172e-02 normal
# AUC: stat=0.898, p=3.500e-09 NOT normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all sexes, split by date

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

for date in df['date'].unique():
    print(f"\nDate: {date} (all sexes merged)")
    for var in variables:
        vals = df[df['date'] == date][var].dropna()
        if len(vals) > 2:
            stat, p = shapiro(vals)
            print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
        else:
            print(f"{var}: Not enough data")
# Out:
# Date: April16 (all sexes merged)
# reactionTime: stat=0.855, p=7.194e-09 NOT normal
# peakTime: stat=0.664, p=2.260e-14 NOT normal
# difference: stat=0.777, p=1.694e-11 NOT normal
# peakValue: stat=0.929, p=2.229e-05 NOT normal
# PTPA: stat=0.928, p=2.055e-05 NOT normal
# PTTA: stat=0.932, p=3.491e-05 NOT normal
# RMS: stat=0.931, p=2.962e-05 NOT normal
# tau: stat=0.985, p=2.647e-01 normal
# AUC: stat=0.935, p=4.974e-05 NOT normal
#
# Date: June26 (all sexes merged)
# reactionTime: stat=0.866, p=1.956e-08 NOT normal
# peakTime: stat=0.866, p=1.888e-08 NOT normal
# difference: stat=0.946, p=2.558e-04 NOT normal
# peakValue: stat=0.871, p=3.200e-08 NOT normal
# PTPA: stat=0.870, p=2.900e-08 NOT normal
# PTTA: stat=0.882, p=9.499e-08 NOT normal
# RMS: stat=0.912, p=2.449e-06 NOT normal
# tau: stat=0.950, p=4.591e-04 NOT normal
# AUC: stat=0.880, p=7.274e-08 NOT normal
#
# Date: May20 (all sexes merged)
# reactionTime: stat=0.921, p=8.246e-06 NOT normal
# peakTime: stat=0.782, p=2.308e-11 NOT normal
# difference: stat=0.878, p=6.250e-08 NOT normal
# peakValue: stat=0.977, p=6.363e-02 normal
# PTPA: stat=0.978, p=7.121e-02 normal
# PTTA: stat=0.977, p=5.436e-02 normal
# RMS: stat=0.949, p=4.317e-04 NOT normal
# tau: stat=0.982, p=1.510e-01 normal
# AUC: stat=0.860, p=1.052e-08 NOT normal

# %%
# Test normality (Shapiro-Wilk) for each variable, merged across all sexes and all dates

from scipy.stats import shapiro

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

print("\nAll data (sexes and dates merged):")
for var in variables:
    vals = df[var].dropna()
    if len(vals) > 2:
        stat, p = shapiro(vals)
        print(f"{var}: stat={stat:.3f}, p={p:.3e} {'NOT normal' if p < 0.05 else 'normal'}")
    else:
        print(f"{var}: Not enough data")
# Out:
# All data (sexes and dates merged):
# reactionTime: stat=0.921, p=5.199e-12 NOT normal
# peakTime: stat=0.795, p=6.354e-20 NOT normal
# difference: stat=0.896, p=4.357e-14 NOT normal
# peakValue: stat=0.935, p=1.060e-10 NOT normal
# PTPA: stat=0.935, p=1.012e-10 NOT normal
# PTTA: stat=0.936, p=1.235e-10 NOT normal
# RMS: stat=0.931, p=3.833e-11 NOT normal
# tau: stat=0.976, p=3.589e-05 NOT normal
# AUC: stat=0.894, p=3.022e-14 NOT normal

# %% [markdown]
# ### ---> no change, even if not grouped by sex and / or date
# ### ---> data not normally distributed

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']
variables = ['peakValue', 'reactionTime', 'peakTime', 'tau']#[col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

plt.figure(figsize=(16, 9), dpi=200)
for var in variables:
    vals = pd.to_numeric(df[var], errors='coerce').dropna()
    norm_vals = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
    sns.kdeplot(
        norm_vals,
        label=var,
        fill=True,
        alpha=0.4,
        linewidth=2,
        bw_adjust=0.7,
        clip=(0, 1)
    )
plt.xlabel("Normalized Value", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

plt.figure(figsize=(16, 9), dpi=200)
for var in variables:
    vals = pd.to_numeric(df[var], errors='coerce').dropna()
    norm_vals = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
    sns.kdeplot(
        norm_vals,
        label=var,
        fill=True,
        alpha=0.4,
        linewidth=2,
        bw_adjust=0.7,
        clip=(0, 1)
    )
plt.xlabel("Normalized Value", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...

import matplotlib.pyplot as plt
import seaborn as sns

df = dfs['RESULTS_MERGED']

plt.figure(figsize=(10, 6), dpi=300)  # High quality output

for sex in df['sex'].unique():
    vals = df[df['sex'] == sex]['reactionTime'].dropna()
    sns.kdeplot(
        vals,
        label=f"{sex}",
        fill=True,
        alpha=0.5,
        linewidth=1.5,
        bw_adjust=0.7
    )

plt.xlabel("Reaction Time", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.title("Reaction Time Distribution by Sex", fontsize=18)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# ...existing code...

# %%
from scipy.stats import shapiro, gamma, weibull_min, boxcox, lognorm, t, yeojohnson
import numpy as np
from sklearn.preprocessing import QuantileTransformer, PowerTransformer

df = dfs['RESULTS_MERGED']
variables = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

def try_transformations(vals):
    results = {}
    # Original
    results['original'] = shapiro(vals)[1] if len(vals) > 2 else np.nan
    # Gamma
    if len(vals) > 2 and (vals > 0).all():
        params = gamma.fit(vals, floc=0)
        trans = gamma.cdf(vals, *params)
        results['gamma'] = shapiro(trans)[1]
    # Weibull
    if len(vals) > 2 and (vals > 0).all():
        params = weibull_min.fit(vals, floc=0)
        trans = weibull_min.cdf(vals, *params)
        results['weibull'] = shapiro(trans)[1]
    # Box-Cox
    if len(vals) > 2 and (vals > 0).all():
        trans, _ = boxcox(vals)
        results['boxcox'] = shapiro(trans)[1]
    # Lognormal
    if len(vals) > 2 and (vals > 0).all():
        params = lognorm.fit(vals, floc=0)
        trans = lognorm.cdf(vals, *params)
        results['lognorm'] = shapiro(trans)[1]
    # Student-t
    if len(vals) > 2:
        params = t.fit(vals)
        trans = t.cdf(vals, *params)
        results['student_t'] = shapiro(trans)[1]
    # Yeo-Johnson
    if len(vals) > 2:
        trans, _ = yeojohnson(vals)
        results['yeojohnson'] = shapiro(trans)[1]
    # Log
    if len(vals) > 2 and (vals > 0).all():
        trans = np.log(vals + 1e-6)
        results['log'] = shapiro(trans)[1]
    # Sqrt
    if len(vals) > 2 and (vals >= 0).all():
        trans = np.sqrt(vals)
        results['sqrt'] = shapiro(trans)[1]
    # Z-score
    if len(vals) > 2:
        trans = (vals - vals.mean()) / (vals.std() + 1e-8)
        results['zscore'] = shapiro(trans)[1]
    # Min-max
    if len(vals) > 2:
        trans = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
        results['minmax'] = shapiro(trans)[1]
    # Quantile (normal)
    if len(vals) > 2:
        qt = QuantileTransformer(output_distribution='normal', random_state=0, n_quantiles=min(len(vals), 1000))
        trans = qt.fit_transform(vals.values.reshape(-1, 1)).flatten()
        results['quantile'] = shapiro(trans)[1]
    # Power (Yeo-Johnson, sklearn)
    if len(vals) > 2:
        pt = PowerTransformer(method='yeo-johnson')
        trans = pt.fit_transform(vals.values.reshape(-1, 1)).flatten()
        results['power'] = shapiro(trans)[1]
    return results

for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        for var in variables:
            vals = pd.to_numeric(df[(df['sex'] == sex) & (df['date'] == date)][var], errors='coerce').dropna()
            res = try_transformations(vals)
            for method, p in res.items():
                print(f"{var:15} {method:10}: p={p:.3e} {'normal' if p > 0.05 else 'NOT normal'}")
# Out:
# Sex: female, Date: April16
# reactionTime    original  : p=8.984e-03 NOT normal
# reactionTime    gamma     : p=1.881e-04 NOT normal
# reactionTime    weibull   : p=2.734e-04 NOT normal
# reactionTime    boxcox    : p=1.508e-02 NOT normal
# reactionTime    lognorm   : p=1.817e-04 NOT normal
# reactionTime    student_t : p=1.995e-04 NOT normal
# reactionTime    yeojohnson: p=1.511e-02 NOT normal
# reactionTime    log       : p=5.761e-03 NOT normal
# reactionTime    sqrt      : p=7.317e-03 NOT normal
# reactionTime    zscore    : p=8.984e-03 NOT normal
# reactionTime    minmax    : p=8.984e-03 NOT normal
# reactionTime    quantile  : p=9.158e-06 NOT normal
# reactionTime    power     : p=1.511e-02 NOT normal
# peakTime        original  : p=1.392e-08 NOT normal
# peakTime        gamma     : p=1.801e-04 NOT normal
# peakTime        weibull   : p=2.029e-04 NOT normal
# peakTime        boxcox    : p=5.655e-07 NOT normal
# peakTime        lognorm   : p=1.707e-04 NOT normal
# peakTime        student_t : p=2.079e-04 NOT normal
# peakTime        yeojohnson: p=5.639e-07 NOT normal
# peakTime        log       : p=6.706e-09 NOT normal
# peakTime        sqrt      : p=9.697e-09 NOT normal
# peakTime        zscore    : p=1.392e-08 NOT normal
# peakTime        minmax    : p=1.392e-08 NOT normal
# peakTime        quantile  : p=9.530e-07 NOT normal
# peakTime        power     : p=5.639e-07 NOT normal
# difference      original  : p=1.033e-02 NOT normal
# difference      gamma     : p=5.546e-03 NOT normal
# difference      weibull   : p=1.985e-03 NOT normal
# difference      boxcox    : p=5.876e-02 normal
# difference      lognorm   : p=5.869e-03 NOT normal
# difference      student_t : p=1.651e-03 NOT normal
# difference      yeojohnson: p=5.870e-02 normal
# difference      log       : p=2.997e-03 NOT normal
# difference      sqrt      : p=5.777e-03 NOT normal
# difference      zscore    : p=1.033e-02 NOT normal
# difference      minmax    : p=1.033e-02 NOT normal
# difference      quantile  : p=2.900e-05 NOT normal
# difference      power     : p=5.870e-02 normal
# peakValue       original  : p=1.092e-01 normal
# peakValue       gamma     : p=1.082e-03 NOT normal
# peakValue       weibull   : p=4.788e-03 NOT normal
# peakValue       boxcox    : p=2.389e-01 normal
# peakValue       lognorm   : p=6.744e-04 NOT normal
# peakValue       student_t : p=2.231e-03 NOT normal
# peakValue       yeojohnson: p=2.398e-01 normal
# peakValue       log       : p=7.466e-03 NOT normal
# peakValue       sqrt      : p=3.402e-02 NOT normal
# peakValue       zscore    : p=1.092e-01 normal
# peakValue       minmax    : p=1.092e-01 normal
# peakValue       quantile  : p=2.317e-04 NOT normal
# peakValue       power     : p=2.398e-01 normal
# PTPA            original  : p=1.327e-01 normal
# PTPA            gamma     : p=1.182e-03 NOT normal
# PTPA            weibull   : p=5.074e-03 NOT normal
# PTPA            boxcox    : p=2.692e-01 normal
# PTPA            lognorm   : p=7.477e-04 NOT normal
# PTPA            student_t : p=2.378e-03 NOT normal
# PTPA            yeojohnson: p=2.701e-01 normal
# PTPA            log       : p=9.787e-03 NOT normal
# PTPA            sqrt      : p=4.330e-02 NOT normal
# PTPA            zscore    : p=1.327e-01 normal
# PTPA            minmax    : p=1.327e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=2.701e-01 normal
# PTTA            original  : p=1.635e-01 normal
# PTTA            gamma     : p=1.736e-03 NOT normal
# PTTA            weibull   : p=6.528e-03 NOT normal
# PTTA            boxcox    : p=3.052e-01 normal
# PTTA            lognorm   : p=1.119e-03 NOT normal
# PTTA            student_t : p=3.302e-03 NOT normal
# PTTA            yeojohnson: p=3.063e-01 normal
# PTTA            log       : p=1.155e-02 NOT normal
# PTTA            sqrt      : p=5.386e-02 normal
# PTTA            zscore    : p=1.635e-01 normal
# PTTA            minmax    : p=1.635e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=3.063e-01 normal
# RMS             original  : p=1.408e-01 normal
# RMS             gamma     : p=1.553e-03 NOT normal
# RMS             weibull   : p=6.767e-03 NOT normal
# RMS             boxcox    : p=2.489e-01 normal
# RMS             lognorm   : p=9.167e-04 NOT normal
# RMS             student_t : p=3.414e-03 NOT normal
# RMS             yeojohnson: p=2.511e-01 normal
# RMS             log       : p=9.875e-03 NOT normal
# RMS             sqrt      : p=4.670e-02 NOT normal
# RMS             zscore    : p=1.408e-01 normal
# RMS             minmax    : p=1.408e-01 normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=2.511e-01 normal
# tau             original  : p=2.828e-02 NOT normal
# tau             gamma     : p=2.965e-04 NOT normal
# tau             weibull   : p=3.126e-04 NOT normal
# tau             boxcox    : p=2.939e-02 NOT normal
# tau             lognorm   : p=2.913e-04 NOT normal
# tau             student_t : p=3.007e-04 NOT normal
# tau             yeojohnson: p=2.939e-02 NOT normal
# tau             log       : p=2.346e-02 NOT normal
# tau             sqrt      : p=2.620e-02 NOT normal
# tau             zscore    : p=2.828e-02 NOT normal
# tau             minmax    : p=2.828e-02 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=2.939e-02 NOT normal
# AUC             original  : p=1.735e-01 normal
# AUC             gamma     : p=3.112e-03 NOT normal
# AUC             weibull   : p=8.938e-03 NOT normal
# AUC             boxcox    : p=1.940e-01 normal
# AUC             lognorm   : p=1.896e-03 NOT normal
# AUC             student_t : p=5.873e-03 NOT normal
# AUC             yeojohnson: p=1.940e-01 normal
# AUC             log       : p=1.896e-02 NOT normal
# AUC             sqrt      : p=7.997e-02 normal
# AUC             zscore    : p=1.735e-01 normal
# AUC             minmax    : p=1.735e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=1.940e-01 normal
#
# Sex: female, Date: June26
# reactionTime    original  : p=2.730e-04 NOT normal
# reactionTime    gamma     : p=1.279e-02 NOT normal
# reactionTime    weibull   : p=1.045e-02 NOT normal
# reactionTime    boxcox    : p=4.105e-02 NOT normal
# reactionTime    lognorm   : p=1.020e-02 NOT normal
# reactionTime    student_t : p=3.190e-03 NOT normal
# reactionTime    yeojohnson: p=4.013e-02 NOT normal
# reactionTime    log       : p=4.406e-07 NOT normal
# reactionTime    sqrt      : p=1.272e-05 NOT normal
# reactionTime    zscore    : p=2.730e-04 NOT normal
# reactionTime    minmax    : p=2.730e-04 NOT normal
# reactionTime    quantile  : p=3.554e-05 NOT normal
# reactionTime    power     : p=4.013e-02 NOT normal
# peakTime        original  : p=2.781e-10 NOT normal
# peakTime        gamma     : p=1.310e-09 NOT normal
# peakTime        weibull   : p=2.412e-10 NOT normal
# peakTime        boxcox    : p=6.263e-09 NOT normal
# peakTime        lognorm   : p=1.557e-09 NOT normal
# peakTime        student_t : p=9.344e-10 NOT normal
# peakTime        yeojohnson: p=6.377e-09 NOT normal
# peakTime        log       : p=5.600e-10 NOT normal
# peakTime        sqrt      : p=3.959e-10 NOT normal
# peakTime        zscore    : p=2.781e-10 NOT normal
# peakTime        minmax    : p=2.781e-10 NOT normal
# peakTime        quantile  : p=1.871e-07 NOT normal
# peakTime        power     : p=6.377e-09 NOT normal
# difference      original  : p=9.364e-05 NOT normal
# difference      gamma     : p=1.101e-03 NOT normal
# difference      weibull   : p=7.805e-05 NOT normal
# difference      boxcox    : p=7.952e-02 normal
# difference      lognorm   : p=1.780e-03 NOT normal
# difference      student_t : p=4.786e-03 NOT normal
# difference      yeojohnson: p=8.003e-02 normal
# difference      log       : p=2.150e-03 NOT normal
# difference      sqrt      : p=4.723e-04 NOT normal
# difference      zscore    : p=9.364e-05 NOT normal
# difference      minmax    : p=9.364e-05 NOT normal
# difference      quantile  : p=1.430e-04 NOT normal
# difference      power     : p=8.003e-02 normal
# peakValue       original  : p=1.093e-02 NOT normal
# peakValue       gamma     : p=1.181e-04 NOT normal
# peakValue       weibull   : p=3.062e-04 NOT normal
# peakValue       boxcox    : p=2.385e-02 NOT normal
# peakValue       lognorm   : p=8.148e-05 NOT normal
# peakValue       student_t : p=2.024e-04 NOT normal
# peakValue       yeojohnson: p=2.395e-02 NOT normal
# peakValue       log       : p=1.148e-03 NOT normal
# peakValue       sqrt      : p=4.215e-03 NOT normal
# peakValue       zscore    : p=1.093e-02 NOT normal
# peakValue       minmax    : p=1.093e-02 NOT normal
# peakValue       quantile  : p=2.315e-04 NOT normal
# peakValue       power     : p=2.395e-02 NOT normal
# PTPA            original  : p=6.370e-03 NOT normal
# PTPA            gamma     : p=8.701e-05 NOT normal
# PTPA            weibull   : p=2.173e-04 NOT normal
# PTPA            boxcox    : p=1.374e-02 NOT normal
# PTPA            lognorm   : p=6.138e-05 NOT normal
# PTPA            student_t : p=1.450e-04 NOT normal
# PTPA            yeojohnson: p=1.380e-02 NOT normal
# PTPA            log       : p=7.781e-04 NOT normal
# PTPA            sqrt      : p=2.619e-03 NOT normal
# PTPA            zscore    : p=6.370e-03 NOT normal
# PTPA            minmax    : p=6.370e-03 NOT normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=1.380e-02 NOT normal
# PTTA            original  : p=3.066e-02 NOT normal
# PTTA            gamma     : p=2.965e-04 NOT normal
# PTTA            weibull   : p=6.083e-04 NOT normal
# PTTA            boxcox    : p=4.946e-02 NOT normal
# PTTA            lognorm   : p=2.102e-04 NOT normal
# PTTA            student_t : p=4.511e-04 NOT normal
# PTTA            yeojohnson: p=4.962e-02 NOT normal
# PTTA            log       : p=3.026e-03 NOT normal
# PTTA            sqrt      : p=1.215e-02 NOT normal
# PTTA            zscore    : p=3.066e-02 NOT normal
# PTTA            minmax    : p=3.066e-02 NOT normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=4.962e-02 NOT normal
# RMS             original  : p=3.578e-02 NOT normal
# RMS             gamma     : p=1.814e-04 NOT normal
# RMS             weibull   : p=5.088e-04 NOT normal
# RMS             boxcox    : p=5.253e-02 normal
# RMS             lognorm   : p=1.183e-04 NOT normal
# RMS             student_t : p=3.289e-04 NOT normal
# RMS             yeojohnson: p=5.298e-02 normal
# RMS             log       : p=3.347e-03 NOT normal
# RMS             sqrt      : p=1.370e-02 NOT normal
# RMS             zscore    : p=3.578e-02 NOT normal
# RMS             minmax    : p=3.578e-02 NOT normal
# RMS             quantile  : p=2.357e-04 NOT normal
# RMS             power     : p=5.298e-02 normal
# tau             original  : p=2.034e-02 NOT normal
# tau             gamma     : p=5.250e-04 NOT normal
# tau             weibull   : p=4.989e-04 NOT normal
# tau             boxcox    : p=2.557e-01 normal
# tau             lognorm   : p=5.970e-04 NOT normal
# tau             student_t : p=3.873e-04 NOT normal
# tau             yeojohnson: p=2.554e-01 normal
# tau             log       : p=1.156e-01 normal
# tau             sqrt      : p=5.470e-02 normal
# tau             zscore    : p=2.034e-02 NOT normal
# tau             minmax    : p=2.034e-02 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=2.554e-01 normal
# AUC             original  : p=1.328e-02 NOT normal
# AUC             gamma     : p=5.301e-05 NOT normal
# AUC             weibull   : p=1.699e-04 NOT normal
# AUC             boxcox    : p=1.739e-02 NOT normal
# AUC             lognorm   : p=3.710e-05 NOT normal
# AUC             student_t : p=9.503e-05 NOT normal
# AUC             yeojohnson: p=1.739e-02 NOT normal
# AUC             log       : p=2.113e-03 NOT normal
# AUC             sqrt      : p=6.150e-03 NOT normal
# AUC             zscore    : p=1.328e-02 NOT normal
# AUC             minmax    : p=1.328e-02 NOT normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=1.739e-02 NOT normal
#
# Sex: female, Date: May20
# reactionTime    original  : p=3.664e-03 NOT normal
# reactionTime    gamma     : p=7.864e-02 normal
# reactionTime    weibull   : p=5.271e-02 normal
# reactionTime    boxcox    : p=3.647e-03 NOT normal
# reactionTime    lognorm   : p=1.003e-01 normal
# reactionTime    student_t : p=3.512e-03 NOT normal
# reactionTime    yeojohnson: p=3.635e-03 NOT normal
# reactionTime    log       : p=2.667e-04 NOT normal
# reactionTime    sqrt      : p=1.774e-03 NOT normal
# reactionTime    zscore    : p=3.664e-03 NOT normal
# reactionTime    minmax    : p=3.664e-03 NOT normal
# reactionTime    quantile  : p=8.125e-05 NOT normal
# reactionTime    power     : p=3.635e-03 NOT normal
# peakTime        original  : p=2.992e-10 NOT normal
# peakTime        gamma     : p=1.622e-08 NOT normal
# peakTime        weibull   : p=1.000e-09 NOT normal
# peakTime        boxcox    : p=1.000e+00 normal
# peakTime        lognorm   : p=2.078e-08 NOT normal
# peakTime        student_t : p=1.013e-08 NOT normal
# peakTime        yeojohnson: p=4.718e-07 NOT normal
# peakTime        log       : p=6.146e-10 NOT normal
# peakTime        sqrt      : p=4.283e-10 NOT normal
# peakTime        zscore    : p=2.992e-10 NOT normal
# peakTime        minmax    : p=2.992e-10 NOT normal
# peakTime        quantile  : p=2.173e-07 NOT normal
# peakTime        power     : p=4.718e-07 NOT normal
# difference      original  : p=5.934e-07 NOT normal
# difference      gamma     : p=3.519e-04 NOT normal
# difference      weibull   : p=2.556e-05 NOT normal
# difference      boxcox    : p=5.187e-02 normal
# difference      lognorm   : p=5.262e-04 NOT normal
# difference      student_t : p=2.588e-03 NOT normal
# difference      yeojohnson: p=5.242e-02 normal
# difference      log       : p=1.294e-05 NOT normal
# difference      sqrt      : p=2.770e-06 NOT normal
# difference      zscore    : p=5.934e-07 NOT normal
# difference      minmax    : p=5.934e-07 NOT normal
# difference      quantile  : p=1.102e-04 NOT normal
# difference      power     : p=5.242e-02 normal
# peakValue       original  : p=8.667e-02 normal
# peakValue       gamma     : p=6.163e-04 NOT normal
# peakValue       weibull   : p=1.119e-03 NOT normal
# peakValue       boxcox    : p=1.362e-01 normal
# peakValue       lognorm   : p=4.204e-04 NOT normal
# peakValue       student_t : p=8.783e-04 NOT normal
# peakValue       yeojohnson: p=1.367e-01 normal
# peakValue       log       : p=2.875e-03 NOT normal
# peakValue       sqrt      : p=2.316e-02 NOT normal
# peakValue       zscore    : p=8.667e-02 normal
# peakValue       minmax    : p=8.667e-02 normal
# peakValue       quantile  : p=2.347e-04 NOT normal
# peakValue       power     : p=1.367e-01 normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# PTPA            original  : p=8.561e-02 normal
# PTPA            gamma     : p=5.937e-04 NOT normal
# PTPA            weibull   : p=1.057e-03 NOT normal
# PTPA            boxcox    : p=1.432e-01 normal
# PTPA            lognorm   : p=4.049e-04 NOT normal
# PTPA            student_t : p=8.440e-04 NOT normal
# PTPA            yeojohnson: p=1.438e-01 normal
# PTPA            log       : p=2.542e-03 NOT normal
# PTPA            sqrt      : p=2.160e-02 NOT normal
# PTPA            zscore    : p=8.561e-02 normal
# PTPA            minmax    : p=8.561e-02 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=1.438e-01 normal
# PTTA            original  : p=8.991e-02 normal
# PTTA            gamma     : p=8.497e-04 NOT normal
# PTTA            weibull   : p=1.493e-03 NOT normal
# PTTA            boxcox    : p=1.233e-01 normal
# PTTA            lognorm   : p=5.681e-04 NOT normal
# PTTA            student_t : p=1.200e-03 NOT normal
# PTTA            yeojohnson: p=1.237e-01 normal
# PTTA            log       : p=3.052e-03 NOT normal
# PTTA            sqrt      : p=2.555e-02 NOT normal
# PTTA            zscore    : p=8.991e-02 normal
# PTTA            minmax    : p=8.991e-02 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=1.237e-01 normal
# RMS             original  : p=9.582e-02 normal
# RMS             gamma     : p=4.756e-04 NOT normal
# RMS             weibull   : p=1.677e-03 NOT normal
# RMS             boxcox    : p=2.226e-01 normal
# RMS             lognorm   : p=2.768e-04 NOT normal
# RMS             student_t : p=1.018e-03 NOT normal
# RMS             yeojohnson: p=2.250e-01 normal
# RMS             log       : p=1.851e-03 NOT normal
# RMS             sqrt      : p=1.805e-02 NOT normal
# RMS             zscore    : p=9.582e-02 normal
# RMS             minmax    : p=9.582e-02 normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=2.250e-01 normal
# tau             original  : p=9.653e-05 NOT normal
# tau             gamma     : p=1.516e-04 NOT normal
# tau             weibull   : p=1.480e-04 NOT normal
# tau             boxcox    : p=2.004e-02 NOT normal
# tau             lognorm   : p=1.846e-04 NOT normal
# tau             student_t : p=6.038e-05 NOT normal
# tau             yeojohnson: p=1.996e-02 NOT normal
# tau             log       : p=4.119e-03 NOT normal
# tau             sqrt      : p=8.052e-04 NOT normal
# tau             zscore    : p=9.653e-05 NOT normal
# tau             minmax    : p=9.653e-05 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=1.996e-02 NOT normal
# AUC             original  : p=2.030e-01 normal
# AUC             gamma     : p=1.904e-03 NOT normal
# AUC             weibull   : p=1.738e-02 NOT normal
# AUC             boxcox    : p=2.092e-01 normal
# AUC             lognorm   : p=1.119e-03 NOT normal
# AUC             student_t : p=4.753e-03 NOT normal
# AUC             yeojohnson: p=2.092e-01 normal
# AUC             log       : p=2.253e-02 NOT normal
# AUC             sqrt      : p=1.005e-01 normal
# AUC             zscore    : p=2.030e-01 normal
# AUC             minmax    : p=2.030e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=2.092e-01 normal
#
# Sex: male, Date: April16
# reactionTime    original  : p=3.109e-06 NOT normal
# reactionTime    gamma     : p=1.102e-02 NOT normal
# reactionTime    weibull   : p=5.554e-03 NOT normal
# reactionTime    boxcox    : p=2.514e-04 NOT normal
# reactionTime    lognorm   : p=7.935e-03 NOT normal
# reactionTime    student_t : p=1.014e-02 NOT normal
# reactionTime    yeojohnson: p=2.445e-04 NOT normal
# reactionTime    log       : p=2.764e-08 NOT normal
# reactionTime    sqrt      : p=3.136e-07 NOT normal
# reactionTime    zscore    : p=3.109e-06 NOT normal
# reactionTime    minmax    : p=3.109e-06 NOT normal
# reactionTime    quantile  : p=2.740e-06 NOT normal
# reactionTime    power     : p=2.445e-04 NOT normal
# peakTime        original  : p=1.067e-07 NOT normal
# peakTime        gamma     : p=5.221e-03 NOT normal
# peakTime        weibull   : p=6.784e-04 NOT normal
# peakTime        boxcox    : p=5.409e-03 NOT normal
# peakTime        lognorm   : p=6.537e-03 NOT normal
# peakTime        student_t : p=2.257e-03 NOT normal
# peakTime        yeojohnson: p=5.474e-03 NOT normal
# peakTime        log       : p=4.370e-06 NOT normal
# peakTime        sqrt      : p=6.962e-07 NOT normal
# peakTime        zscore    : p=1.067e-07 NOT normal
# peakTime        minmax    : p=1.067e-07 NOT normal
# peakTime        quantile  : p=9.657e-05 NOT normal
# peakTime        power     : p=5.474e-03 NOT normal
# difference      original  : p=7.026e-06 NOT normal
# difference      gamma     : p=1.079e-02 NOT normal
# difference      weibull   : p=5.609e-03 NOT normal
# difference      boxcox    : p=1.610e-02 NOT normal
# difference      lognorm   : p=1.517e-02 NOT normal
# difference      student_t : p=5.115e-03 NOT normal
# difference      yeojohnson: p=1.681e-02 NOT normal
# difference      log       : p=1.788e-03 NOT normal
# difference      sqrt      : p=1.417e-04 NOT normal
# difference      zscore    : p=7.026e-06 NOT normal
# difference      minmax    : p=7.026e-06 NOT normal
# difference      quantile  : p=1.673e-04 NOT normal
# difference      power     : p=1.681e-02 NOT normal
# peakValue       original  : p=3.268e-01 normal
# peakValue       gamma     : p=3.967e-03 NOT normal
# peakValue       weibull   : p=9.405e-03 NOT normal
# peakValue       boxcox    : p=5.952e-01 normal
# peakValue       lognorm   : p=2.726e-03 NOT normal
# peakValue       student_t : p=6.304e-03 NOT normal
# peakValue       yeojohnson: p=5.959e-01 normal
# peakValue       log       : p=1.511e-02 NOT normal
# peakValue       sqrt      : p=9.534e-02 normal
# peakValue       zscore    : p=3.268e-01 normal
# peakValue       minmax    : p=3.268e-01 normal
# peakValue       quantile  : p=2.367e-04 NOT normal
# peakValue       power     : p=5.959e-01 normal
# PTPA            original  : p=2.116e-01 normal
# PTPA            gamma     : p=2.261e-03 NOT normal
# PTPA            weibull   : p=6.690e-03 NOT normal
# PTPA            boxcox    : p=5.540e-01 normal
# PTPA            lognorm   : p=1.532e-03 NOT normal
# PTPA            student_t : p=3.848e-03 NOT normal
# PTPA            yeojohnson: p=5.547e-01 normal
# PTPA            log       : p=7.332e-03 NOT normal
# PTPA            sqrt      : p=5.072e-02 normal
# PTPA            zscore    : p=2.116e-01 normal
# PTPA            minmax    : p=2.116e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=5.547e-01 normal
# PTTA            original  : p=4.724e-01 normal
# PTTA            gamma     : p=8.743e-03 NOT normal
# PTTA            weibull   : p=4.004e-02 NOT normal
# PTTA            boxcox    : p=7.222e-01 normal
# PTTA            lognorm   : p=5.187e-03 NOT normal
# PTTA            student_t : p=1.849e-02 NOT normal
# PTTA            yeojohnson: p=7.226e-01 normal
# PTTA            log       : p=1.706e-02 NOT normal
# PTTA            sqrt      : p=1.316e-01 normal
# PTTA            zscore    : p=4.724e-01 normal
# PTTA            minmax    : p=4.724e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=7.226e-01 normal
# RMS             original  : p=5.057e-01 normal
# RMS             gamma     : p=2.563e-03 NOT normal
# RMS             weibull   : p=4.929e-03 NOT normal
# RMS             boxcox    : p=5.703e-01 normal
# RMS             lognorm   : p=1.876e-03 NOT normal
# RMS             student_t : p=3.483e-03 NOT normal
# RMS             yeojohnson: p=5.715e-01 normal
# RMS             log       : p=5.548e-02 normal
# RMS             sqrt      : p=2.429e-01 normal
# RMS             zscore    : p=5.057e-01 normal
# RMS             minmax    : p=5.057e-01 normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=5.715e-01 normal
# tau             original  : p=3.249e-02 NOT normal
# tau             gamma     : p=1.401e-02 NOT normal
# tau             weibull   : p=6.095e-03 NOT normal
# tau             boxcox    : p=9.756e-01 normal
# tau             lognorm   : p=1.739e-02 NOT normal
# tau             student_t : p=5.982e-03 NOT normal
# tau             yeojohnson: p=9.754e-01 normal
# tau             log       : p=6.323e-01 normal
# tau             sqrt      : p=1.999e-01 normal
# tau             zscore    : p=3.249e-02 NOT normal
# tau             minmax    : p=3.249e-02 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=9.754e-01 normal
# AUC             original  : p=2.001e-01 normal
# AUC             gamma     : p=6.480e-04 NOT normal
# AUC             weibull   : p=8.147e-04 NOT normal
# AUC             boxcox    : p=2.335e-01 normal
# AUC             lognorm   : p=6.129e-04 NOT normal
# AUC             student_t : p=5.691e-04 NOT normal
# AUC             yeojohnson: p=2.335e-01 normal
# AUC             log       : p=1.325e-01 normal
# AUC             sqrt      : p=2.271e-01 normal
# AUC             zscore    : p=2.001e-01 normal
# AUC             minmax    : p=2.001e-01 normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=2.335e-01 normal
#
# Sex: male, Date: June26
# reactionTime    original  : p=9.930e-07 NOT normal
# reactionTime    gamma     : p=4.808e-07 NOT normal
# reactionTime    weibull   : p=2.008e-07 NOT normal
# reactionTime    boxcox    : p=9.713e-07 NOT normal
# reactionTime    lognorm   : p=5.402e-07 NOT normal
# reactionTime    student_t : p=3.808e-07 NOT normal
# reactionTime    yeojohnson: p=9.697e-07 NOT normal
# reactionTime    log       : p=6.301e-07 NOT normal
# reactionTime    sqrt      : p=8.616e-07 NOT normal
# reactionTime    zscore    : p=9.930e-07 NOT normal
# reactionTime    minmax    : p=9.930e-07 NOT normal
# reactionTime    quantile  : p=4.133e-09 NOT normal
# reactionTime    power     : p=9.697e-07 NOT normal
# peakTime        original  : p=8.977e-03 NOT normal
# peakTime        gamma     : p=3.729e-03 NOT normal
# peakTime        weibull   : p=3.690e-03 NOT normal
# peakTime        boxcox    : p=3.757e-02 NOT normal
# peakTime        lognorm   : p=3.490e-03 NOT normal
# peakTime        student_t : p=3.668e-03 NOT normal
# peakTime        yeojohnson: p=3.759e-02 NOT normal
# peakTime        log       : p=3.647e-02 NOT normal
# peakTime        sqrt      : p=2.331e-02 NOT normal
# peakTime        zscore    : p=8.977e-03 NOT normal
# peakTime        minmax    : p=8.977e-03 NOT normal
# peakTime        quantile  : p=9.075e-06 NOT normal
# peakTime        power     : p=3.759e-02 NOT normal
# difference      original  : p=6.836e-02 normal
# difference      gamma     : p=3.893e-03 NOT normal
# difference      weibull   : p=1.176e-02 NOT normal
# difference      boxcox    : p=1.033e-01 normal
# difference      lognorm   : p=2.293e-03 NOT normal
# difference      student_t : p=6.590e-03 NOT normal
# difference      yeojohnson: p=1.032e-01 normal
# difference      log       : p=4.170e-02 NOT normal
# difference      sqrt      : p=1.024e-01 normal
# difference      zscore    : p=6.836e-02 normal
# difference      minmax    : p=6.836e-02 normal
# difference      quantile  : p=1.292e-04 NOT normal
# difference      power     : p=1.032e-01 normal
# peakValue       original  : p=1.451e-05 NOT normal
# peakValue       gamma     : p=4.222e-07 NOT normal
# peakValue       weibull   : p=1.946e-06 NOT normal
# peakValue       boxcox    : p=3.332e-05 NOT normal
# peakValue       lognorm   : p=2.086e-07 NOT normal
# peakValue       student_t : p=1.838e-06 NOT normal
# peakValue       yeojohnson: p=3.362e-05 NOT normal
# peakValue       log       : p=1.381e-06 NOT normal
# peakValue       sqrt      : p=4.439e-06 NOT normal
# peakValue       zscore    : p=1.451e-05 NOT normal
# peakValue       minmax    : p=1.451e-05 NOT normal
# peakValue       quantile  : p=2.362e-04 NOT normal
# peakValue       power     : p=3.362e-05 NOT normal
# PTPA            original  : p=1.312e-05 NOT normal
# PTPA            gamma     : p=3.878e-07 NOT normal
# PTPA            weibull   : p=1.794e-06 NOT normal
# PTPA            boxcox    : p=3.201e-05 NOT normal
# PTPA            lognorm   : p=1.938e-07 NOT normal
# PTPA            student_t : p=1.662e-06 NOT normal
# PTPA            yeojohnson: p=3.229e-05 NOT normal
# PTPA            log       : p=1.275e-06 NOT normal
# PTPA            sqrt      : p=4.043e-06 NOT normal
# PTPA            zscore    : p=1.312e-05 NOT normal
# PTPA            minmax    : p=1.312e-05 NOT normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=3.229e-05 NOT normal
# PTTA            original  : p=2.257e-04 NOT normal
# PTTA            gamma     : p=3.868e-06 NOT normal
# PTTA            weibull   : p=1.786e-05 NOT normal
# PTTA            boxcox    : p=2.614e-04 NOT normal
# PTTA            lognorm   : p=1.701e-06 NOT normal
# PTTA            student_t : p=1.763e-05 NOT normal
# PTTA            yeojohnson: p=2.631e-04 NOT normal
# PTTA            log       : p=1.563e-05 NOT normal
# PTTA            sqrt      : p=6.596e-05 NOT normal
# PTTA            zscore    : p=2.257e-04 NOT normal
# PTTA            minmax    : p=2.257e-04 NOT normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=2.631e-04 NOT normal
# RMS             original  : p=7.757e-04 NOT normal
# RMS             gamma     : p=6.399e-06 NOT normal
# RMS             weibull   : p=2.760e-05 NOT normal
# RMS             boxcox    : p=4.968e-04 NOT normal
# RMS             lognorm   : p=2.540e-06 NOT normal
# RMS             student_t : p=3.294e-05 NOT normal
# RMS             yeojohnson: p=5.045e-04 NOT normal
# RMS             log       : p=3.694e-05 NOT normal
# RMS             sqrt      : p=1.972e-04 NOT normal
# RMS             zscore    : p=7.757e-04 NOT normal
# RMS             minmax    : p=7.757e-04 NOT normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=5.045e-04 NOT normal
# tau             original  : p=4.212e-03 NOT normal
# tau             gamma     : p=1.169e-04 NOT normal
# tau             weibull   : p=1.909e-04 NOT normal
# tau             boxcox    : p=4.656e-03 NOT normal
# tau             lognorm   : p=8.497e-05 NOT normal
# tau             student_t : p=1.358e-04 NOT normal
# tau             yeojohnson: p=4.649e-03 NOT normal
# tau             log       : p=3.996e-03 NOT normal
# tau             sqrt      : p=5.786e-03 NOT normal
# tau             zscore    : p=4.212e-03 NOT normal
# tau             minmax    : p=4.212e-03 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=4.649e-03 NOT normal
# AUC             original  : p=1.488e-03 NOT normal
# AUC             gamma     : p=2.819e-04 NOT normal
# AUC             weibull   : p=2.344e-04 NOT normal
# AUC             boxcox    : p=1.404e-02 NOT normal
# AUC             lognorm   : p=2.725e-04 NOT normal
# AUC             student_t : p=8.415e-05 NOT normal
# AUC             yeojohnson: p=1.404e-02 NOT normal
# AUC             log       : p=1.356e-02 NOT normal
# AUC             sqrt      : p=8.678e-03 NOT normal
# AUC             zscore    : p=1.488e-03 NOT normal
# AUC             minmax    : p=1.488e-03 NOT normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=1.404e-02 NOT normal
#
# Sex: male, Date: May20
# reactionTime    original  : p=5.936e-04 NOT normal
# reactionTime    gamma     : p=9.722e-05 NOT normal
# reactionTime    weibull   : p=2.452e-05 NOT normal
# reactionTime    boxcox    : p=1.575e-03 NOT normal
# reactionTime    lognorm   : p=1.207e-04 NOT normal
# reactionTime    student_t : p=4.284e-05 NOT normal
# reactionTime    yeojohnson: p=1.580e-03 NOT normal
# reactionTime    log       : p=1.415e-03 NOT normal
# reactionTime    sqrt      : p=1.010e-03 NOT normal
# reactionTime    zscore    : p=5.936e-04 NOT normal
# reactionTime    minmax    : p=5.936e-04 NOT normal
# reactionTime    quantile  : p=5.624e-06 NOT normal
# reactionTime    power     : p=1.580e-03 NOT normal
# peakTime        original  : p=1.819e-06 NOT normal
# peakTime        gamma     : p=2.033e-04 NOT normal
# peakTime        weibull   : p=1.028e-04 NOT normal
# peakTime        boxcox    : p=5.417e-06 NOT normal
# peakTime        lognorm   : p=1.789e-04 NOT normal
# peakTime        student_t : p=2.335e-03 NOT normal
# peakTime        yeojohnson: p=5.436e-06 NOT normal
# peakTime        log       : p=4.503e-06 NOT normal
# peakTime        sqrt      : p=3.133e-06 NOT normal
# peakTime        zscore    : p=1.819e-06 NOT normal
# peakTime        minmax    : p=1.819e-06 NOT normal
# peakTime        quantile  : p=3.033e-06 NOT normal
# peakTime        power     : p=5.436e-06 NOT normal
# difference      original  : p=7.823e-04 NOT normal
# difference      gamma     : p=6.896e-02 normal
# difference      weibull   : p=1.859e-01 normal
# difference      boxcox    : p=1.008e-02 NOT normal
# difference      lognorm   : p=5.768e-02 normal
# difference      student_t : p=1.018e-01 normal
# difference      yeojohnson: p=1.022e-02 NOT normal
# difference      log       : p=7.722e-03 NOT normal
# difference      sqrt      : p=3.239e-03 NOT normal
# difference      zscore    : p=7.823e-04 NOT normal
# difference      minmax    : p=7.823e-04 NOT normal
# difference      quantile  : p=1.061e-04 NOT normal
# difference      power     : p=1.022e-02 NOT normal
# peakValue       original  : p=1.526e-01 normal
# peakValue       gamma     : p=9.101e-04 NOT normal
# peakValue       weibull   : p=1.263e-03 NOT normal
# peakValue       boxcox    : p=1.632e-01 normal
# peakValue       lognorm   : p=8.092e-04 NOT normal
# peakValue       student_t : p=1.009e-03 NOT normal
# peakValue       yeojohnson: p=1.633e-01 normal
# peakValue       log       : p=6.335e-02 normal
# peakValue       sqrt      : p=1.116e-01 normal
# peakValue       zscore    : p=1.526e-01 normal
# peakValue       minmax    : p=1.526e-01 normal
# peakValue       quantile  : p=2.367e-04 NOT normal
# peakValue       power     : p=1.633e-01 normal
# PTPA            original  : p=1.789e-01 normal
# PTPA            gamma     : p=1.081e-03 NOT normal
# PTPA            weibull   : p=1.482e-03 NOT normal
# PTPA            boxcox    : p=1.893e-01 normal
# PTPA            lognorm   : p=9.578e-04 NOT normal
# PTPA            student_t : p=1.209e-03 NOT normal
# PTPA            yeojohnson: p=1.894e-01 normal
# PTPA            log       : p=7.564e-02 normal
# PTPA            sqrt      : p=1.325e-01 normal
# PTPA            zscore    : p=1.789e-01 normal
# PTPA            minmax    : p=1.789e-01 normal
# PTPA            quantile  : p=2.367e-04 NOT normal
# PTPA            power     : p=1.894e-01 normal
# PTTA            original  : p=2.294e-01 normal
# PTTA            gamma     : p=9.682e-04 NOT normal
# PTTA            weibull   : p=3.412e-03 NOT normal
# PTTA            boxcox    : p=3.561e-01 normal
# PTTA            lognorm   : p=7.352e-04 NOT normal
# PTTA            student_t : p=1.500e-03 NOT normal
# PTTA            yeojohnson: p=3.565e-01 normal
# PTTA            log       : p=4.224e-02 NOT normal
# PTTA            sqrt      : p=1.150e-01 normal
# PTTA            zscore    : p=2.294e-01 normal
# PTTA            minmax    : p=2.294e-01 normal
# PTTA            quantile  : p=2.367e-04 NOT normal
# PTTA            power     : p=3.565e-01 normal
# RMS             original  : p=1.161e-03 NOT normal
# RMS             gamma     : p=5.529e-05 NOT normal
# RMS             weibull   : p=2.645e-05 NOT normal
# RMS             boxcox    : p=7.869e-03 NOT normal
# RMS             lognorm   : p=7.327e-05 NOT normal
# RMS             student_t : p=2.692e-05 NOT normal
# RMS             yeojohnson: p=7.787e-03 NOT normal
# RMS             log       : p=5.659e-03 NOT normal
# RMS             sqrt      : p=2.825e-03 NOT normal
# RMS             zscore    : p=1.161e-03 NOT normal
# RMS             minmax    : p=1.161e-03 NOT normal
# RMS             quantile  : p=2.367e-04 NOT normal
# RMS             power     : p=7.787e-03 NOT normal
# tau             original  : p=3.070e-02 NOT normal
# tau             gamma     : p=1.021e-03 NOT normal
# tau             weibull   : p=1.066e-03 NOT normal
# tau             boxcox    : p=5.156e-02 normal
# tau             lognorm   : p=7.247e-04 NOT normal
# tau             student_t : p=5.826e-04 NOT normal
# tau             yeojohnson: p=5.138e-02 normal
# tau             log       : p=1.414e-02 NOT normal
# tau             sqrt      : p=5.138e-02 normal
# tau             zscore    : p=3.070e-02 NOT normal
# tau             minmax    : p=3.070e-02 NOT normal
# tau             quantile  : p=2.367e-04 NOT normal
# tau             power     : p=5.138e-02 normal
# AUC             original  : p=8.010e-05 NOT normal
# AUC             gamma     : p=1.238e-05 NOT normal
# AUC             weibull   : p=6.922e-06 NOT normal
# AUC             boxcox    : p=1.284e-03 NOT normal
# AUC             lognorm   : p=1.881e-05 NOT normal
# AUC             student_t : p=4.345e-06 NOT normal
# AUC             yeojohnson: p=1.284e-03 NOT normal
# AUC             log       : p=6.314e-04 NOT normal
# AUC             sqrt      : p=2.443e-04 NOT normal
# AUC             zscore    : p=8.010e-05 NOT normal
# AUC             minmax    : p=8.010e-05 NOT normal
# AUC             quantile  : p=2.367e-04 NOT normal
# AUC             power     : p=1.284e-03 NOT normal

# %% [markdown]
# ### ---> Box-Cox could work, especially for strength metrics which are already closer to normality by default

# %%
from scipy.stats import boxcox, shapiro
import numpy as np

df = dfs['RESULTS_MERGED']
metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

print("\nBox-Cox normality results (split by sex and date):")
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        for metric in metrics:
            vals = pd.to_numeric(df[(df['sex'] == sex) & (df['date'] == date)][metric], errors='coerce').dropna()
            # Box-Cox requires all values > 0 and at least 3 samples
            if len(vals) > 2 and (vals > 0).all():
                transformed, _ = boxcox(vals)
                stat, p = shapiro(transformed)
                print(f"{metric:15}: p={p:.3e} {'normal' if p > 0.05 else 'NOT normal'}")
            else:
                print(f"{metric:15}: Not enough data or non-positive values")
# Out:
# Box-Cox normality results (split by sex and date):
#
# Sex: female, Date: April16
# reactionTime   : p=1.508e-02 NOT normal
# peakTime       : p=5.655e-07 NOT normal
# difference     : p=5.876e-02 normal
# peakValue      : p=2.389e-01 normal
# PTPA           : p=2.692e-01 normal
# PTTA           : p=3.052e-01 normal
# RMS            : p=2.489e-01 normal
# tau            : p=2.939e-02 NOT normal
# AUC            : p=1.940e-01 normal
#
# Sex: female, Date: June26
# reactionTime   : p=4.105e-02 NOT normal
# peakTime       : p=6.263e-09 NOT normal
# difference     : p=7.952e-02 normal
# peakValue      : p=2.385e-02 NOT normal
# PTPA           : p=1.374e-02 NOT normal
# PTTA           : p=4.946e-02 NOT normal
# RMS            : p=5.253e-02 normal
# tau            : p=2.557e-01 normal
# AUC            : p=1.739e-02 NOT normal
#
# Sex: female, Date: May20
# reactionTime   : p=3.647e-03 NOT normal
# peakTime       : p=1.000e+00 normal
# difference     : p=5.187e-02 normal
# peakValue      : p=1.362e-01 normal
# PTPA           : p=1.432e-01 normal
# PTTA           : p=1.233e-01 normal
# RMS            : p=2.226e-01 normal
# tau            : p=2.004e-02 NOT normal
# AUC            : p=2.092e-01 normal
#
# Sex: male, Date: April16
# reactionTime   : p=2.514e-04 NOT normal
# peakTime       : p=5.409e-03 NOT normal
# difference     : p=1.610e-02 NOT normal
# peakValue      : p=5.952e-01 normal
# PTPA           : p=5.540e-01 normal
# PTTA           : p=7.222e-01 normal
# RMS            : p=5.703e-01 normal
# tau            : p=9.756e-01 normal
# AUC            : p=2.335e-01 normal
#
# Sex: male, Date: June26
# reactionTime   : p=9.713e-07 NOT normal
# peakTime       : p=3.757e-02 NOT normal
# difference     : p=1.033e-01 normal
# peakValue      : p=3.332e-05 NOT normal
# PTPA           : p=3.201e-05 NOT normal
# PTTA           : p=2.614e-04 NOT normal
# RMS            : p=4.968e-04 NOT normal
# tau            : p=4.656e-03 NOT normal
# AUC            : p=1.404e-02 NOT normal
#
# Sex: male, Date: May20
# reactionTime   : p=1.575e-03 NOT normal
# peakTime       : p=5.417e-06 NOT normal
# difference     : p=1.008e-02 NOT normal
# peakValue      : p=1.632e-01 normal
# PTPA           : p=1.893e-01 normal
# PTTA           : p=3.561e-01 normal
# RMS            : p=7.869e-03 NOT normal
# tau            : p=5.156e-02 normal
# AUC            : p=1.284e-03 NOT normal
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ### ---> not great, use non-parametric tests instead

# %% [markdown]
# ---

# %% [markdown]
# ## Uniformity

# %%
from scipy.stats import kstest

metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
        for metric in metrics:
            vals = pd.to_numeric(df_sub[metric], errors='coerce').dropna()
            if len(vals) > 2:
                stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
            else:
                print(f"{metric}: Not enough data")
# Out:
# Sex: female, Date: April16
# reactionTime: KS stat=0.283, p=2.559e-04 NOT uniform
# peakTime: KS stat=0.507, p=2.076e-13 NOT uniform
# difference: KS stat=0.418, p=4.791e-09 NOT uniform
# peakValue: KS stat=0.143, p=1.968e-01 uniform
# PTPA: KS stat=0.149, p=1.635e-01 uniform
# PTTA: KS stat=0.127, p=3.208e-01 uniform
# RMS: KS stat=0.156, p=1.275e-01 uniform
# tau: KS stat=0.060, p=9.842e-01 uniform
# AUC: KS stat=0.138, p=2.313e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.415, p=6.306e-09 NOT uniform
# peakTime: KS stat=0.549, p=8.472e-16 NOT uniform
# difference: KS stat=0.386, p=9.241e-08 NOT uniform
# peakValue: KS stat=0.189, p=3.725e-02 NOT uniform
# PTPA: KS stat=0.195, p=2.800e-02 NOT uniform
# PTTA: KS stat=0.186, p=4.150e-02 NOT uniform
# RMS: KS stat=0.110, p=4.923e-01 uniform
# tau: KS stat=0.287, p=1.990e-04 NOT uniform
# AUC: KS stat=0.105, p=5.535e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.299, p=9.080e-05 NOT uniform
# peakTime: KS stat=0.630, p=2.975e-21 NOT uniform
# difference: KS stat=0.450, p=1.737e-10 NOT uniform
# peakValue: KS stat=0.138, p=2.326e-01 uniform
# PTPA: KS stat=0.147, p=1.771e-01 uniform
# PTTA: KS stat=0.129, p=3.075e-01 uniform
# RMS: KS stat=0.173, p=6.878e-02 uniform
# tau: KS stat=0.403, p=1.942e-08 NOT uniform
# AUC: KS stat=0.269, p=6.161e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.505, p=2.853e-13 NOT uniform
# peakTime: KS stat=0.513, p=9.931e-14 NOT uniform
# difference: KS stat=0.445, p=2.954e-10 NOT uniform
# peakValue: KS stat=0.136, p=2.482e-01 uniform
# PTPA: KS stat=0.143, p=2.018e-01 uniform
# PTTA: KS stat=0.174, p=6.596e-02 uniform
# RMS: KS stat=0.109, p=5.025e-01 uniform
# tau: KS stat=0.308, p=4.844e-05 NOT uniform
# AUC: KS stat=0.136, p=2.437e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.490, p=1.787e-12 NOT uniform
# peakTime: KS stat=0.337, p=5.715e-06 NOT uniform
# difference: KS stat=0.301, p=7.811e-05 NOT uniform
# peakValue: KS stat=0.247, p=2.128e-03 NOT uniform
# PTPA: KS stat=0.255, p=1.388e-03 NOT uniform
# PTTA: KS stat=0.172, p=7.228e-02 uniform
# RMS: KS stat=0.178, p=5.723e-02 uniform
# tau: KS stat=0.197, p=2.613e-02 NOT uniform
# AUC: KS stat=0.241, p=2.999e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.279, p=3.248e-04 NOT uniform
# peakTime: KS stat=0.487, p=2.673e-12 NOT uniform
# difference: KS stat=0.423, p=2.930e-09 NOT uniform
# peakValue: KS stat=0.092, p=7.191e-01 uniform
# PTPA: KS stat=0.094, p=6.878e-01 uniform
# PTTA: KS stat=0.137, p=2.385e-01 uniform
# RMS: KS stat=0.187, p=3.938e-02 NOT uniform
# tau: KS stat=0.159, p=1.165e-01 uniform
# AUC: KS stat=0.266, p=7.481e-04 NOT uniform

# %% [markdown]
# ### ---> not too uniform

# %%
from scipy.stats import gamma, weibull_min, boxcox, lognorm, t, kstest, yeojohnson
import numpy as np
import pandas as pd

try:
    from sklearn.preprocessing import QuantileTransformer, PowerTransformer
    sklearn_available = True
except ImportError:
    sklearn_available = False

df = dfs['RESULTS_MERGED']
metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]

def test_uniformity_grouped(transform_func, df, metrics, label):
    print(f"\n{label} transformation (grouped by sex and date):")
    for sex in df['sex'].unique():
        for date in df['date'].unique():
            df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
            if len(df_sub) < 3:
                continue
            transformed = transform_func(df_sub, metrics)
            print(f"\nSex: {sex}, Date: {date}")
            for metric in metrics:
                vals = pd.to_numeric(transformed[metric], errors='coerce').dropna()
                if len(vals) > 2:
                    stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                    print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
                else:
                    print(f"{metric}: Not enough data")

def gamma_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals > 0).all():
            params = gamma.fit(vals, floc=0)
            df_copy[metric] = gamma.cdf(pd.to_numeric(df_copy[metric], errors='coerce'), *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def weibull_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            params = weibull_min.fit(vals, floc=0)
            df_copy[metric] = weibull_min.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def boxcox_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            transformed, _ = boxcox(vals)
            df_copy.loc[vals.index, metric] = transformed
        else:
            df_copy[metric] = np.nan
    return df_copy

def lognorm_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2 and (vals > 0).all():
            params = lognorm.fit(vals, floc=0)
            df_copy[metric] = lognorm.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def student_t_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna() + 1e-6
        if len(vals) > 2:
            params = t.fit(vals)
            df_copy[metric] = t.cdf(pd.to_numeric(df_copy[metric], errors='coerce') + 1e-6, *params)
        else:
            df_copy[metric] = np.nan
    return df_copy

def yeojohnson_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            transformed, _ = yeojohnson(vals)
            df_copy.loc[vals.index, metric] = transformed
        else:
            df_copy[metric] = np.nan
    return df_copy

def log_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals > 0).all():
            df_copy.loc[vals.index, metric] = np.log(vals + 1e-6)
        else:
            df_copy[metric] = np.nan
    return df_copy

def sqrt_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2 and (vals >= 0).all():
            df_copy.loc[vals.index, metric] = np.sqrt(vals)
        else:
            df_copy[metric] = np.nan
    return df_copy

def zscore_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            df_copy.loc[vals.index, metric] = (vals - vals.mean()) / (vals.std() + 1e-8)
        else:
            df_copy[metric] = np.nan
    return df_copy

def minmax_transform(df, metrics):
    df_copy = df.copy()
    for metric in metrics:
        vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna()
        if len(vals) > 2:
            df_copy.loc[vals.index, metric] = (vals - vals.min()) / (vals.max() - vals.min() + 1e-8)
        else:
            df_copy[metric] = np.nan
    return df_copy

if sklearn_available:
    def quantile_transform(df, metrics):
        df_copy = df.copy()
        qt = QuantileTransformer(output_distribution='uniform', random_state=0)
        for metric in metrics:
            vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna().values.reshape(-1, 1)
            if len(vals) > 2:
                transformed = qt.fit_transform(vals).flatten()
                df_copy.loc[df_copy[metric].dropna().index, metric] = transformed
            else:
                df_copy[metric] = np.nan
        return df_copy

    def power_transform(df, metrics):
        df_copy = df.copy()
        pt = PowerTransformer(method='yeo-johnson')
        for metric in metrics:
            vals = pd.to_numeric(df_copy[metric], errors='coerce').dropna().values.reshape(-1, 1)
            if len(vals) > 2:
                transformed = pt.fit_transform(vals).flatten()
                df_copy.loc[df_copy[metric].dropna().index, metric] = transformed
            else:
                df_copy[metric] = np.nan
        return df_copy

# Run all transformations grouped by sex and date
test_uniformity_grouped(gamma_transform, df, metrics, "Gamma")
test_uniformity_grouped(weibull_transform, df, metrics, "Weibull")
test_uniformity_grouped(boxcox_transform, df, metrics, "Box-Cox")
test_uniformity_grouped(lognorm_transform, df, metrics, "Lognormal")
test_uniformity_grouped(student_t_transform, df, metrics, "Student-t")
test_uniformity_grouped(yeojohnson_transform, df, metrics, "Yeo-Johnson")
test_uniformity_grouped(log_transform, df, metrics, "Log")
test_uniformity_grouped(sqrt_transform, df, metrics, "Sqrt")
test_uniformity_grouped(zscore_transform, df, metrics, "Z-score")
test_uniformity_grouped(minmax_transform, df, metrics, "Min-max")

if sklearn_available:
    test_uniformity_grouped(quantile_transform, df, metrics, "Quantile (uniform)")
    test_uniformity_grouped(power_transform, df, metrics, "Power (Yeo-Johnson, sklearn)")
else:
    print("\nscikit-learn not available: skipping quantile and power transforms.")
# Out:
# Gamma transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.220, p=8.958e-03 NOT uniform
# peakTime: KS stat=0.335, p=6.785e-06 NOT uniform
# difference: KS stat=0.181, p=5.152e-02 uniform
# peakValue: KS stat=0.127, p=3.229e-01 uniform
# PTPA: KS stat=0.120, p=3.836e-01 uniform
# PTTA: KS stat=0.128, p=3.124e-01 uniform
# RMS: KS stat=0.159, p=1.173e-01 uniform
# tau: KS stat=0.132, p=2.811e-01 uniform
# AUC: KS stat=0.159, p=1.174e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.254, p=1.490e-03 NOT uniform
# peakTime: KS stat=0.410, p=1.020e-08 NOT uniform
# difference: KS stat=0.208, p=1.618e-02 NOT uniform
# peakValue: KS stat=0.200, p=2.226e-02 NOT uniform
# PTPA: KS stat=0.217, p=1.020e-02 NOT uniform
# PTTA: KS stat=0.188, p=3.782e-02 NOT uniform
# RMS: KS stat=0.195, p=2.882e-02 NOT uniform
# tau: KS stat=0.181, p=5.145e-02 uniform
# AUC: KS stat=0.174, p=6.744e-02 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.169, p=8.152e-02 uniform
# peakTime: KS stat=0.448, p=2.169e-10 NOT uniform
# difference: KS stat=0.262, p=9.494e-04 NOT uniform
# peakValue: KS stat=0.170, p=7.741e-02 uniform
# PTPA: KS stat=0.168, p=8.318e-02 uniform
# PTTA: KS stat=0.153, p=1.430e-01 uniform
# RMS: KS stat=0.152, p=1.470e-01 uniform
# tau: KS stat=0.212, p=1.329e-02 NOT uniform
# AUC: KS stat=0.123, p=3.541e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.306, p=5.606e-05 NOT uniform
# peakTime: KS stat=0.217, p=1.028e-02 NOT uniform
# difference: KS stat=0.166, p=9.151e-02 uniform
# peakValue: KS stat=0.123, p=3.601e-01 uniform
# PTPA: KS stat=0.134, p=2.604e-01 uniform
# PTTA: KS stat=0.125, p=3.401e-01 uniform
# RMS: KS stat=0.124, p=3.456e-01 uniform
# tau: KS stat=0.113, p=4.586e-01 uniform
# AUC: KS stat=0.149, p=1.621e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.287, p=2.035e-04 NOT uniform
# peakTime: KS stat=0.164, p=9.828e-02 uniform
# difference: KS stat=0.151, p=1.517e-01 uniform
# peakValue: KS stat=0.325, p=1.453e-05 NOT uniform
# PTPA: KS stat=0.330, p=9.927e-06 NOT uniform
# PTTA: KS stat=0.253, p=1.557e-03 NOT uniform
# RMS: KS stat=0.211, p=1.393e-02 NOT uniform
# tau: KS stat=0.175, p=6.344e-02 uniform
# AUC: KS stat=0.162, p=1.057e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.255, p=1.354e-03 NOT uniform
# peakTime: KS stat=0.247, p=2.150e-03 NOT uniform
# difference: KS stat=0.160, p=1.118e-01 uniform
# peakValue: KS stat=0.129, p=3.018e-01 uniform
# PTPA: KS stat=0.113, p=4.579e-01 uniform
# PTTA: KS stat=0.126, p=3.299e-01 uniform
# RMS: KS stat=0.164, p=9.788e-02 uniform
# tau: KS stat=0.117, p=4.140e-01 uniform
# AUC: KS stat=0.186, p=4.221e-02 NOT uniform
#
# Weibull transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.172, p=7.117e-02 uniform
# peakTime: KS stat=0.295, p=1.165e-04 NOT uniform
# difference: KS stat=0.145, p=1.860e-01 uniform
# peakValue: KS stat=0.121, p=3.789e-01 uniform
# PTPA: KS stat=0.119, p=4.001e-01 uniform
# PTTA: KS stat=0.103, p=5.799e-01 uniform
# RMS: KS stat=0.098, p=6.465e-01 uniform
# tau: KS stat=0.167, p=8.769e-02 uniform
# AUC: KS stat=0.083, p=8.161e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.175, p=6.425e-02 uniform
# peakTime: KS stat=0.480, p=6.030e-12 NOT uniform
# difference: KS stat=0.284, p=2.440e-04 NOT uniform
# peakValue: KS stat=0.142, p=2.040e-01 uniform
# PTPA: KS stat=0.157, p=1.265e-01 uniform
# PTTA: KS stat=0.124, p=3.517e-01 uniform
# RMS: KS stat=0.145, p=1.885e-01 uniform
# tau: KS stat=0.241, p=3.047e-03 NOT uniform
# AUC: KS stat=0.135, p=2.551e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.166, p=9.146e-02 uniform
# peakTime: KS stat=0.532, p=8.467e-15 NOT uniform
# difference: KS stat=0.324, p=1.552e-05 NOT uniform
# peakValue: KS stat=0.110, p=4.942e-01 uniform
# PTPA: KS stat=0.114, p=4.501e-01 uniform
# PTTA: KS stat=0.111, p=4.814e-01 uniform
# RMS: KS stat=0.099, p=6.291e-01 uniform
# tau: KS stat=0.272, p=5.127e-04 NOT uniform
# AUC: KS stat=0.104, p=5.719e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.240, p=3.204e-03 NOT uniform
# peakTime: KS stat=0.313, p=3.388e-05 NOT uniform
# difference: KS stat=0.231, p=5.238e-03 NOT uniform
# peakValue: KS stat=0.090, p=7.382e-01 uniform
# PTPA: KS stat=0.089, p=7.529e-01 uniform
# PTTA: KS stat=0.075, p=9.014e-01 uniform
# RMS: KS stat=0.086, p=7.830e-01 uniform
# tau: KS stat=0.181, p=5.120e-02 uniform
# AUC: KS stat=0.112, p=4.682e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.294, p=1.232e-04 NOT uniform
# peakTime: KS stat=0.244, p=2.573e-03 NOT uniform
# difference: KS stat=0.147, p=1.761e-01 uniform
# peakValue: KS stat=0.246, p=2.286e-03 NOT uniform
# PTPA: KS stat=0.251, p=1.724e-03 NOT uniform
# PTTA: KS stat=0.209, p=1.505e-02 NOT uniform
# RMS: KS stat=0.216, p=1.075e-02 NOT uniform
# tau: KS stat=0.204, p=1.865e-02 NOT uniform
# AUC: KS stat=0.179, p=5.543e-02 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.295, p=1.194e-04 NOT uniform
# peakTime: KS stat=0.319, p=2.224e-05 NOT uniform
# difference: KS stat=0.238, p=3.538e-03 NOT uniform
# peakValue: KS stat=0.111, p=4.900e-01 uniform
# PTPA: KS stat=0.110, p=5.009e-01 uniform
# PTTA: KS stat=0.085, p=7.978e-01 uniform
# RMS: KS stat=0.220, p=8.991e-03 NOT uniform
# tau: KS stat=0.117, p=4.187e-01 uniform
# AUC: KS stat=0.238, p=3.498e-03 NOT uniform
#
# Box-Cox transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.207, p=1.684e-02 NOT uniform
# peakTime: KS stat=0.343, p=3.454e-06 NOT uniform
# difference: KS stat=0.308, p=4.787e-05 NOT uniform
# peakValue: KS stat=0.181, p=5.092e-02 uniform
# PTPA: KS stat=0.186, p=4.142e-02 NOT uniform
# PTTA: KS stat=0.132, p=2.816e-01 uniform
# RMS: KS stat=0.105, p=5.521e-01 uniform
# tau: KS stat=0.060, p=9.829e-01 uniform
# AUC: KS stat=0.118, p=4.082e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.229, p=5.588e-03 NOT uniform
# peakTime: KS stat=0.506, p=2.587e-13 NOT uniform
# difference: KS stat=0.253, p=1.546e-03 NOT uniform
# peakValue: KS stat=0.100, p=6.222e-01 uniform
# PTPA: KS stat=0.121, p=3.823e-01 uniform
# PTTA: KS stat=0.120, p=3.915e-01 uniform
# RMS: KS stat=0.094, p=6.860e-01 uniform
# tau: KS stat=0.146, p=1.790e-01 uniform
# AUC: KS stat=0.118, p=4.128e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.301, p=7.949e-05 NOT uniform
# peakTime: KS stat=nan, p=nan NOT uniform
# difference: KS stat=0.317, p=2.517e-05 NOT uniform
# peakValue: KS stat=0.088, p=7.602e-01 uniform
# PTPA: KS stat=0.092, p=7.161e-01 uniform
# PTTA: KS stat=0.088, p=7.618e-01 uniform
# RMS: KS stat=0.218, p=9.989e-03 NOT uniform
# tau: KS stat=0.151, p=1.533e-01 uniform
# AUC: KS stat=0.277, p=3.770e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.335, p=6.687e-06 NOT uniform
# peakTime: KS stat=0.298, p=9.634e-05 NOT uniform
# difference: KS stat=0.305, p=5.735e-05 NOT uniform
# peakValue: KS stat=0.118, p=4.082e-01 uniform
# PTPA: KS stat=0.188, p=3.899e-02 NOT uniform
# PTTA: KS stat=0.217, p=1.015e-02 NOT uniform
# RMS: KS stat=0.123, p=3.608e-01 uniform
# tau: KS stat=0.134, p=2.593e-01 uniform
# AUC: KS stat=0.119, p=4.028e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.497, p=7.245e-13 NOT uniform
# peakTime: KS stat=0.237, p=3.704e-03 NOT uniform
# difference: KS stat=0.244, p=2.601e-03 NOT uniform
# peakValue: KS stat=0.198, p=2.444e-02 NOT uniform
# PTPA: KS stat=0.203, p=1.966e-02 NOT uniform
# PTTA: KS stat=0.162, p=1.059e-01 uniform
# RMS: KS stat=0.162, p=1.068e-01 uniform
# tau: KS stat=0.115, p=4.405e-01 uniform
# AUC: KS stat=0.111, p=4.799e-01 uniform
#
# Sex: male, Date: May20
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2148: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# reactionTime: KS stat=0.282, p=2.734e-04 NOT uniform
# peakTime: KS stat=0.404, p=1.863e-08 NOT uniform
# difference: KS stat=0.313, p=3.363e-05 NOT uniform
# peakValue: KS stat=0.074, p=9.059e-01 uniform
# PTPA: KS stat=0.078, p=8.745e-01 uniform
# PTTA: KS stat=0.122, p=3.693e-01 uniform
# RMS: KS stat=0.112, p=4.696e-01 uniform
# tau: KS stat=0.105, p=5.570e-01 uniform
# AUC: KS stat=0.125, p=3.361e-01 uniform
#
# Lognormal transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.222, p=8.160e-03 NOT uniform
# peakTime: KS stat=0.337, p=5.578e-06 NOT uniform
# difference: KS stat=0.185, p=4.396e-02 NOT uniform
# peakValue: KS stat=0.143, p=1.991e-01 uniform
# PTPA: KS stat=0.141, p=2.153e-01 uniform
# PTTA: KS stat=0.148, p=1.670e-01 uniform
# RMS: KS stat=0.181, p=5.078e-02 uniform
# tau: KS stat=0.136, p=2.479e-01 uniform
# AUC: KS stat=0.182, p=4.901e-02 NOT uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.270, p=5.572e-04 NOT uniform
# peakTime: KS stat=0.404, p=1.722e-08 NOT uniform
# difference: KS stat=0.196, p=2.667e-02 NOT uniform
# peakValue: KS stat=0.215, p=1.151e-02 NOT uniform
# PTPA: KS stat=0.231, p=5.212e-03 NOT uniform
# PTTA: KS stat=0.204, p=1.937e-02 NOT uniform
# RMS: KS stat=0.208, p=1.561e-02 NOT uniform
# tau: KS stat=0.169, p=8.071e-02 uniform
# AUC: KS stat=0.193, p=3.122e-02 NOT uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.178, p=5.638e-02 uniform
# peakTime: KS stat=0.441, p=4.595e-10 NOT uniform
# difference: KS stat=0.253, p=1.543e-03 NOT uniform
# peakValue: KS stat=0.193, p=3.100e-02 NOT uniform
# PTPA: KS stat=0.187, p=3.901e-02 NOT uniform
# PTTA: KS stat=0.171, p=7.414e-02 uniform
# RMS: KS stat=0.174, p=6.665e-02 uniform
# tau: KS stat=0.196, p=2.765e-02 NOT uniform
# AUC: KS stat=0.139, p=2.237e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.324, p=1.494e-05 NOT uniform
# peakTime: KS stat=0.208, p=1.613e-02 NOT uniform
# difference: KS stat=0.153, p=1.423e-01 uniform
# peakValue: KS stat=0.142, p=2.025e-01 uniform
# PTPA: KS stat=0.154, p=1.402e-01 uniform
# PTTA: KS stat=0.144, p=1.953e-01 uniform
# RMS: KS stat=0.136, p=2.492e-01 uniform
# tau: KS stat=0.097, p=6.479e-01 uniform
# AUC: KS stat=0.166, p=9.143e-02 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.293, p=1.361e-04 NOT uniform
# peakTime: KS stat=0.151, p=1.514e-01 uniform
# difference: KS stat=0.173, p=7.033e-02 uniform
# peakValue: KS stat=0.360, p=9.197e-07 NOT uniform
# PTPA: KS stat=0.364, p=6.314e-07 NOT uniform
# PTTA: KS stat=0.293, p=1.328e-04 NOT uniform
# RMS: KS stat=0.254, p=1.466e-03 NOT uniform
# tau: KS stat=0.161, p=1.070e-01 uniform
# AUC: KS stat=0.152, p=1.498e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.249, p=1.923e-03 NOT uniform
# peakTime: KS stat=0.253, p=1.565e-03 NOT uniform
# difference: KS stat=0.152, p=1.502e-01 uniform
# peakValue: KS stat=0.141, p=2.106e-01 uniform
# PTPA: KS stat=0.123, p=3.580e-01 uniform
# PTTA: KS stat=0.140, p=2.188e-01 uniform
# RMS: KS stat=0.170, p=7.840e-02 uniform
# tau: KS stat=0.139, p=2.250e-01 uniform
# AUC: KS stat=0.172, p=7.114e-02 uniform
#
# Student-t transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.216, p=1.077e-02 NOT uniform
# peakTime: KS stat=0.329, p=1.019e-05 NOT uniform
# difference: KS stat=0.140, p=2.172e-01 uniform
# peakValue: KS stat=0.119, p=4.021e-01 uniform
# PTPA: KS stat=0.117, p=4.220e-01 uniform
# PTTA: KS stat=0.101, p=6.026e-01 uniform
# RMS: KS stat=0.114, p=4.469e-01 uniform
# tau: KS stat=0.125, p=3.416e-01 uniform
# AUC: KS stat=0.112, p=4.706e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.272, p=4.990e-04 NOT uniform
# peakTime: KS stat=0.335, p=6.517e-06 NOT uniform
# difference: KS stat=0.134, p=2.621e-01 uniform
# peakValue: KS stat=0.171, p=7.659e-02 uniform
# PTPA: KS stat=0.189, p=3.679e-02 NOT uniform
# PTTA: KS stat=0.156, p=1.303e-01 uniform
# RMS: KS stat=0.167, p=8.875e-02 uniform
# tau: KS stat=0.204, p=1.921e-02 NOT uniform
# AUC: KS stat=0.135, p=2.553e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.120, p=3.829e-01 uniform
# peakTime: KS stat=0.470, p=1.942e-11 NOT uniform
# difference: KS stat=0.131, p=2.868e-01 uniform
# peakValue: KS stat=0.129, p=3.066e-01 uniform
# PTPA: KS stat=0.132, p=2.761e-01 uniform
# PTTA: KS stat=0.125, p=3.418e-01 uniform
# RMS: KS stat=0.115, p=4.448e-01 uniform
# tau: KS stat=0.223, p=7.764e-03 NOT uniform
# AUC: KS stat=0.104, p=5.686e-01 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.319, p=2.136e-05 NOT uniform
# peakTime: KS stat=0.127, p=3.234e-01 uniform
# difference: KS stat=0.113, p=4.636e-01 uniform
# peakValue: KS stat=0.085, p=7.953e-01 uniform
# PTPA: KS stat=0.096, p=6.719e-01 uniform
# PTTA: KS stat=0.088, p=7.688e-01 uniform
# RMS: KS stat=0.101, p=6.019e-01 uniform
# tau: KS stat=0.125, p=3.436e-01 uniform
# AUC: KS stat=0.115, p=4.405e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.312, p=3.645e-05 NOT uniform
# peakTime: KS stat=0.190, p=3.553e-02 NOT uniform
# difference: KS stat=0.124, p=3.468e-01 uniform
# peakValue: KS stat=0.248, p=2.045e-03 NOT uniform
# PTPA: KS stat=0.254, p=1.434e-03 NOT uniform
# PTTA: KS stat=0.213, p=1.225e-02 NOT uniform
# RMS: KS stat=0.224, p=7.404e-03 NOT uniform
# tau: KS stat=0.213, p=1.279e-02 NOT uniform
# AUC: KS stat=0.204, p=1.906e-02 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.292, p=1.432e-04 NOT uniform
# peakTime: KS stat=0.219, p=9.161e-03 NOT uniform
# difference: KS stat=0.186, p=4.145e-02 NOT uniform
# peakValue: KS stat=0.107, p=5.263e-01 uniform
# PTPA: KS stat=0.099, p=6.329e-01 uniform
# PTTA: KS stat=0.101, p=6.076e-01 uniform
# RMS: KS stat=0.205, p=1.792e-02 NOT uniform
# tau: KS stat=0.147, p=1.741e-01 uniform
# AUC: KS stat=0.248, p=2.045e-03 NOT uniform
#
# Yeo-Johnson transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.207, p=1.689e-02 NOT uniform
# peakTime: KS stat=0.343, p=3.472e-06 NOT uniform
# difference: KS stat=0.308, p=4.760e-05 NOT uniform
# peakValue: KS stat=0.181, p=5.042e-02 uniform
# PTPA: KS stat=0.186, p=4.102e-02 NOT uniform
# PTTA: KS stat=0.132, p=2.798e-01 uniform
# RMS: KS stat=0.105, p=5.613e-01 uniform
# tau: KS stat=0.060, p=9.828e-01 uniform
# AUC: KS stat=0.118, p=4.082e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.230, p=5.505e-03 NOT uniform
# peakTime: KS stat=0.504, p=3.339e-13 NOT uniform
# difference: KS stat=0.253, p=1.563e-03 NOT uniform
# peakValue: KS stat=0.099, p=6.260e-01 uniform
# PTPA: KS stat=0.120, p=3.852e-01 uniform
# PTTA: KS stat=0.119, p=3.945e-01 uniform
# RMS: KS stat=0.095, p=6.781e-01 uniform
# tau: KS stat=0.146, p=1.790e-01 uniform
# AUC: KS stat=0.118, p=4.128e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.302, p=7.147e-05 NOT uniform
# peakTime: KS stat=0.397, p=3.382e-08 NOT uniform
# difference: KS stat=0.317, p=2.583e-05 NOT uniform
# peakValue: KS stat=0.088, p=7.640e-01 uniform
# PTPA: KS stat=0.092, p=7.200e-01 uniform
# PTTA: KS stat=0.088, p=7.663e-01 uniform
# RMS: KS stat=0.218, p=9.666e-03 NOT uniform
# tau: KS stat=0.151, p=1.535e-01 uniform
# AUC: KS stat=0.277, p=3.770e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.336, p=6.278e-06 NOT uniform
# peakTime: KS stat=0.298, p=9.608e-05 NOT uniform
# difference: KS stat=0.305, p=5.719e-05 NOT uniform
# peakValue: KS stat=0.118, p=4.072e-01 uniform
# PTPA: KS stat=0.188, p=3.880e-02 NOT uniform
# PTTA: KS stat=0.217, p=1.010e-02 NOT uniform
# RMS: KS stat=0.123, p=3.583e-01 uniform
# tau: KS stat=0.134, p=2.594e-01 uniform
# AUC: KS stat=0.119, p=4.029e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.498, p=6.803e-13 NOT uniform
# peakTime: KS stat=0.237, p=3.732e-03 NOT uniform
# difference: KS stat=0.244, p=2.587e-03 NOT uniform
# peakValue: KS stat=0.198, p=2.496e-02 NOT uniform
# PTPA: KS stat=0.203, p=2.008e-02 NOT uniform
# PTTA: KS stat=0.161, p=1.076e-01 uniform
# RMS: KS stat=0.162, p=1.042e-01 uniform
# tau: KS stat=0.115, p=4.375e-01 uniform
# AUC: KS stat=0.111, p=4.800e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.282, p=2.678e-04 NOT uniform
# peakTime: KS stat=0.403, p=1.913e-08 NOT uniform
# difference: KS stat=0.312, p=3.500e-05 NOT uniform
# peakValue: KS stat=0.074, p=9.066e-01 uniform
# PTPA: KS stat=0.078, p=8.753e-01 uniform
# PTTA: KS stat=0.122, p=3.685e-01 uniform
# RMS: KS stat=0.112, p=4.723e-01 uniform
# tau: KS stat=0.104, p=5.637e-01 uniform
# AUC: KS stat=0.125, p=3.361e-01 uniform
#
# Log transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.308, p=4.838e-05 NOT uniform
# peakTime: KS stat=0.528, p=1.543e-14 NOT uniform
# difference: KS stat=0.452, p=1.395e-10 NOT uniform
# peakValue: KS stat=0.219, p=9.460e-03 NOT uniform
# PTPA: KS stat=0.218, p=9.875e-03 NOT uniform
# PTTA: KS stat=0.228, p=6.129e-03 NOT uniform
# RMS: KS stat=0.260, p=1.051e-03 NOT uniform
# tau: KS stat=0.091, p=7.307e-01 uniform
# AUC: KS stat=0.247, p=2.187e-03 NOT uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.522, p=3.410e-14 NOT uniform
# peakTime: KS stat=0.511, p=1.326e-13 NOT uniform
# difference: KS stat=0.308, p=4.719e-05 NOT uniform
# peakValue: KS stat=0.304, p=6.277e-05 NOT uniform
# PTPA: KS stat=0.299, p=8.661e-05 NOT uniform
# PTTA: KS stat=0.307, p=5.044e-05 NOT uniform
# RMS: KS stat=0.235, p=4.230e-03 NOT uniform
# tau: KS stat=0.221, p=8.386e-03 NOT uniform
# AUC: KS stat=0.222, p=8.265e-03 NOT uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.413, p=7.500e-09 NOT uniform
# peakTime: KS stat=0.609, p=9.640e-20 NOT uniform
# difference: KS stat=0.385, p=1.068e-07 NOT uniform
# peakValue: KS stat=0.281, p=2.844e-04 NOT uniform
# PTPA: KS stat=0.292, p=1.416e-04 NOT uniform
# PTTA: KS stat=0.271, p=5.258e-04 NOT uniform
# RMS: KS stat=0.249, p=1.971e-03 NOT uniform
# tau: KS stat=0.291, p=1.531e-04 NOT uniform
# AUC: KS stat=0.184, p=4.595e-02 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.602, p=2.873e-19 NOT uniform
# peakTime: KS stat=0.446, p=2.592e-10 NOT uniform
# difference: KS stat=0.330, p=9.464e-06 NOT uniform
# peakValue: KS stat=0.243, p=2.772e-03 NOT uniform
# PTPA: KS stat=0.230, p=5.531e-03 NOT uniform
# PTTA: KS stat=0.246, p=2.355e-03 NOT uniform
# RMS: KS stat=0.224, p=7.317e-03 NOT uniform
# tau: KS stat=0.214, p=1.193e-02 NOT uniform
# AUC: KS stat=0.186, p=4.201e-02 NOT uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.545, p=1.393e-15 NOT uniform
# peakTime: KS stat=0.256, p=1.323e-03 NOT uniform
# difference: KS stat=0.186, p=4.206e-02 NOT uniform
# peakValue: KS stat=0.376, p=2.281e-07 NOT uniform
# PTPA: KS stat=0.381, p=1.475e-07 NOT uniform
# PTTA: KS stat=0.317, p=2.578e-05 NOT uniform
# RMS: KS stat=0.265, p=7.982e-04 NOT uniform
# tau: KS stat=0.107, p=5.335e-01 uniform
# AUC: KS stat=0.130, p=2.933e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.242, p=2.886e-03 NOT uniform
# peakTime: KS stat=0.434, p=9.013e-10 NOT uniform
# difference: KS stat=0.345, p=2.971e-06 NOT uniform
# peakValue: KS stat=0.168, p=8.268e-02 uniform
# PTPA: KS stat=0.174, p=6.690e-02 uniform
# PTTA: KS stat=0.224, p=7.457e-03 NOT uniform
# RMS: KS stat=0.091, p=7.220e-01 uniform
# tau: KS stat=0.209, p=1.514e-02 NOT uniform
# AUC: KS stat=0.139, p=2.286e-01 uniform
#
# Sqrt transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.295, p=1.140e-04 NOT uniform
# peakTime: KS stat=0.518, p=5.734e-14 NOT uniform
# difference: KS stat=0.435, p=8.512e-10 NOT uniform
# peakValue: KS stat=0.168, p=8.360e-02 uniform
# PTPA: KS stat=0.167, p=8.627e-02 uniform
# PTTA: KS stat=0.177, p=5.955e-02 uniform
# RMS: KS stat=0.208, p=1.554e-02 NOT uniform
# tau: KS stat=0.075, p=8.969e-01 uniform
# AUC: KS stat=0.192, p=3.188e-02 NOT uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.469, p=2.013e-11 NOT uniform
# peakTime: KS stat=0.530, p=1.092e-14 NOT uniform
# difference: KS stat=0.347, p=2.496e-06 NOT uniform
# peakValue: KS stat=0.247, p=2.226e-03 NOT uniform
# PTPA: KS stat=0.247, p=2.148e-03 NOT uniform
# PTTA: KS stat=0.246, p=2.257e-03 NOT uniform
# RMS: KS stat=0.169, p=8.185e-02 uniform
# tau: KS stat=0.252, p=1.632e-03 NOT uniform
# AUC: KS stat=0.163, p=1.016e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.355, p=1.337e-06 NOT uniform
# peakTime: KS stat=0.619, p=1.687e-20 NOT uniform
# difference: KS stat=0.417, p=5.227e-09 NOT uniform
# peakValue: KS stat=0.208, p=1.569e-02 NOT uniform
# PTPA: KS stat=0.218, p=9.850e-03 NOT uniform
# PTTA: KS stat=0.199, p=2.389e-02 NOT uniform
# RMS: KS stat=0.177, p=6.072e-02 uniform
# tau: KS stat=0.346, p=2.708e-06 NOT uniform
# AUC: KS stat=0.218, p=9.951e-03 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.554, p=3.996e-16 NOT uniform
# peakTime: KS stat=0.480, p=5.766e-12 NOT uniform
# difference: KS stat=0.387, p=8.531e-08 NOT uniform
# peakValue: KS stat=0.189, p=3.694e-02 NOT uniform
# PTPA: KS stat=0.177, p=5.959e-02 uniform
# PTTA: KS stat=0.189, p=3.611e-02 NOT uniform
# RMS: KS stat=0.163, p=1.029e-01 uniform
# tau: KS stat=0.261, p=9.971e-04 NOT uniform
# AUC: KS stat=0.134, p=2.632e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.518, p=5.582e-14 NOT uniform
# peakTime: KS stat=0.297, p=1.038e-04 NOT uniform
# difference: KS stat=0.242, p=2.900e-03 NOT uniform
# peakValue: KS stat=0.313, p=3.295e-05 NOT uniform
# PTPA: KS stat=0.320, p=2.092e-05 NOT uniform
# PTTA: KS stat=0.245, p=2.408e-03 NOT uniform
# RMS: KS stat=0.178, p=5.758e-02 uniform
# tau: KS stat=0.150, p=1.600e-01 uniform
# AUC: KS stat=0.143, p=1.993e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.248, p=2.056e-03 NOT uniform
# peakTime: KS stat=0.460, p=5.388e-11 NOT uniform
# difference: KS stat=0.384, p=1.141e-07 NOT uniform
# peakValue: KS stat=0.129, p=3.058e-01 uniform
# PTPA: KS stat=0.134, p=2.617e-01 uniform
# PTTA: KS stat=0.180, p=5.197e-02 uniform
# RMS: KS stat=0.141, p=2.146e-01 uniform
# tau: KS stat=0.106, p=5.449e-01 uniform
# AUC: KS stat=0.205, p=1.827e-02 NOT uniform
#
# Z-score transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.283, p=2.559e-04 NOT uniform
# peakTime: KS stat=0.507, p=2.076e-13 NOT uniform
# difference: KS stat=0.418, p=4.791e-09 NOT uniform
# peakValue: KS stat=0.143, p=1.968e-01 uniform
# PTPA: KS stat=0.149, p=1.635e-01 uniform
# PTTA: KS stat=0.127, p=3.208e-01 uniform
# RMS: KS stat=0.156, p=1.275e-01 uniform
# tau: KS stat=0.060, p=9.842e-01 uniform
# AUC: KS stat=0.138, p=2.313e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.415, p=6.306e-09 NOT uniform
# peakTime: KS stat=0.549, p=8.472e-16 NOT uniform
# difference: KS stat=0.386, p=9.241e-08 NOT uniform
# peakValue: KS stat=0.189, p=3.725e-02 NOT uniform
# PTPA: KS stat=0.195, p=2.800e-02 NOT uniform
# PTTA: KS stat=0.186, p=4.150e-02 NOT uniform
# RMS: KS stat=0.110, p=4.923e-01 uniform
# tau: KS stat=0.287, p=1.990e-04 NOT uniform
# AUC: KS stat=0.105, p=5.535e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.299, p=9.080e-05 NOT uniform
# peakTime: KS stat=0.630, p=2.975e-21 NOT uniform
# difference: KS stat=0.450, p=1.737e-10 NOT uniform
# peakValue: KS stat=0.138, p=2.326e-01 uniform
# PTPA: KS stat=0.147, p=1.771e-01 uniform
# PTTA: KS stat=0.129, p=3.075e-01 uniform
# RMS: KS stat=0.173, p=6.878e-02 uniform
# tau: KS stat=0.403, p=1.942e-08 NOT uniform
# AUC: KS stat=0.269, p=6.161e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.505, p=2.853e-13 NOT uniform
# peakTime: KS stat=0.513, p=9.931e-14 NOT uniform
# difference: KS stat=0.445, p=2.954e-10 NOT uniform
# peakValue: KS stat=0.136, p=2.482e-01 uniform
# PTPA: KS stat=0.143, p=2.018e-01 uniform
# PTTA: KS stat=0.174, p=6.596e-02 uniform
# RMS: KS stat=0.109, p=5.025e-01 uniform
# tau: KS stat=0.308, p=4.844e-05 NOT uniform
# AUC: KS stat=0.136, p=2.437e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.490, p=1.787e-12 NOT uniform
# peakTime: KS stat=0.337, p=5.715e-06 NOT uniform
# difference: KS stat=0.301, p=7.811e-05 NOT uniform
# peakValue: KS stat=0.247, p=2.128e-03 NOT uniform
# PTPA: KS stat=0.255, p=1.388e-03 NOT uniform
# PTTA: KS stat=0.172, p=7.228e-02 uniform
# RMS: KS stat=0.178, p=5.723e-02 uniform
# tau: KS stat=0.197, p=2.613e-02 NOT uniform
# AUC: KS stat=0.241, p=2.999e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.279, p=3.248e-04 NOT uniform
# peakTime: KS stat=0.487, p=2.673e-12 NOT uniform
# difference: KS stat=0.423, p=2.930e-09 NOT uniform
# peakValue: KS stat=0.092, p=7.191e-01 uniform
# PTPA: KS stat=0.094, p=6.878e-01 uniform
# PTTA: KS stat=0.137, p=2.385e-01 uniform
# RMS: KS stat=0.187, p=3.938e-02 NOT uniform
# tau: KS stat=0.159, p=1.165e-01 uniform
# AUC: KS stat=0.266, p=7.481e-04 NOT uniform
#
# Min-max transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.283, p=2.559e-04 NOT uniform
# peakTime: KS stat=0.507, p=2.076e-13 NOT uniform
# difference: KS stat=0.418, p=4.791e-09 NOT uniform
# peakValue: KS stat=0.143, p=1.968e-01 uniform
# PTPA: KS stat=0.149, p=1.635e-01 uniform
# PTTA: KS stat=0.127, p=3.208e-01 uniform
# RMS: KS stat=0.156, p=1.275e-01 uniform
# tau: KS stat=0.060, p=9.842e-01 uniform
# AUC: KS stat=0.138, p=2.313e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.415, p=6.306e-09 NOT uniform
# peakTime: KS stat=0.549, p=8.472e-16 NOT uniform
# difference: KS stat=0.386, p=9.241e-08 NOT uniform
# peakValue: KS stat=0.189, p=3.725e-02 NOT uniform
# PTPA: KS stat=0.195, p=2.800e-02 NOT uniform
# PTTA: KS stat=0.186, p=4.150e-02 NOT uniform
# RMS: KS stat=0.110, p=4.923e-01 uniform
# tau: KS stat=0.287, p=1.990e-04 NOT uniform
# AUC: KS stat=0.105, p=5.535e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.299, p=9.080e-05 NOT uniform
# peakTime: KS stat=0.630, p=2.975e-21 NOT uniform
# difference: KS stat=0.450, p=1.737e-10 NOT uniform
# peakValue: KS stat=0.138, p=2.326e-01 uniform
# PTPA: KS stat=0.147, p=1.771e-01 uniform
# PTTA: KS stat=0.129, p=3.075e-01 uniform
# RMS: KS stat=0.173, p=6.878e-02 uniform
# tau: KS stat=0.403, p=1.942e-08 NOT uniform
# AUC: KS stat=0.269, p=6.161e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.505, p=2.853e-13 NOT uniform
# peakTime: KS stat=0.513, p=9.931e-14 NOT uniform
# difference: KS stat=0.445, p=2.954e-10 NOT uniform
# peakValue: KS stat=0.136, p=2.482e-01 uniform
# PTPA: KS stat=0.143, p=2.018e-01 uniform
# PTTA: KS stat=0.174, p=6.596e-02 uniform
# RMS: KS stat=0.109, p=5.025e-01 uniform
# tau: KS stat=0.308, p=4.844e-05 NOT uniform
# AUC: KS stat=0.136, p=2.437e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.490, p=1.787e-12 NOT uniform
# peakTime: KS stat=0.337, p=5.715e-06 NOT uniform
# difference: KS stat=0.301, p=7.811e-05 NOT uniform
# peakValue: KS stat=0.247, p=2.128e-03 NOT uniform
# PTPA: KS stat=0.255, p=1.388e-03 NOT uniform
# PTTA: KS stat=0.172, p=7.228e-02 uniform
# RMS: KS stat=0.178, p=5.723e-02 uniform
# tau: KS stat=0.197, p=2.613e-02 NOT uniform
# AUC: KS stat=0.241, p=2.999e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.279, p=3.248e-04 NOT uniform
# peakTime: KS stat=0.487, p=2.673e-12 NOT uniform
# difference: KS stat=0.423, p=2.930e-09 NOT uniform
# peakValue: KS stat=0.092, p=7.191e-01 uniform
# PTPA: KS stat=0.094, p=6.878e-01 uniform
# PTTA: KS stat=0.137, p=2.385e-01 uniform
# RMS: KS stat=0.187, p=3.938e-02 NOT uniform
# tau: KS stat=0.159, p=1.165e-01 uniform
# AUC: KS stat=0.266, p=7.481e-04 NOT uniform
#
# Quantile (uniform) transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.144, p=1.955e-01 uniform
# peakTime: KS stat=0.226, p=6.721e-03 NOT uniform
# difference: KS stat=0.135, p=2.558e-01 uniform
# peakValue: KS stat=0.029, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.159, p=1.168e-01 uniform
# peakTime: KS stat=0.254, p=1.501e-03 NOT uniform
# difference: KS stat=0.103, p=5.831e-01 uniform
# peakValue: KS stat=0.027, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.025, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.124, p=3.448e-01 uniform
# peakTime: KS stat=0.181, p=5.091e-02 uniform
# difference: KS stat=0.103, p=5.831e-01 uniform
# peakValue: KS stat=0.026, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.153, p=1.417e-01 uniform
# peakTime: KS stat=0.124, p=3.448e-01 uniform
# difference: KS stat=0.074, p=9.070e-01 uniform
# peakValue: KS stat=0.019, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.281, p=2.914e-04 NOT uniform
# peakTime: KS stat=0.139, p=2.253e-01 uniform
# difference: KS stat=0.111, p=4.795e-01 uniform
# peakValue: KS stat=0.023, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.224, p=7.466e-03 NOT uniform
# peakTime: KS stat=0.186, p=4.171e-02 NOT uniform
# difference: KS stat=0.123, p=3.614e-01 uniform
# peakValue: KS stat=0.019, p=1.000e+00 uniform
# PTPA: KS stat=0.019, p=1.000e+00 uniform
# PTTA: KS stat=0.019, p=1.000e+00 uniform
# RMS: KS stat=0.019, p=1.000e+00 uniform
# tau: KS stat=0.019, p=1.000e+00 uniform
# AUC: KS stat=0.019, p=1.000e+00 uniform
#
# Power (Yeo-Johnson, sklearn) transformation (grouped by sex and date):
#
# Sex: female, Date: April16
# reactionTime: KS stat=0.207, p=1.689e-02 NOT uniform
# peakTime: KS stat=0.343, p=3.472e-06 NOT uniform
# difference: KS stat=0.308, p=4.760e-05 NOT uniform
# peakValue: KS stat=0.181, p=5.042e-02 uniform
# PTPA: KS stat=0.186, p=4.102e-02 NOT uniform
# PTTA: KS stat=0.132, p=2.798e-01 uniform
# RMS: KS stat=0.105, p=5.613e-01 uniform
# tau: KS stat=0.060, p=9.828e-01 uniform
# AUC: KS stat=0.118, p=4.082e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.230, p=5.505e-03 NOT uniform
# peakTime: KS stat=0.504, p=3.339e-13 NOT uniform
# difference: KS stat=0.253, p=1.563e-03 NOT uniform
# peakValue: KS stat=0.099, p=6.260e-01 uniform
# PTPA: KS stat=0.120, p=3.852e-01 uniform
# PTTA: KS stat=0.119, p=3.945e-01 uniform
# RMS: KS stat=0.095, p=6.781e-01 uniform
# tau: KS stat=0.146, p=1.790e-01 uniform
# AUC: KS stat=0.118, p=4.128e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.302, p=7.147e-05 NOT uniform
# peakTime: KS stat=0.397, p=3.382e-08 NOT uniform
# difference: KS stat=0.317, p=2.583e-05 NOT uniform
# peakValue: KS stat=0.088, p=7.640e-01 uniform
# PTPA: KS stat=0.092, p=7.200e-01 uniform
# PTTA: KS stat=0.088, p=7.663e-01 uniform
# RMS: KS stat=0.218, p=9.666e-03 NOT uniform
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\Galahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (54). n_quantiles is set to n_samples.
#   warnings.warn(
# tau: KS stat=0.151, p=1.535e-01 uniform
# AUC: KS stat=0.277, p=3.770e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.336, p=6.278e-06 NOT uniform
# peakTime: KS stat=0.298, p=9.608e-05 NOT uniform
# difference: KS stat=0.305, p=5.719e-05 NOT uniform
# peakValue: KS stat=0.118, p=4.072e-01 uniform
# PTPA: KS stat=0.188, p=3.880e-02 NOT uniform
# PTTA: KS stat=0.217, p=1.010e-02 NOT uniform
# RMS: KS stat=0.123, p=3.583e-01 uniform
# tau: KS stat=0.134, p=2.594e-01 uniform
# AUC: KS stat=0.119, p=4.029e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.498, p=6.803e-13 NOT uniform
# peakTime: KS stat=0.237, p=3.732e-03 NOT uniform
# difference: KS stat=0.244, p=2.587e-03 NOT uniform
# peakValue: KS stat=0.198, p=2.496e-02 NOT uniform
# PTPA: KS stat=0.203, p=2.008e-02 NOT uniform
# PTTA: KS stat=0.161, p=1.076e-01 uniform
# RMS: KS stat=0.162, p=1.042e-01 uniform
# tau: KS stat=0.115, p=4.375e-01 uniform
# AUC: KS stat=0.111, p=4.800e-01 uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.282, p=2.678e-04 NOT uniform
# peakTime: KS stat=0.403, p=1.913e-08 NOT uniform
# difference: KS stat=0.312, p=3.500e-05 NOT uniform
# peakValue: KS stat=0.074, p=9.066e-01 uniform
# PTPA: KS stat=0.078, p=8.753e-01 uniform
# PTTA: KS stat=0.122, p=3.685e-01 uniform
# RMS: KS stat=0.112, p=4.723e-01 uniform
# tau: KS stat=0.104, p=5.637e-01 uniform
# AUC: KS stat=0.125, p=3.361e-01 uniform

# %% [markdown]
# | Variable        | Most Suitable Fit/Transformation | Generally Good? | Notes                                                      |
# |-----------------|----------------------------------|-----------------|------------------------------------------------------------|
# | peakValue       | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | RMS             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | tau             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | AUC             | Quantile (uniform)               | Yes             | Consistently uniform for all sex/date groups               |
# | reactionTime    | Quantile (uniform)               | No              | Sometimes uniform, but not consistent across all groups    |
# | peakTime        | No good fit                      | No              | No transformation yields uniformity                        |
# | difference      | Quantile (uniform)               | No              | Sometimes uniform, but not consistent across all groups    |
#
# **Notes:**
# - For strength metrics (peakValue, RMS, tau, AUC), Quantile (uniform) transformation is robust and generally good.
# - For reaction metrics (reactionTime, peakTime, difference), no transformation is consistently good; Quantile (uniform) is the best available for reactionTime and difference, but not reliable.
# - PeakTime cannot be made uniform with any tested transformation.

# %% [markdown]
# ### ---> use quantile

# %% [markdown]
# The Quantile (uniform) transformation maps each value in a variable to its rank in the sorted data, then rescales these ranks to a uniform distribution between 0 and 1. This is done using the empirical cumulative distribution function (ECDF), so the transformed data is evenly spread regardless of the original distribution.
#
# **Effect on analysis:**
# - Makes variables comparable by removing distributional differences.
# - Improves robustness for non-parametric statistics and tests that assume uniformity.
# - Destroys the original scale and spacing, so only rank order is preserved.
# - May obscure biological or experimental meaning if absolute values are important.
#
# Use quantile transformation when you need standardized, comparable variables and distributional assumptions are problematic, but be cautious if the original scale matters for interpretation.

# %%
# Suppress sklearn QuantileTransformer warning by setting n_quantiles to min(n_samples, 1000)
from sklearn.preprocessing import QuantileTransformer

def quantile_fit_df(df):
    df_copy = df.copy()
    numeric_cols = df_copy.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        vals = pd.to_numeric(df_copy[col], errors='coerce').dropna().values.reshape(-1, 1)
        n_samples = len(vals)
        if n_samples > 2:
            qt = QuantileTransformer(output_distribution='uniform', random_state=0, n_quantiles=min(n_samples, 1000))
            transformed = qt.fit_transform(vals).flatten()
            df_copy.loc[df_copy[col].dropna().index, col] = transformed
        else:
            df_copy[col] = np.nan
    return df_copy

""" fit_keys = list(dfs.keys())
for key in fit_keys:
    df = dfs[key]
    dfs[f"{key}_FIT"] = quantile_fit_df(df) """

print(f"Applied quantile fit and saved {len(dfs)} dataframes with '_FIT' suffix.")
# Out:
# Applied quantile fit and saved 13 dataframes with '_FIT' suffix.

# %%
from scipy.stats import kstest

metrics = [col for col in df.columns if col not in ['animal', 'experiment', 'sex', 'date']]
for sex in df['sex'].unique():
    for date in df['date'].unique():
        print(f"\nSex: {sex}, Date: {date}")
        df_sub = df[(df['sex'] == sex) & (df['date'] == date)]
        for metric in metrics:
            vals = pd.to_numeric(df_sub[metric], errors='coerce').dropna()
            if len(vals) > 2:
                stat, p = kstest(vals, 'uniform', args=(vals.min(), vals.max() - vals.min()))
                print(f"{metric}: KS stat={stat:.3f}, p={p:.3e} {'uniform' if p > 0.05 else 'NOT uniform'}")
            else:
                print(f"{metric}: Not enough data")
# Out:
# Sex: female, Date: April16
# reactionTime: KS stat=0.283, p=2.559e-04 NOT uniform
# peakTime: KS stat=0.507, p=2.076e-13 NOT uniform
# difference: KS stat=0.418, p=4.791e-09 NOT uniform
# peakValue: KS stat=0.143, p=1.968e-01 uniform
# PTPA: KS stat=0.149, p=1.635e-01 uniform
# PTTA: KS stat=0.127, p=3.208e-01 uniform
# RMS: KS stat=0.156, p=1.275e-01 uniform
# tau: KS stat=0.060, p=9.842e-01 uniform
# AUC: KS stat=0.138, p=2.313e-01 uniform
#
# Sex: female, Date: June26
# reactionTime: KS stat=0.415, p=6.306e-09 NOT uniform
# peakTime: KS stat=0.549, p=8.472e-16 NOT uniform
# difference: KS stat=0.386, p=9.241e-08 NOT uniform
# peakValue: KS stat=0.189, p=3.725e-02 NOT uniform
# PTPA: KS stat=0.195, p=2.800e-02 NOT uniform
# PTTA: KS stat=0.186, p=4.150e-02 NOT uniform
# RMS: KS stat=0.110, p=4.923e-01 uniform
# tau: KS stat=0.287, p=1.990e-04 NOT uniform
# AUC: KS stat=0.105, p=5.535e-01 uniform
#
# Sex: female, Date: May20
# reactionTime: KS stat=0.299, p=9.080e-05 NOT uniform
# peakTime: KS stat=0.630, p=2.975e-21 NOT uniform
# difference: KS stat=0.450, p=1.737e-10 NOT uniform
# peakValue: KS stat=0.138, p=2.326e-01 uniform
# PTPA: KS stat=0.147, p=1.771e-01 uniform
# PTTA: KS stat=0.129, p=3.075e-01 uniform
# RMS: KS stat=0.173, p=6.878e-02 uniform
# tau: KS stat=0.403, p=1.942e-08 NOT uniform
# AUC: KS stat=0.269, p=6.161e-04 NOT uniform
#
# Sex: male, Date: April16
# reactionTime: KS stat=0.505, p=2.853e-13 NOT uniform
# peakTime: KS stat=0.513, p=9.931e-14 NOT uniform
# difference: KS stat=0.445, p=2.954e-10 NOT uniform
# peakValue: KS stat=0.136, p=2.482e-01 uniform
# PTPA: KS stat=0.143, p=2.018e-01 uniform
# PTTA: KS stat=0.174, p=6.596e-02 uniform
# RMS: KS stat=0.109, p=5.025e-01 uniform
# tau: KS stat=0.308, p=4.844e-05 NOT uniform
# AUC: KS stat=0.136, p=2.437e-01 uniform
#
# Sex: male, Date: June26
# reactionTime: KS stat=0.490, p=1.787e-12 NOT uniform
# peakTime: KS stat=0.337, p=5.715e-06 NOT uniform
# difference: KS stat=0.301, p=7.811e-05 NOT uniform
# peakValue: KS stat=0.247, p=2.128e-03 NOT uniform
# PTPA: KS stat=0.255, p=1.388e-03 NOT uniform
# PTTA: KS stat=0.172, p=7.228e-02 uniform
# RMS: KS stat=0.178, p=5.723e-02 uniform
# tau: KS stat=0.197, p=2.613e-02 NOT uniform
# AUC: KS stat=0.241, p=2.999e-03 NOT uniform
#
# Sex: male, Date: May20
# reactionTime: KS stat=0.279, p=3.248e-04 NOT uniform
# peakTime: KS stat=0.487, p=2.673e-12 NOT uniform
# difference: KS stat=0.423, p=2.930e-09 NOT uniform
# peakValue: KS stat=0.092, p=7.191e-01 uniform
# PTPA: KS stat=0.094, p=6.878e-01 uniform
# PTTA: KS stat=0.137, p=2.385e-01 uniform
# RMS: KS stat=0.187, p=3.938e-02 NOT uniform
# tau: KS stat=0.159, p=1.165e-01 uniform
# AUC: KS stat=0.266, p=7.481e-04 NOT uniform

# %% [markdown]
# ### ---> uniformity improved

# %% [markdown]
# ---

# %%
import os

output_dir = "[2] Analyzer Results"
os.makedirs(output_dir, exist_ok=True)

for key, df in dfs.items():
    output_path = os.path.join(output_dir, f"{key}.xlsx")
    df.to_excel(output_path, index=False)

print(f"Saved {len(dfs)} dataframes to '{output_dir}' as .xlsx files.")
# Out:
# Saved 13 dataframes to '[2] Analyzer Results' as .xlsx files.
